# %% [markdown]
# # Import Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import pickle
from datetime import timedelta, datetime
import datetime
import os
from dotenv import load_dotenv

# %% [markdown]
# # YouTube Connection

# %%
load_dotenv()

api_key = os.getenv('API_KEY')

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-25 23_00_40.csv')
df.head()
# Out:
#       video_id                channel_id          published_at  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ  2023-12-15T15:00:16Z
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw  2023-12-15T13:00:08Z
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA  2023-12-15T16:00:16Z
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T18:47:11Z
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T16:35:30Z
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  category_id  duration  \
# 0  ['data science', 'data scientist', 'self-taugh...           28     PT12M
# 1  ['leetcode', 'coding interview question', 'dat...           27     PT58S
# 2  ['requests vs httpx', 'httpx', 'python request...           27  PT15M11S
# 3  ['data analytics', 'generative ai', 'large lan...           27  PT55M18S
# 4                                                 []           24       P0D
#
#    caption  licensed_content default_language content_rating  view_count  \
# 0     True              True            en-US             {}        4240
# 1    False              True               en             {}       28854
# 2     True              True            en-US             {}       20779
# 3     True             False            en-US             {}         266
# 4    False             False            en-US             {}           0
#
#    like_count  favourite_count  comment_count      extraction_date
# 0         225                0             18  2023-12-25 23:00:40
# 1        1161                0             19  2023-12-25 23:00:40
# 2        1316                0             97  2023-12-25 23:00:40
# 3           6                0              1  2023-12-25 23:00:40
# 4           0                0              0  2023-12-25 23:00:40

# %% [markdown]
# # Day Function

# %%
def day_gen(data):

    # converting published at
    data['published_at_formatted'] = data['published_at'].str.replace('Z','')
    data['published_at_formatted'] = data.published_at_formatted.apply(datetime.datetime.fromisoformat)

    # converting extraction date
    data['extraction_date_formatted'] = pd.to_datetime(data['extraction_date'], format='%Y-%m-%d %H:%M:%S')

    # creating Day column
    data['Day'] =  ((data['extraction_date_formatted'] - data['published_at_formatted']).dt.days) + 1

    data.drop(columns=['published_at', 'extraction_date'], inplace=True)

    return data

# %% [markdown]
# # Cleaning Function

# %%
def clean(data):
    
    # Columns to String
    columns_to_str = ['video_id', 'channel_id', 'title', 'description']

    for column in columns_to_str:
        data[column] = data[column].astype('string')

    # Object to Int
    columns_to_int = ['view_count', 'like_count', 'comment_count']

    for column in columns_to_int:
        data[column] = data[column].astype('int64')

    # YouTube Categories
    def get_categories(youtube, wanted_categories):

        all_data = []
        
        request = youtube.videoCategories().list(part='snippet', id=','.join(wanted_categories))
        
        response = request.execute()
        
        for i in range(len(response['items'])):
            data = dict(category_id = response['items'][i]['id'],
                    category= response['items'][i]['snippet']['title'])
            all_data.append(data)

        return all_data
    
    data['category_id'] = data['category_id'].astype('str')
    category_ids = data['category_id'].unique()
    category_dict = get_categories(youtube, category_ids)
    category_df = pd.DataFrame(category_dict)
    data = pd.merge(data, category_df, on='category_id', how='left')

    # Extracting Duration
    data['duration'] = data['duration'].str.replace('PT', '')
    def format_duration(time_string):

        # store hours, minutes, seconds as integers
        H = 0
        M = 0
        S = 0

        # check if vid time contains hours, minutes and/or seconds
        if 'H' in time_string:
            H += int(time_string.split('H')[0])
        if 'M' in time_string:
            M += int(time_string.split('M')[0].split('H')[-1])
        if 'S' in time_string:
            S += int(time_string.split('S')[0].split('M')[-1].split('H')[-1])
        
        formatted_time = timedelta(hours=H, minutes=M, seconds=S)

        return formatted_time

    data['duration_formatted'] = data['duration'].apply(format_duration)

    # Object to Bool
    columns_to_bool = ['caption', 'licensed_content']

    for column in columns_to_bool:
        data[column] = data[column].astype('bool')

    # Creating No. of Tags Column
    data['no_of_tags'] = data['tags'].apply(lambda x: len(set(x)))

    # Creating Title Length Column
    data['title_length'] = data['title'].apply(len)

    # Creating Description Length Column
    data['description_length'] = data['description'].apply(len)

    # Dropping Columns
    columns_to_drop = ['category_id', 'duration', 'content_rating']
    data.drop(columns=columns_to_drop, inplace=True)

    return data

# %% [markdown]
# # Testing Cleaning function on OG df

# %%
clean_df = clean(df)

# %%
clean_df = day_gen(clean_df)

# %%
clean_df.head()
# Out:
#       video_id                channel_id  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  caption  \
# 0  ['data science', 'data scientist', 'self-taugh...     True
# 1  ['leetcode', 'coding interview question', 'dat...    False
# 2  ['requests vs httpx', 'httpx', 'python request...     True
# 3  ['data analytics', 'generative ai', 'large lan...     True
# 4                                                 []    False
#
#    licensed_content default_language  view_count  like_count  favourite_count  \
# 0              True            en-US        4240         225                0
# 1              True               en       28854        1161                0
# 2              True            en-US       20779        1316                0
# 3             False            en-US         266           6                0
# 4             False            en-US           0           0                0
#
#    comment_count              category duration_formatted  no_of_tags  \
# 0             18  Science & Technology    0 days 00:12:00          36
# 1             19             Education    0 days 00:00:58          26
# 2             97             Education    0 days 00:15:11          24
# 3              1             Education    0 days 00:55:18          21
# 4              0         Entertainment    0 days 00:00:00           2
#
#    title_length  description_length published_at_formatted  \
# 0            52                4434    2023-12-15 15:00:16
# 1            63                  91    2023-12-15 13:00:08
# 2            49                1974    2023-12-15 16:00:16
# 3            32                1069    2023-12-15 18:47:11
# 4            64                1144    2023-12-15 16:35:30
#
#   extraction_date_formatted  Day
# 0       2023-12-25 23:00:40   11
# 1       2023-12-25 23:00:40   11
# 2       2023-12-25 23:00:40   11
# 3       2023-12-25 23:00:40   11
# 4       2023-12-25 23:00:40   11

# %% [markdown]
# # Concat and Apply Days

# %%
def merge_clean_function(running_df, new_df):

    # cloud needs storage of names of dfs so it knows which one to add

    # cleaning the data

    clean_new_df = clean(new_df)

    # generate day column

    day_clean_new_df = day_gen(clean_new_df)
    
    # concat with running df

    running_df = pd.concat([running_df, day_clean_new_df])
    
    running_df.reset_index(drop=True, inplace=True)

    return running_df

# %% [markdown]
# # Testing with another days data

# %%
df_2 = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-26 23_00_41.csv')
df_2.head()
# Out:
#       video_id                channel_id          published_at  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ  2023-12-15T15:00:16Z
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw  2023-12-15T13:00:08Z
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA  2023-12-15T16:00:16Z
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T18:47:11Z
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T16:35:30Z
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  category_id  duration  \
# 0  ['data science', 'data scientist', 'self-taugh...           28     PT12M
# 1  ['leetcode', 'coding interview question', 'dat...           27     PT58S
# 2  ['requests vs httpx', 'httpx', 'python request...           27  PT15M11S
# 3  ['data analytics', 'generative ai', 'large lan...           27  PT55M18S
# 4                                                 []           24       P0D
#
#    caption  licensed_content default_language content_rating  view_count  \
# 0     True              True            en-US             {}        4367
# 1    False              True               en             {}       29122
# 2     True              True            en-US             {}       21151
# 3     True             False            en-US             {}         270
# 4    False             False            en-US             {}           0
#
#    like_count  favourite_count  comment_count      extraction_date
# 0         232                0             18  2023-12-26 23:00:41
# 1        1170                0             20  2023-12-26 23:00:41
# 2        1338                0             97  2023-12-26 23:00:41
# 3           6                0              1  2023-12-26 23:00:41
# 4           0                0              0  2023-12-26 23:00:41

# %%
test_running_df = merge_clean_function(clean_df, df_2)

# %%
clean_df.shape
# Out:
# (55, 20)

# %%
df_2.shape
# Out:
# (59, 17)

# %%
test_running_df.shape
# Out:
# (114, 20)

# %%
test_running_df.head()
# Out:
#       video_id                channel_id  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  caption  \
# 0  ['data science', 'data scientist', 'self-taugh...     True
# 1  ['leetcode', 'coding interview question', 'dat...    False
# 2  ['requests vs httpx', 'httpx', 'python request...     True
# 3  ['data analytics', 'generative ai', 'large lan...     True
# 4                                                 []    False
#
#    licensed_content default_language  view_count  like_count  favourite_count  \
# 0              True            en-US        4240         225                0
# 1              True               en       28854        1161                0
# 2              True            en-US       20779        1316                0
# 3             False            en-US         266           6                0
# 4             False            en-US           0           0                0
#
#    comment_count              category duration_formatted  no_of_tags  \
# 0             18  Science & Technology    0 days 00:12:00          36
# 1             19             Education    0 days 00:00:58          26
# 2             97             Education    0 days 00:15:11          24
# 3              1             Education    0 days 00:55:18          21
# 4              0         Entertainment    0 days 00:00:00           2
#
#    title_length  description_length published_at_formatted  \
# 0            52                4434    2023-12-15 15:00:16
# 1            63                  91    2023-12-15 13:00:08
# 2            49                1974    2023-12-15 16:00:16
# 3            32                1069    2023-12-15 18:47:11
# 4            64                1144    2023-12-15 16:35:30
#
#   extraction_date_formatted  Day
# 0       2023-12-25 23:00:40   11
# 1       2023-12-25 23:00:40   11
# 2       2023-12-25 23:00:40   11
# 3       2023-12-25 23:00:40   11
# 4       2023-12-25 23:00:40   11

# %% [markdown]
# # Adding another Day

# %%
df_3 = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-27 23_00_43.csv')
df_3.head()
# Out:
#       video_id                channel_id          published_at  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ  2023-12-15T15:00:16Z
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw  2023-12-15T13:00:08Z
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA  2023-12-15T16:00:16Z
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T18:47:11Z
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw  2023-12-15T16:35:30Z
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  category_id  duration  \
# 0  ['data science', 'data scientist', 'self-taugh...           28     PT12M
# 1  ['leetcode', 'coding interview question', 'dat...           27     PT58S
# 2  ['requests vs httpx', 'httpx', 'python request...           27  PT15M11S
# 3  ['data analytics', 'generative ai', 'large lan...           27  PT55M18S
# 4                                                 []           24       P0D
#
#    caption  licensed_content default_language content_rating  view_count  \
# 0     True              True            en-US             {}        4457
# 1    False              True               en             {}       29266
# 2     True              True            en-US             {}       21650
# 3     True             False            en-US             {}         277
# 4    False             False            en-US             {}           0
#
#    like_count  favourite_count  comment_count      extraction_date
# 0         233                0             18  2023-12-27 23:00:42
# 1        1179                0             20  2023-12-27 23:00:42
# 2        1357                0             97  2023-12-27 23:00:42
# 3           6                0              2  2023-12-27 23:00:42
# 4           0                0              0  2023-12-27 23:00:42

# %%
test_2_running_df = merge_clean_function(test_running_df, df_3)

# %%
test_2_running_df.head()
# Out:
#       video_id                channel_id  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
#
#                                                title  \
# 0  How to Build Custom ChatGPTs to Learn FAST in ...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  caption  \
# 0  ['data science', 'data scientist', 'self-taugh...     True
# 1  ['leetcode', 'coding interview question', 'dat...    False
# 2  ['requests vs httpx', 'httpx', 'python request...     True
# 3  ['data analytics', 'generative ai', 'large lan...     True
# 4                                                 []    False
#
#    licensed_content default_language  view_count  like_count  favourite_count  \
# 0              True            en-US        4240         225                0
# 1              True               en       28854        1161                0
# 2              True            en-US       20779        1316                0
# 3             False            en-US         266           6                0
# 4             False            en-US           0           0                0
#
#    comment_count              category duration_formatted  no_of_tags  \
# 0             18  Science & Technology    0 days 00:12:00          36
# 1             19             Education    0 days 00:00:58          26
# 2             97             Education    0 days 00:15:11          24
# 3              1             Education    0 days 00:55:18          21
# 4              0         Entertainment    0 days 00:00:00           2
#
#    title_length  description_length published_at_formatted  \
# 0            52                4434    2023-12-15 15:00:16
# 1            63                  91    2023-12-15 13:00:08
# 2            49                1974    2023-12-15 16:00:16
# 3            32                1069    2023-12-15 18:47:11
# 4            64                1144    2023-12-15 16:35:30
#
#   extraction_date_formatted  Day
# 0       2023-12-25 23:00:40   11
# 1       2023-12-25 23:00:40   11
# 2       2023-12-25 23:00:40   11
# 3       2023-12-25 23:00:40   11
# 4       2023-12-25 23:00:40   11

# %% [markdown]
# # Developing function for requesting database

# %%
def database_creator(data, days):

    # Filter by requested days

    filter_list = list(data[data['Day'] == int(days)]['video_id'])
    filtered_df = data[data['video_id'].isin(filter_list)]
    filtered_df = filtered_df[filtered_df['Day'] <= int(days)]

    # Flip
    


    # Add channel information



    return new_data

# %% [markdown]
# ### Testing Flip

# %%
df_a = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-15 23_01_00 (2).csv')
df_b = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-16 23_00_40 (1).csv')
df_c = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-17 23_00_40 (1).csv')
df_d = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-18 23_00_52 (1).csv')
df_e = pd.read_csv('cloud_function_data_youtube_video_data_2023-12-19 23_00_41.csv')

# %%
clean_a = clean(df_a)
final_a = day_gen(clean_a)

# %%
test_flip_df = merge_clean_function(final_a, df_b)
test_flip_df = merge_clean_function(test_flip_df, df_c)
test_flip_df = merge_clean_function(test_flip_df, df_d)
test_flip_df = merge_clean_function(test_flip_df, df_e)

# %%
filter_list_flip = list(test_flip_df[test_flip_df['Day'] == 3]['video_id'])
filtered_test_flip_df = test_flip_df[test_flip_df['video_id'].isin(filter_list_flip)]
filtered_test_flip_df = filtered_test_flip_df[filtered_test_flip_df['Day'] <= 3]

# %%
len(filter_list_flip)
# Out:
# 12

# %%
filtered_test_flip_df['Day'].value_counts()
# Out:
# 1    12
# 2    12
# 3    12
# Name: Day, dtype: int64

# %%
# adjust display options to show all columns
pd.set_option('display.max_columns', None)

# %%
filtered_test_flip_df.shape
# Out:
# (36, 20)

# %%
filtered_test_flip_df.head()
# Out:
#       video_id                channel_id  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
#
#                                                title  \
# 0  I Built Python & Data Analyst Custom ChatGPT f...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  caption  \
# 0  ['data science', 'data scientist', 'self-taugh...     True
# 1  ['leetcode', 'coding interview question', 'dat...    False
# 2  ['requests vs httpx', 'httpx', 'python request...     True
# 3  ['data analytics', 'generative ai', 'large lan...     True
# 4                                                 []    False
#
#    licensed_content default_language  view_count  like_count  favourite_count  \
# 0              True            en-US        1285          94                0
# 1              True               en        4971         338                0
# 2              True            en-US        4912         456                0
# 3             False            en-US          52           1                0
# 4             False            en-US           0           0                0
#
#    comment_count              category duration_formatted  no_of_tags  \
# 0             10  Science & Technology    0 days 00:12:00          37
# 1              8             Education    0 days 00:00:58          26
# 2             27             Education    0 days 00:15:11          24
# 3              0             Education    0 days 00:55:18          21
# 4              0         Entertainment    0 days 00:00:00           2
#
#    title_length  description_length published_at_formatted  \
# 0            62                4194    2023-12-15 15:00:16
# 1            63                  91    2023-12-15 13:00:08
# 2            49                1932    2023-12-15 16:00:16
# 3            32                1069    2023-12-15 18:47:11
# 4            64                1144    2023-12-15 16:35:30
#
#   extraction_date_formatted    Day
# 0       2023-12-15 23:01:00  Day_1
# 1       2023-12-15 23:01:00  Day_1
# 2       2023-12-15 23:01:00  Day_1
# 3       2023-12-15 23:01:00  Day_1
# 4       2023-12-15 23:01:00  Day_1

# %%
filtered_test_flip_df.columns
# Out:
# Index(['video_id', 'channel_id', 'title', 'description', 'tags', 'caption',
#        'licensed_content', 'default_language', 'view_count', 'like_count',
#        'favourite_count', 'comment_count', 'category', 'duration_formatted',
#        'no_of_tags', 'title_length', 'description_length',
#        'published_at_formatted', 'extraction_date_formatted', 'Day'],
#       dtype='object')

# %%
filtered_test_flip_df.head()
# Out:
#       video_id                channel_id  \
# 0  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
#
#                                                title  \
# 0  I Built Python & Data Analyst Custom ChatGPT f...
# 1  My Favorite Stack Question! | Daily Temperatur...
# 2  Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                   Data Analytics and Generative AI
# 4  Enterprise LLM Applications - Not Just a Techn...
#
#                                          description  \
# 0  Get your Excel data visualization template (fr...
# 1  leetcode, coding interview question, data stru...
# 2  Exploring API communication in your app, consi...
# 3  Generative AI is a rapidly evolving field with...
# 4  Generative Al and Large Language Models have t...
#
#                                                 tags  caption  \
# 0  ['data science', 'data scientist', 'self-taugh...     True
# 1  ['leetcode', 'coding interview question', 'dat...    False
# 2  ['requests vs httpx', 'httpx', 'python request...     True
# 3  ['data analytics', 'generative ai', 'large lan...     True
# 4                                                 []    False
#
#    licensed_content default_language  view_count  like_count  favourite_count  \
# 0              True            en-US        1285          94                0
# 1              True               en        4971         338                0
# 2              True            en-US        4912         456                0
# 3             False            en-US          52           1                0
# 4             False            en-US           0           0                0
#
#    comment_count              category duration_formatted  no_of_tags  \
# 0             10  Science & Technology    0 days 00:12:00          37
# 1              8             Education    0 days 00:00:58          26
# 2             27             Education    0 days 00:15:11          24
# 3              0             Education    0 days 00:55:18          21
# 4              0         Entertainment    0 days 00:00:00           2
#
#    title_length  description_length published_at_formatted  \
# 0            62                4194    2023-12-15 15:00:16
# 1            63                  91    2023-12-15 13:00:08
# 2            49                1932    2023-12-15 16:00:16
# 3            32                1069    2023-12-15 18:47:11
# 4            64                1144    2023-12-15 16:35:30
#
#   extraction_date_formatted  Day
# 0       2023-12-15 23:01:00    1
# 1       2023-12-15 23:01:00    1
# 2       2023-12-15 23:01:00    1
# 3       2023-12-15 23:01:00    1
# 4       2023-12-15 23:01:00    1

# %%
# Create a new column for each day's views
filtered_test_flip_df['Day'] = 'Day_' + filtered_test_flip_df['Day'].astype(str)
df_pivoted = filtered_test_flip_df.pivot_table(index='video_id', columns='Day', values=['view_count', 'like_count', 'comment_count'], aggfunc='first', fill_value=0).reset_index()

columns_to_keep = ['video_id', 'channel_id', 'title', 'description', 'tags', 'caption',
       'licensed_content', 'default_language','category', 'duration_formatted',
       'no_of_tags', 'title_length', 'description_length',
       'published_at_formatted', 'extraction_date_formatted']
df_unique_ids = filtered_test_flip_df[columns_to_keep].copy()

df_unique_ids.drop_duplicates(subset='video_id', keep='first', inplace=True)

df_unique_ids.reset_index(drop=True, inplace=True)

# Merge with the original DataFrame to include other information
result_df = pd.concat([df_pivoted, df_unique_ids], axis=1)

result_df
# Out:
#    (video_id, )  (comment_count, Day_1)  (comment_count, Day_2)  \
# 0   0wIDVTUWU3c                       9                      15
# 1   3QvcSvWb9es                      17                      28
# 2   56i1uBshzmA                       8                      11
# 3   9Oh-hDT_VaY                      25                      32
# 4   H8nm5a99_DA                       0                       0
# 5   LciDiBeBCyY                      10                      15
# 6   NI1Psgs1tyI                       0                       0
# 7   OPyoXx0yA0I                      27                      47
# 8   WjhKxXCwFZA                       0                       0
# 9   kX9iZTQNDb4                       6                       8
# 10  qvRzYkLVmKI                       3                       4
# 11  tjo9NJBmExM                       0                       0
#
#     (comment_count, Day_3)  (like_count, Day_1)  (like_count, Day_2)  \
# 0                       14                  252                  474
# 1                       34                  414                  546
# 2                       14                  338                  671
# 3                       35                  491                  724
# 4                        1                    5                    7
# 5                       15                   94                  162
# 6                        0                    0                    0
# 7                       53                  456                  862
# 8                        0                    1                    4
# 9                        8                  270                  468
# 10                       6                  276                  333
# 11                       0                    2                    2
#
#     (like_count, Day_3)  (view_count, Day_1)  (view_count, Day_2)  \
# 0                   539                 3699                 8200
# 1                   625                 7215                10896
# 2                   863                 4971                14058
# 3                   829                 5891                13803
# 4                     7                  242                  301
# 5                   176                 1285                 2688
# 6                     0                    0                    0
# 7                   983                 4912                11558
# 8                     5                   52                  115
# 9                   535                 4191                 9141
# 10                  366                 3670                 4821
# 11                    3                    0                    0
#
#     (view_count, Day_3)     video_id                channel_id  \
# 0                  9429  LciDiBeBCyY  UCteRPiisgIoHtMgqHegpWAQ
# 1                 12559  56i1uBshzmA  UCJublDh2UsiIKsAE1553miw
# 2                 19248  OPyoXx0yA0I  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 3                 18580  WjhKxXCwFZA  UCzL_0nIe8B4-7ShhVPfJkgw
# 4                   335  NI1Psgs1tyI  UCzL_0nIe8B4-7ShhVPfJkgw
# 5                  3102  H8nm5a99_DA  UCObs0kLIrDjX2LLSybqNaEA
# 6                     0  0wIDVTUWU3c  UCJublDh2UsiIKsAE1553miw
# 7                 13798  3QvcSvWb9es  UCJublDh2UsiIKsAE1553miw
# 8                   134  tjo9NJBmExM  UCzL_0nIe8B4-7ShhVPfJkgw
# 9                 10296  9Oh-hDT_VaY  UCNU_lfiiWBdtULKOw6X0Dig
# 10                 5359  kX9iZTQNDb4  UCJublDh2UsiIKsAE1553miw
# 11                    0  qvRzYkLVmKI  UCJublDh2UsiIKsAE1553miw
#
#                                                 title  \
# 0   I Built Python & Data Analyst Custom ChatGPT f...
# 1   My Favorite Stack Question! | Daily Temperatur...
# 2   Requests vs Httpx vs Aiohttp | Which One to Pick?
# 3                    Data Analytics and Generative AI
# 4   Enterprise LLM Applications - Not Just a Techn...
# 5   From India to US: Tips, Insights and Experienc...
# 6   Facebook Asked This Coding Question 50 TIMES!!...
# 7   I Couldn't Get This Coding Question - Can You?...
# 8               Vector Embeddings for Semantic Search
# 9   Power Of Open Source Contribution-50+ End To E...
# 10  FAANG Interview Linked List Question! | Remove...
# 11  The Ultimate Linked List Question! | Copy List...
#
#                                           description  \
# 0   Get your Excel data visualization template (fr...
# 1   leetcode, coding interview question, data stru...
# 2   Exploring API communication in your app, consi...
# 3   Generative AI is a rapidly evolving field with...
# 4   Generative Al and Large Language Models have t...
# 5   Welcome to the sixth episode of the Study Abro...
# 6   leetcode, coding interview question, data stru...
# 7   leetcode, coding interview question, data stru...
# 8   In today's information-rich world, the ability...
# 9   Start Contributing in Open Source Projects
# The...
# 10  leetcode, coding interview question, data stru...
# 11  leetcode, coding interview question, data stru...
#
#                                                  tags  caption  \
# 0   ['data science', 'data scientist', 'self-taugh...     True
# 1   ['leetcode', 'coding interview question', 'dat...    False
# 2   ['requests vs httpx', 'httpx', 'python request...     True
# 3   ['data analytics', 'generative ai', 'large lan...     True
# 4                                                  []    False
# 5   ['Great Learning', 'Data Analytics', 'Data Sci...    False
# 6   ['leetcode', 'coding interview question', 'dat...    False
# 7   ['leetcode', 'coding interview question', 'dat...    False
# 8                                                  []    False
# 9   ['yt:cc=on', 'end to end ml projects', 'end to...    False
# 10  ['leetcode', 'coding interview question', 'dat...    False
# 11  ['leetcode', 'coding interview question', 'dat...    False
#
#     licensed_content default_language              category  \
# 0               True            en-US  Science & Technology
# 1               True               en             Education
# 2               True            en-US             Education
# 3              False            en-US             Education
# 4              False            en-US         Entertainment
# 5              False              NaN             Education
# 6               True               en             Education
# 7               True               en             Education
# 8              False            en-US         Entertainment
# 9               True              NaN             Education
# 10              True               en             Education
# 11              True               en             Education
#
#    duration_formatted  no_of_tags  title_length  description_length  \
# 0     0 days 00:12:00          37            62                4194
# 1     0 days 00:00:58          26            63                  91
# 2     0 days 00:15:11          24            49                1932
# 3     0 days 00:55:18          21            32                1069
# 4     0 days 00:00:00           2            64                1144
# 5     0 days 00:37:32          30            76                1433
# 6     0 days 00:00:58          26            68                  91
# 7     0 days 00:01:00          26           100                  91
# 8     0 days 00:00:00           2            37                1053
# 9     0 days 00:06:06          25            93                2373
# 10    0 days 00:01:00          26            86                  91
# 11    0 days 00:00:59          26            81                  91
#
#    published_at_formatted extraction_date_formatted
# 0     2023-12-15 15:00:16       2023-12-15 23:01:00
# 1     2023-12-15 13:00:08       2023-12-15 23:01:00
# 2     2023-12-15 16:00:16       2023-12-15 23:01:00
# 3     2023-12-15 18:47:11       2023-12-15 23:01:00
# 4     2023-12-15 16:35:30       2023-12-15 23:01:00
# 5     2023-12-15 13:30:06       2023-12-15 23:01:00
# 6     2023-12-16 13:00:02       2023-12-16 23:00:40
# 7     2023-12-16 01:00:01       2023-12-16 23:00:40
# 8     2023-12-15 23:51:29       2023-12-16 23:00:40
# 9     2023-12-17 12:32:34       2023-12-17 23:00:40
# 10    2023-12-17 13:00:36       2023-12-17 23:00:40
# 11    2023-12-17 01:00:31       2023-12-17 23:00:40

# %%
df_pivoted
# Out:
#         video_id comment_count             like_count             view_count  \
# Day                      Day_1 Day_2 Day_3      Day_1 Day_2 Day_3      Day_1
# 0    0wIDVTUWU3c             9    15    14        252   474   539       3699
# 1    3QvcSvWb9es            17    28    34        414   546   625       7215
# 2    56i1uBshzmA             8    11    14        338   671   863       4971
# 3    9Oh-hDT_VaY            25    32    35        491   724   829       5891
# 4    H8nm5a99_DA             0     0     1          5     7     7        242
# 5    LciDiBeBCyY            10    15    15         94   162   176       1285
# 6    NI1Psgs1tyI             0     0     0          0     0     0          0
# 7    OPyoXx0yA0I            27    47    53        456   862   983       4912
# 8    WjhKxXCwFZA             0     0     0          1     4     5         52
# 9    kX9iZTQNDb4             6     8     8        270   468   535       4191
# 10   qvRzYkLVmKI             3     4     6        276   333   366       3670
# 11   tjo9NJBmExM             0     0     0          2     2     3          0
#
#
# Day  Day_2  Day_3
# 0     8200   9429
# 1    10896  12559
# 2    14058  19248
# 3    13803  18580
# 4      301    335
# 5     2688   3102
# 6        0      0
# 7    11558  13798
# 8      115    134
# 9     9141  10296
# 10    4821   5359
# 11       0      0

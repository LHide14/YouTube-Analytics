# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
from datetime import timedelta
import datetime

# %% [markdown]
# # Establishing Youtube Link

# %%
api_key = 'AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # Importing Raw Data File

# %%
df = pd.read_csv('raw_df.csv')
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags  category_id  duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...           28  PT12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...           28    PT7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...           28   PT9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...           28   PT6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...           28  PT10M44S
#
#    caption  licensed_content  ... content_rating view_count  like_count  \
# 0    False              True  ...             {}       1521        75.0
# 1    False              True  ...             {}       5386       365.0
# 2    False              True  ...             {}      16112       529.0
# 3    False              True  ...             {}     104975      2554.0
# 4    False              True  ...             {}       5753       235.0
#
#    favourite_count  comment_count  channel_name subscribers  total_views  \
# 0                0           22.0       Ken Jee      254000      8708402
# 1                0           73.0       Ken Jee      254000      8708402
# 2                0           64.0       Ken Jee      254000      8708402
# 3                0          292.0       Ken Jee      254000      8708402
# 4                0           41.0       Ken Jee      254000      8708402
#
#    total_videos               playlist_id
# 0           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 1           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 2           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 3           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 4           285  UUiT9RITQ9PW6BhXK0y2jaeg
#
# [5 rows x 21 columns]

# %% [markdown]
# # Null Check

# %%
df.isnull().sum()
# Out:
# channel_id             0
# video_id               0
# published_at           0
# title                  0
# description          157
# tags                   0
# category_id            0
# duration               0
# caption                0
# licensed_content       0
# default_language    8631
# content_rating         0
# view_count             0
# like_count            11
# favourite_count        0
# comment_count         98
# channel_name           0
# subscribers            0
# total_views            0
# total_videos           0
# playlist_id            0
# dtype: int64

# %% [markdown]
# #### Filling Description Nulls

# %%
df['description'].fillna('No Description', inplace=True)

# %% [markdown]
# #### Filling like_count Nulls

# %%
df['like_count'].fillna(0, inplace=True)

# %% [markdown]
# #### Filling Comment Nulls

# %%
df['comment_count'].fillna(0, inplace=True)

# %% [markdown]
# #### Filling default language nulls

# %%
df['default_language'].fillna('None', inplace=True)

# %% [markdown]
# #### Final Check

# %%
df.isnull().sum()
# Out:
# channel_id          0
# video_id            0
# published_at        0
# title               0
# description         0
# tags                0
# category_id         0
# duration            0
# caption             0
# licensed_content    0
# default_language    0
# content_rating      0
# view_count          0
# like_count          0
# favourite_count     0
# comment_count       0
# channel_name        0
# subscribers         0
# total_views         0
# total_videos        0
# playlist_id         0
# dtype: int64

# %% [markdown]
# # Youtube Categories

# %%
def get_categories(youtube, wanted_categories):

    all_data = []
    
    request = youtube.videoCategories().list(part='snippet', id=','.join(wanted_categories))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(category_id = response['items'][i]['id'],
                category= response['items'][i]['snippet']['title'])
        all_data.append(data)

    return all_data

# %%
df['category_id'] = df['category_id'].astype('str')

# %%
df.dtypes
# Out:
# channel_id           object
# video_id             object
# published_at         object
# title                object
# description          object
# tags                 object
# category_id          object
# duration             object
# caption                bool
# licensed_content       bool
# default_language     object
# content_rating       object
# view_count            int64
# like_count          float64
# favourite_count       int64
# comment_count       float64
# channel_name         object
# subscribers           int64
# total_views           int64
# total_videos          int64
# playlist_id          object
# dtype: object

# %%
category_ids = df['category_id'].unique()
print(category_ids)
# Out:
# ['28' '22' '27' '17' '23' '24' '19' '2' '1' '20' '26' '10']

# %%
category_dict = get_categories(youtube, category_ids)
print(category_dict)
# Out:
# [{'category_id': '1', 'category': 'Film & Animation'}, {'category_id': '2', 'category': 'Autos & Vehicles'}, {'category_id': '10', 'category': 'Music'}, {'category_id': '17', 'category': 'Sports'}, {'category_id': '19', 'category': 'Travel & Events'}, {'category_id': '20', 'category': 'Gaming'}, {'category_id': '22', 'category': 'People & Blogs'}, {'category_id': '23', 'category': 'Comedy'}, {'category_id': '24', 'category': 'Entertainment'}, {'category_id': '26', 'category': 'Howto & Style'}, {'category_id': '27', 'category': 'Education'}, {'category_id': '28', 'category': 'Science & Technology'}]

# %%
category_df = pd.DataFrame(category_dict)
category_df
# Out:
#    category_id              category
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           17                Sports
# 4           19       Travel & Events
# 5           20                Gaming
# 6           22        People & Blogs
# 7           23                Comedy
# 8           24         Entertainment
# 9           26         Howto & Style
# 10          27             Education
# 11          28  Science & Technology

# %%
df = pd.merge(df, category_df, on='category_id', how='left')
df
# Out:
#                      channel_id     video_id          published_at  \
# 0      UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1      UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2      UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3      UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4      UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
# ...                         ...          ...                   ...
# 10771  UCb5aI-GwJm3ZxlwtCsLu78Q  khKT1RMe_Fk  2020-07-02T00:56:33Z
# 10772  UCb5aI-GwJm3ZxlwtCsLu78Q  ae_XVhjHd_o  2020-06-30T08:21:17Z
# 10773  UCb5aI-GwJm3ZxlwtCsLu78Q  V-EssPrGPHg  2020-06-24T05:08:39Z
# 10774  UCb5aI-GwJm3ZxlwtCsLu78Q  KiqPS6du3B4  2020-06-20T01:29:43Z
# 10775  UCb5aI-GwJm3ZxlwtCsLu78Q  QMovh2PPhbg  2020-05-29T00:42:17Z
#
#                                                    title  \
# 0                                 A Data Dream Come True
# 1      The Death of the Full-Time Job (Rise of the Co...
# 2                  How to Survive a Down Data Job Market
# 3               The Harsh Reality of the Data Job Market
# 4              7 Industries AI will Aggressively Disrupt
# ...                                                  ...
# 10771  11 YouTube Channels Every Data Scientist Shoul...
# 10772  Text analysis / mining in R - how to plot word...
# 10773  Discover 7 Hidden Gems in the R Package Ecosystem
# 10774         Clean column names in R with clean_names()
# 10775  How to plot a time series in R with ggplot2 in...
#
#                                              description  \
# 0      #datascience  #KenJee \nI gave up on my dream ...
# 1      #KenJee #jobs \nBuild your new website in seco...
# 2      #datascience  #KenJee \n\nIn this video, I giv...
# 3      #DataScience #KenJee \nFrom everything I'm hea...
# 4      #DataScience #KenJee \n\nThe future is here, a...
# ...                                                  ...
# 10771  🔔 *Subscribe for weekly R videos:* https://www...
# 10772  🔔 *Subscribe for weekly R videos:* https://www...
# 10773  🔔 *Subscribe for weekly R videos:* https://www...
# 10774  🔔 *Subscribe for weekly R videos:* https://www...
# 10775  🧰 Data science projects & consulting - https:/...
#
#                                                     tags category_id  \
# 0      ['Data Science', 'Ken Jee', 'Machine Learning'...          28
# 1      ['Data Science', 'Ken Jee', 'Machine Learning'...          28
# 2      ['Data Science', 'Ken Jee', 'data scientist', ...          28
# 3      ['Data Science', 'Ken Jee', 'data scientist', ...          28
# 4      ['Data Science', 'Ken Jee', 'Machine Learning'...          28
# ...                                                  ...         ...
# 10771                                                 []          28
# 10772  ['datascience', 'tidytext', 'tidyverse', 'ggra...          28
# 10773                                                 []          28
# 10774                          ['datascience', 'rstats']          28
# 10775  ['ggplot2', 'timeseries', 'datascience', 'data...          22
#
#        duration  caption  licensed_content  ... view_count like_count  \
# 0      PT12M38S    False              True  ...       1521       75.0
# 1        PT7M9S    False              True  ...       5386      365.0
# 2       PT9M56S    False              True  ...      16112      529.0
# 3       PT6M43S    False              True  ...     104975     2554.0
# 4      PT10M44S    False              True  ...       5753      235.0
# ...         ...      ...               ...  ...        ...        ...
# 10771   PT5M44S    False             False  ...      11907      438.0
# 10772  PT25M38S    False             False  ...      27396      627.0
# 10773  PT20M18S    False             False  ...      11757      484.0
# 10774   PT3M16S    False             False  ...       4562      116.0
# 10775  PT11M44S    False             False  ...       5689       57.0
#
#        favourite_count  comment_count                     channel_name  \
# 0                    0           22.0                          Ken Jee
# 1                    0           73.0                          Ken Jee
# 2                    0           64.0                          Ken Jee
# 3                    0          292.0                          Ken Jee
# 4                    0           41.0                          Ken Jee
# ...                ...            ...                              ...
# 10771                0           36.0  Tom Henry - data science with R
# 10772                0           61.0  Tom Henry - data science with R
# 10773                0           49.0  Tom Henry - data science with R
# 10774                0           11.0  Tom Henry - data science with R
# 10775                0            9.0  Tom Henry - data science with R
#
#        subscribers total_views  total_videos               playlist_id  \
# 0           254000     8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 1           254000     8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 2           254000     8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 3           254000     8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 4           254000     8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg
# ...            ...         ...           ...                       ...
# 10771         3760      191499            16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10772         3760      191499            16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10773         3760      191499            16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10774         3760      191499            16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10775         3760      191499            16  UUb5aI-GwJm3ZxlwtCsLu78Q
#
#                    category
# 0      Science & Technology
# 1      Science & Technology
# 2      Science & Technology
# 3      Science & Technology
# 4      Science & Technology
# ...                     ...
# 10771  Science & Technology
# 10772  Science & Technology
# 10773  Science & Technology
# 10774  Science & Technology
# 10775        People & Blogs
#
# [10776 rows x 22 columns]

# %% [markdown]
# # Extracting Duration

# %% [markdown]
# #### Stripping of the 'PT' from begining of duration values

# %%
df['duration'] = df['duration'].str.replace('PT', '')

# %% [markdown]
# #### Function to reformat the duration

# %%
def format_duration(time_string):

    # store hours, minutes, seconds as integers
    H = 0
    M = 0
    S = 0

    # check if vid time contains hours, minutes and/or seconds
    if 'H' in time_string:
        H += int(time_string.split('H')[0])
    if 'M' in time_string:
        M += int(time_string.split('M')[0].split('H')[-1])
    if 'S' in time_string:
        S += int(time_string.split('S')[0].split('M')[-1].split('H')[-1])
    
    formatted_time = timedelta(hours=H, minutes=M, seconds=S)

    return formatted_time

# %% [markdown]
# #### Applying to dataframe

# %%
df['duration_formatted'] = df['duration'].apply(format_duration)
df
# Out:
#                      channel_id     video_id          published_at  \
# 0      UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1      UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2      UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3      UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4      UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
# ...                         ...          ...                   ...
# 10771  UCb5aI-GwJm3ZxlwtCsLu78Q  khKT1RMe_Fk  2020-07-02T00:56:33Z
# 10772  UCb5aI-GwJm3ZxlwtCsLu78Q  ae_XVhjHd_o  2020-06-30T08:21:17Z
# 10773  UCb5aI-GwJm3ZxlwtCsLu78Q  V-EssPrGPHg  2020-06-24T05:08:39Z
# 10774  UCb5aI-GwJm3ZxlwtCsLu78Q  KiqPS6du3B4  2020-06-20T01:29:43Z
# 10775  UCb5aI-GwJm3ZxlwtCsLu78Q  QMovh2PPhbg  2020-05-29T00:42:17Z
#
#                                                    title  \
# 0                                 A Data Dream Come True
# 1      The Death of the Full-Time Job (Rise of the Co...
# 2                  How to Survive a Down Data Job Market
# 3               The Harsh Reality of the Data Job Market
# 4              7 Industries AI will Aggressively Disrupt
# ...                                                  ...
# 10771  11 YouTube Channels Every Data Scientist Shoul...
# 10772  Text analysis / mining in R - how to plot word...
# 10773  Discover 7 Hidden Gems in the R Package Ecosystem
# 10774         Clean column names in R with clean_names()
# 10775  How to plot a time series in R with ggplot2 in...
#
#                                              description  \
# 0      #datascience  #KenJee \nI gave up on my dream ...
# 1      #KenJee #jobs \nBuild your new website in seco...
# 2      #datascience  #KenJee \n\nIn this video, I giv...
# 3      #DataScience #KenJee \nFrom everything I'm hea...
# 4      #DataScience #KenJee \n\nThe future is here, a...
# ...                                                  ...
# 10771  🔔 *Subscribe for weekly R videos:* https://www...
# 10772  🔔 *Subscribe for weekly R videos:* https://www...
# 10773  🔔 *Subscribe for weekly R videos:* https://www...
# 10774  🔔 *Subscribe for weekly R videos:* https://www...
# 10775  🧰 Data science projects & consulting - https:/...
#
#                                                     tags category_id duration  \
# 0      ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1      ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2      ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3      ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4      ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
# ...                                                  ...         ...      ...
# 10771                                                 []          28    5M44S
# 10772  ['datascience', 'tidytext', 'tidyverse', 'ggra...          28   25M38S
# 10773                                                 []          28   20M18S
# 10774                          ['datascience', 'rstats']          28    3M16S
# 10775  ['ggplot2', 'timeseries', 'datascience', 'data...          22   11M44S
#
#        caption  licensed_content  ... like_count favourite_count  \
# 0        False              True  ...       75.0               0
# 1        False              True  ...      365.0               0
# 2        False              True  ...      529.0               0
# 3        False              True  ...     2554.0               0
# 4        False              True  ...      235.0               0
# ...        ...               ...  ...        ...             ...
# 10771    False             False  ...      438.0               0
# 10772    False             False  ...      627.0               0
# 10773    False             False  ...      484.0               0
# 10774    False             False  ...      116.0               0
# 10775    False             False  ...       57.0               0
#
#        comment_count                     channel_name  subscribers  \
# 0               22.0                          Ken Jee       254000
# 1               73.0                          Ken Jee       254000
# 2               64.0                          Ken Jee       254000
# 3              292.0                          Ken Jee       254000
# 4               41.0                          Ken Jee       254000
# ...              ...                              ...          ...
# 10771           36.0  Tom Henry - data science with R         3760
# 10772           61.0  Tom Henry - data science with R         3760
# 10773           49.0  Tom Henry - data science with R         3760
# 10774           11.0  Tom Henry - data science with R         3760
# 10775            9.0  Tom Henry - data science with R         3760
#
#        total_views total_videos               playlist_id  \
# 0          8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 1          8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 2          8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 3          8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 4          8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# ...            ...          ...                       ...
# 10771       191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10772       191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10773       191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10774       191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10775       191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q
#
#                    category  duration_formatted
# 0      Science & Technology     0 days 00:12:38
# 1      Science & Technology     0 days 00:07:09
# 2      Science & Technology     0 days 00:09:56
# 3      Science & Technology     0 days 00:06:43
# 4      Science & Technology     0 days 00:10:44
# ...                     ...                 ...
# 10771  Science & Technology     0 days 00:05:44
# 10772  Science & Technology     0 days 00:25:38
# 10773  Science & Technology     0 days 00:20:18
# 10774  Science & Technology     0 days 00:03:16
# 10775        People & Blogs     0 days 00:11:44
#
# [10776 rows x 23 columns]

# %% [markdown]
# # Published Date Format

# %%
df['published_at_formatted'] = df['published_at'].str.replace('Z','')

# format published date column to datetime
df['published_at_formatted'] = df.published_at_formatted.apply(datetime.datetime.fromisoformat)

# %% [markdown]
# # Like Ratio Column

# %%
df['like_ratio'] = (df['like_count'] / df['view_count'])
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags category_id duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
#
#    caption  licensed_content  ... comment_count channel_name  subscribers  \
# 0    False              True  ...          22.0      Ken Jee       254000
# 1    False              True  ...          73.0      Ken Jee       254000
# 2    False              True  ...          64.0      Ken Jee       254000
# 3    False              True  ...         292.0      Ken Jee       254000
# 4    False              True  ...          41.0      Ken Jee       254000
#
#    total_views  total_videos               playlist_id              category  \
# 0      8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 1      8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 2      8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 3      8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 4      8708402           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
#
#    duration_formatted  published_at_formatted  like_ratio
# 0     0 days 00:12:38     2023-11-17 12:00:28    0.049310
# 1     0 days 00:07:09     2023-09-22 11:46:35    0.067768
# 2     0 days 00:09:56     2023-09-05 10:50:39    0.032833
# 3     0 days 00:06:43     2023-08-24 11:30:19    0.024330
# 4     0 days 00:10:44     2023-08-14 11:30:19    0.040848
#
# [5 rows x 25 columns]

# %% [markdown]
# # Comment Ratio

# %%
df['comment_ratio'] = (df['comment_count'] / df['view_count'])
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags category_id duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
#
#    caption  licensed_content  ... channel_name subscribers  total_views  \
# 0    False              True  ...      Ken Jee      254000      8708402
# 1    False              True  ...      Ken Jee      254000      8708402
# 2    False              True  ...      Ken Jee      254000      8708402
# 3    False              True  ...      Ken Jee      254000      8708402
# 4    False              True  ...      Ken Jee      254000      8708402
#
#    total_videos               playlist_id              category  \
# 0           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 1           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 2           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 3           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
# 4           285  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology
#
#   duration_formatted  published_at_formatted  like_ratio  comment_ratio
# 0    0 days 00:12:38     2023-11-17 12:00:28    0.049310       0.014464
# 1    0 days 00:07:09     2023-09-22 11:46:35    0.067768       0.013554
# 2    0 days 00:09:56     2023-09-05 10:50:39    0.032833       0.003972
# 3    0 days 00:06:43     2023-08-24 11:30:19    0.024330       0.002782
# 4    0 days 00:10:44     2023-08-14 11:30:19    0.040848       0.007127
#
# [5 rows x 26 columns]

# %% [markdown]
# # Favourite Ratio

# %%
df['favourite_ratio'] = (df['favourite_count'] / df['view_count'])
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags category_id duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
#
#    caption  licensed_content  ... subscribers total_views  total_videos  \
# 0    False              True  ...      254000     8708402           285
# 1    False              True  ...      254000     8708402           285
# 2    False              True  ...      254000     8708402           285
# 3    False              True  ...      254000     8708402           285
# 4    False              True  ...      254000     8708402           285
#
#                 playlist_id              category  duration_formatted  \
# 0  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology     0 days 00:12:38
# 1  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology     0 days 00:07:09
# 2  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology     0 days 00:09:56
# 3  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology     0 days 00:06:43
# 4  UUiT9RITQ9PW6BhXK0y2jaeg  Science & Technology     0 days 00:10:44
#
#   published_at_formatted  like_ratio  comment_ratio  favourite_ratio
# 0    2023-11-17 12:00:28    0.049310       0.014464              0.0
# 1    2023-09-22 11:46:35    0.067768       0.013554              0.0
# 2    2023-09-05 10:50:39    0.032833       0.003972              0.0
# 3    2023-08-24 11:30:19    0.024330       0.002782              0.0
# 4    2023-08-14 11:30:19    0.040848       0.007127              0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Sorting nulls from ratio calculations

# %%
df['like_ratio'].fillna(0, inplace=True)
df['favourite_ratio'].fillna(0, inplace=True)
df['comment_ratio'].fillna(0, inplace=True)

# %% [markdown]
# #### Null Check

# %%
df.isnull().sum()
# Out:
# channel_id                0
# video_id                  0
# published_at              0
# title                     0
# description               0
# tags                      0
# category_id               0
# duration                  0
# caption                   0
# licensed_content          0
# default_language          0
# content_rating            0
# view_count                0
# like_count                0
# favourite_count           0
# comment_count             0
# channel_name              0
# subscribers               0
# total_views               0
# total_videos              0
# playlist_id               0
# category                  0
# duration_formatted        0
# published_at_formatted    0
# like_ratio                0
# comment_ratio             0
# favourite_ratio           0
# dtype: int64

# %% [markdown]
# # Tags Formatting

# %%
# convert tags dtype to list
df['tags_formatted'] = df['tags'].apply(lambda x: eval(x))

# create column of unique tag count for each video
df['no_of_tags'] = df['tags_formatted'].apply(lambda x: len(set(x)))

# %% [markdown]
# # Description Formatting

# %%
df['description'][0]
# Out:
# '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO'

# %%
df.loc[[4769]]['description']
# Out:
# 4769    Patreon: https://www.patreon.com/shashankkalan...
# Name: description, dtype: object

# %%
df['description'][4769]
# Out:
# 'Patreon: https://www.patreon.com/shashankkalanithi\nClick "Join" below to become a Member (same as the Patreon Membership)\n\nThis is an overview of Chapter 3 of Practical Statistics for Data Scientists. I\'ll be going over the first couple of chapters of this book because the later chapters cover similar materials from my Hands on Machine Learning book overview videos. \n\nFREE Python Course: https://youtu.be/sZDgJKI8DAM\nLink to Book: https://amzn.to/3ufeoYQ\n----------------------------\nMX Master 3 https://amzn.to/3sTroBW\nLG 35in Curved Monitor https://amzn.to/39pPzR3\nUSB-C Hub https://amzn.to/31Ip8Sl\nMacBook Pro Retina 16 Inch https://amzn.to/2PSwZde\n\nTwitter: https://twitter.com/kalamari95\nLinkedIn: https://www.linkedin.com/in/shashankkalanithi/'

# %%
df.dtypes
# Out:
# channel_id                         object
# video_id                           object
# published_at                       object
# title                              object
# description                        object
# tags                               object
# category_id                        object
# duration                           object
# caption                              bool
# licensed_content                     bool
# default_language                   object
# content_rating                     object
# view_count                          int64
# like_count                        float64
# favourite_count                     int64
# comment_count                     float64
# channel_name                       object
# subscribers                         int64
# total_views                         int64
# total_videos                        int64
# playlist_id                        object
# category                           object
# duration_formatted        timedelta64[ns]
# published_at_formatted     datetime64[ns]
# like_ratio                        float64
# comment_ratio                     float64
# favourite_ratio                   float64
# tags_formatted                     object
# no_of_tags                          int64
# dtype: object

# %%
df[df['description'].apply(lambda x: isinstance(x, float))]['description'] != 'NaN'
# Out:
# Series([], Name: description, dtype: bool)

# %% [markdown]
# # Description Length Column

# %%
df['description_length'] = df['description'].apply(len)
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags category_id duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
#
#    caption  licensed_content  ...               playlist_id  \
# 0    False              True  ...  UUiT9RITQ9PW6BhXK0y2jaeg
# 1    False              True  ...  UUiT9RITQ9PW6BhXK0y2jaeg
# 2    False              True  ...  UUiT9RITQ9PW6BhXK0y2jaeg
# 3    False              True  ...  UUiT9RITQ9PW6BhXK0y2jaeg
# 4    False              True  ...  UUiT9RITQ9PW6BhXK0y2jaeg
#
#                category  duration_formatted  published_at_formatted  \
# 0  Science & Technology     0 days 00:12:38     2023-11-17 12:00:28
# 1  Science & Technology     0 days 00:07:09     2023-09-22 11:46:35
# 2  Science & Technology     0 days 00:09:56     2023-09-05 10:50:39
# 3  Science & Technology     0 days 00:06:43     2023-08-24 11:30:19
# 4  Science & Technology     0 days 00:10:44     2023-08-14 11:30:19
#
#    like_ratio  comment_ratio favourite_ratio  \
# 0    0.049310       0.014464             0.0
# 1    0.067768       0.013554             0.0
# 2    0.032833       0.003972             0.0
# 3    0.024330       0.002782             0.0
# 4    0.040848       0.007127             0.0
#
#                                       tags_formatted  no_of_tags  \
# 0  [Data Science, Ken Jee, Machine Learning, Spor...           7
# 1  [Data Science, Ken Jee, Machine Learning, jobs...          11
# 2  [Data Science, Ken Jee, data scientist, data s...          14
# 3  [Data Science, Ken Jee, data scientist, data s...          10
# 4  [Data Science, Ken Jee, Machine Learning, ai, ...          19
#
#    description_length
# 0                1755
# 1                1992
# 2                1699
# 3                2111
# 4                2867
#
# [5 rows x 30 columns]

# %% [markdown]
# # Title Formatting

# %%
df['title'][0]
# Out:
# 'A Data Dream Come True'

# %% [markdown]
# # Title length column

# %%
df['title_length'] = df['title'].apply(len)
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags category_id duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...          28     7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...          28    9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...          28    6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...          28   10M44S
#
#    caption  licensed_content  ...              category duration_formatted  \
# 0    False              True  ...  Science & Technology    0 days 00:12:38
# 1    False              True  ...  Science & Technology    0 days 00:07:09
# 2    False              True  ...  Science & Technology    0 days 00:09:56
# 3    False              True  ...  Science & Technology    0 days 00:06:43
# 4    False              True  ...  Science & Technology    0 days 00:10:44
#
#    published_at_formatted  like_ratio  comment_ratio  favourite_ratio  \
# 0     2023-11-17 12:00:28    0.049310       0.014464              0.0
# 1     2023-09-22 11:46:35    0.067768       0.013554              0.0
# 2     2023-09-05 10:50:39    0.032833       0.003972              0.0
# 3     2023-08-24 11:30:19    0.024330       0.002782              0.0
# 4     2023-08-14 11:30:19    0.040848       0.007127              0.0
#
#                                       tags_formatted  no_of_tags  \
# 0  [Data Science, Ken Jee, Machine Learning, Spor...           7
# 1  [Data Science, Ken Jee, Machine Learning, jobs...          11
# 2  [Data Science, Ken Jee, data scientist, data s...          14
# 3  [Data Science, Ken Jee, data scientist, data s...          10
# 4  [Data Science, Ken Jee, Machine Learning, ai, ...          19
#
#    description_length  title_length
# 0                1755            22
# 1                1992            55
# 2                1699            37
# 3                2111            40
# 4                2867            41
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['channel_id', 'video_id', 'published_at', 'title', 'description',
#        'tags', 'category_id', 'duration', 'caption', 'licensed_content',
#        'default_language', 'content_rating', 'view_count', 'like_count',
#        'favourite_count', 'comment_count', 'channel_name', 'subscribers',
#        'total_views', 'total_videos', 'playlist_id', 'category',
#        'duration_formatted', 'published_at_formatted', 'like_ratio',
#        'comment_ratio', 'favourite_ratio', 'tags_formatted', 'no_of_tags',
#        'description_length', 'title_length'],
#       dtype='object')

# %% [markdown]
# # Exporting the clean data

# %%
df.to_pickle('./clean_df.pkl')

# %%
df.to_csv('clean_df.csv', index=False)

# %%
df = pd.read_csv('raw_df.csv')
df.head()
# Out:
#                  channel_id     video_id          published_at  \
# 0  UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1  UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2  UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3  UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4  UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
#
#                                                title  \
# 0                             A Data Dream Come True
# 1  The Death of the Full-Time Job (Rise of the Co...
# 2              How to Survive a Down Data Job Market
# 3           The Harsh Reality of the Data Job Market
# 4          7 Industries AI will Aggressively Disrupt
#
#                                          description  \
# 0  #datascience  #KenJee \nI gave up on my dream ...
# 1  #KenJee #jobs \nBuild your new website in seco...
# 2  #datascience  #KenJee \n\nIn this video, I giv...
# 3  #DataScience #KenJee \nFrom everything I'm hea...
# 4  #DataScience #KenJee \n\nThe future is here, a...
#
#                                                 tags  category_id  duration  \
# 0  ['Data Science', 'Ken Jee', 'Machine Learning'...           28  PT12M38S
# 1  ['Data Science', 'Ken Jee', 'Machine Learning'...           28    PT7M9S
# 2  ['Data Science', 'Ken Jee', 'data scientist', ...           28   PT9M56S
# 3  ['Data Science', 'Ken Jee', 'data scientist', ...           28   PT6M43S
# 4  ['Data Science', 'Ken Jee', 'Machine Learning'...           28  PT10M44S
#
#    caption  licensed_content  ... content_rating view_count  like_count  \
# 0    False              True  ...             {}       1521        75.0
# 1    False              True  ...             {}       5386       365.0
# 2    False              True  ...             {}      16112       529.0
# 3    False              True  ...             {}     104975      2554.0
# 4    False              True  ...             {}       5753       235.0
#
#    favourite_count  comment_count  channel_name subscribers  total_views  \
# 0                0           22.0       Ken Jee      254000      8708402
# 1                0           73.0       Ken Jee      254000      8708402
# 2                0           64.0       Ken Jee      254000      8708402
# 3                0          292.0       Ken Jee      254000      8708402
# 4                0           41.0       Ken Jee      254000      8708402
#
#    total_videos               playlist_id
# 0           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 1           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 2           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 3           285  UUiT9RITQ9PW6BhXK0y2jaeg
# 4           285  UUiT9RITQ9PW6BhXK0y2jaeg
#
# [5 rows x 21 columns]

# %%
base_list = df['video_id']
base_list
# Out:
# 0        L5Cis5bOwgw
# 1        M1I5HlzQges
# 2        T_-0l0ORi5I
# 3        w13zJB_jyBI
# 4        oZ9rMrqyTbI
#             ...
# 10771    khKT1RMe_Fk
# 10772    ae_XVhjHd_o
# 10773    V-EssPrGPHg
# 10774    KiqPS6du3B4
# 10775    QMovh2PPhbg
# Name: video_id, Length: 10776, dtype: object

# %%
base_list.to_pickle('./base_video_id_list.pkl')

# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %% [markdown]
# # API Key

# %%
# api key AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8

# %% [markdown]
# # Configuring YouTube Connection

# %%
api_key = 'AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # List of Wanted Channel's IDs

# %%
channel_ids = ['UCEBpSZhI1X8WaP-kY_2LLcg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCzL_0nIe8B4-7ShhVPfJkgw',
               'UC79Gv3mYp6zKiSwYemEik9A',
               'UCV8e2g4IWQqK71bbzGDEI4Q',
               'UCtYLUTtgS3k1Fg4y5tAhLbw',
               'UC7cs8q-gJRlGwj4A8OmCmXg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCnz-ZXXER4jOvuED5trXfEA',
               'UCteRPiisgIoHtMgqHegpWAQ',
               'UCSMqVwPTmerMiCaL_zKRjBw',
               'UCJublDh2UsiIKsAE1553miw',
               'UCvZnwzmc3m1Eush-Or8Z6DA',
               'UCNU_lfiiWBdtULKOw6X0Dig',
               'UCRqCK8izkO5xeVVtMKSHeRQ',
               'UC9LfrPNcIyHspci0t2W4T_w',
               'UCJQJAI7IjbLcpsjWdSzYz0Q',
               'UCaGe6wVIAymH17HKO8kjQsw',
               'UCWzIuRTyadYzg1-6OCejRMg',
               'UCHXa4OpASJEwrHrLeIzw7Yg',
               'UCb5aI-GwJm3ZxlwtCsLu78Q',
               'UCHGw1uT1XmqaRm-6W15-KlQ',
               'UCmMGlb7mGXYVthrXYSwlQhw',
               'UCQALLeQPoZdZC4JNUboVEUg',
               'UCSATlCAUi7R0Ik-wsZb2gOA',
               'UC1emV4A8liRs9p80CY8ElUQ',
               'UCDybamfye5An6p-j1t2YMsg',
               'UCVhQ2NnY5Rskt6UjCUkJ_DA',
               'UCq6XkhO5SZ66N04IcPbqNcw',
               'UCn1O_4_ApzbYwrsUdRoMmOg',
               'UCUIBKDoSSwehuDK4jk1CjFQ',
               'UCw_LFe2pS8x3NyipGNJgeEA',
               'UCPvDKIsrjA_h3g5yZJwCIHA',
               'UCObs0kLIrDjX2LLSybqNaEA',
               'UCChmJrVa8kDg05JfCmxpLRw',
               'UCup-fnSNRaByeuXOWqfnykw',
               'UCI8JpGrDmtggrryhml8kFGw']

# %% [markdown]
# # Function to Gather Channel Information

# %%
def get_channel_stats(youtube, channel_id):
    
    all_data = []
    
    request = youtube.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats_df = pd.DataFrame(channel_stats)
channel_stats_df
# Out:
#                             channel_name                channel_id  \
# 0                  Thu Vu data analytics  UCJQJAI7IjbLcpsjWdSzYz0Q
# 1                         Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q
# 2                 Rocketing Data Science  UCUIBKDoSSwehuDK4jk1CjFQ
# 3                               DataCamp  UC79Gv3mYp6zKiSwYemEik9A
# 4                          luke barousse  UCaGe6wVIAymH17HKO8kjQsw
# 5                     Shashank Kalanithi  UCvZnwzmc3m1Eush-Or8Z6DA
# 6                             Krish Naik  UCNU_lfiiWBdtULKOw6X0Dig
# 7                              Jon Krohn  UCup-fnSNRaByeuXOWqfnykw
# 8                         Great Learning  UCObs0kLIrDjX2LLSybqNaEA
# 9                             ArjanCodes  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 10                               Jabrils  UCQALLeQPoZdZC4JNUboVEUg
# 11                      365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg
# 12           StatQuest with Josh Starmer  UCtYLUTtgS3k1Fg4y5tAhLbw
# 13                      Nicholas Renotte  UCHXa4OpASJEwrHrLeIzw7Yg
# 14                          Data With Mo  UCDybamfye5An6p-j1t2YMsg
# 15                               Dataiku  UCSMqVwPTmerMiCaL_zKRjBw
# 16                        Darshil Parmar  UCChmJrVa8kDg05JfCmxpLRw
# 17                           Keith Galli  UCq6XkhO5SZ66N04IcPbqNcw
# 18                               techTFQ  UCnz-ZXXER4jOvuED5trXfEA
# 19       Tom Henry - data science with R  UCb5aI-GwJm3ZxlwtCsLu78Q
# 20                      Alex The Analyst  UC7cs8q-gJRlGwj4A8OmCmXg
# 21                       Study with Tina  UCI8JpGrDmtggrryhml8kFGw
# 22                         Andy McDonald  UCn1O_4_ApzbYwrsUdRoMmOg
# 23                     Data Science Dojo  UCzL_0nIe8B4-7ShhVPfJkgw
# 24                             Data Nash  UCRqCK8izkO5xeVVtMKSHeRQ
# 25                      Learn with Lukas  UCw_LFe2pS8x3NyipGNJgeEA
# 26                          Tech Classes  UCPvDKIsrjA_h3g5yZJwCIHA
# 27                  freeCodeCamp Español  UC1emV4A8liRs9p80CY8ElUQ
# 28                               Ken Jee  UCiT9RITQ9PW6BhXK0y2jaeg
# 29                     Time Out With Tim  UCSATlCAUi7R0Ik-wsZb2gOA
# 30                             Greg Hogg  UCJublDh2UsiIKsAE1553miw
# 31                           Joma in NYC  UCmMGlb7mGXYVthrXYSwlQhw
# 32                         Sundas Khalid  UCteRPiisgIoHtMgqHegpWAQ
# 33          Data Science for High School  UCWzIuRTyadYzg1-6OCejRMg
# 34  Data36 - Online Data Science Courses  UC9LfrPNcIyHspci0t2W4T_w
# 35                   Data Science Basics  UCHGw1uT1XmqaRm-6W15-KlQ
#
#    subscribers total_views total_videos               playlist_id
# 0       174000     5789346           78  UUJQJAI7IjbLcpsjWdSzYz0Q
# 1       168000     5373120          323  UUV8e2g4IWQqK71bbzGDEI4Q
# 2         1750      153848           88  UUUIBKDoSSwehuDK4jk1CjFQ
# 3       154000    22705138         1512  UU79Gv3mYp6zKiSwYemEik9A
# 4          331        3264            8  UUaGe6wVIAymH17HKO8kjQsw
# 5       138000     6478635          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 6       839000    84839423         1743  UUNU_lfiiWBdtULKOw6X0Dig
# 7        18200      692260          143  UUup-fnSNRaByeuXOWqfnykw
# 8       806000    62767792         1851  UUObs0kLIrDjX2LLSybqNaEA
# 9       204000    13918532          304  UUVhQ2NnY5Rskt6UjCUkJ_DA
# 10      496000    26815549          164  UUQALLeQPoZdZC4JNUboVEUg
# 11      301000    13314176          223  UUEBpSZhI1X8WaP-kY_2LLcg
# 12     1040000    56232443          265  UUtYLUTtgS3k1Fg4y5tAhLbw
# 13      214000    13679412          303  UUHXa4OpASJEwrHrLeIzw7Yg
# 14       71500     2130348           64  UUDybamfye5An6p-j1t2YMsg
# 15       15100     9118566          675  UUSMqVwPTmerMiCaL_zKRjBw
# 16      101000     4119688          136  UUChmJrVa8kDg05JfCmxpLRw
# 17      207000    14183360           78  UUq6XkhO5SZ66N04IcPbqNcw
# 18      250000    13090245          100  UUnz-ZXXER4jOvuED5trXfEA
# 19        3760      191081           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 20      629000    26574606          262  UU7cs8q-gJRlGwj4A8OmCmXg
# 21       20900      290359          249  UUI8JpGrDmtggrryhml8kFGw
# 22        6440      288453           47  UUn1O_4_ApzbYwrsUdRoMmOg
# 23      101000     5695646          454  UUzL_0nIe8B4-7ShhVPfJkgw
# 24       18300      880630           49  UURqCK8izkO5xeVVtMKSHeRQ
# 25       27000     1423295           53  UUw_LFe2pS8x3NyipGNJgeEA
# 26       29200     1883561          155  UUPvDKIsrjA_h3g5yZJwCIHA
# 27      225000     7652655           78  UU1emV4A8liRs9p80CY8ElUQ
# 28      254000     8698465          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 29        6410       28427            9  UUSATlCAUi7R0Ik-wsZb2gOA
# 30       55300     3372500          539  UUJublDh2UsiIKsAE1553miw
# 31      260000    14887179           20  UUmMGlb7mGXYVthrXYSwlQhw
# 32      180000     9038366          114  UUteRPiisgIoHtMgqHegpWAQ
# 33          32        1278           34  UUWzIuRTyadYzg1-6OCejRMg
# 34        4800      203916           69  UU9LfrPNcIyHspci0t2W4T_w
# 35        5620      281639          144  UUHGw1uT1XmqaRm-6W15-KlQ

# %% [markdown]
# # Get Video IDs

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId = playlist_id,
        maxResults=50)
    
    response = request.execute()
    
    return response

# %%
playlist_id_list = ['UUiT9RITQ9PW6BhXK0y2jaeg']

# %%
def mass_video_ids(youtube, playlist_id_lists):

    all_data = []

    for id in playlist_id_lists:

        request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId = id,
            maxResults=50)
            
        response = request.execute()

        for i in range(len(response['items'])):
            data = dict(playlist_id = id,
                video_id = response['items'][i]['contentDetails']['videoId'])
            all_data.append(data)

    return all_data

# %%
video_ids = mass_video_ids(youtube, playlist_id_list)

# %%
video_id_df = pd.DataFrame(video_ids)
video_id_df.head()
# Out:
#                 playlist_id     video_id
# 0  UUiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw
# 1  UUiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges
# 2  UUiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I
# 3  UUiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI
# 4  UUiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI

# %%
playlist_id = 'UUiT9RITQ9PW6BhXK0y2jaeg'

# %%
get_video_ids(youtube, playlist_id)
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '5GTKcvjaDCWFjK9Fcwgz_gb8DJA',
#  'nextPageToken': 'EAAaI1BUOkNESWlFRGhETlVaQlJUWkNNVFkwT0RFelF6Z29BVkFC',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'OwocmkLUUACMmDgcgw78tBXO1kU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkw1Q2lzNWJPd2d3',
#    'contentDetails': {'videoId': 'L5Cis5bOwgw',
#     'videoPublishedAt': '2023-11-17T12:00:28Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'JSkVJoB8qyrUEb_2d86fVyhZ8zA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk0xSTVIbHpRZ2Vz',
#    'contentDetails': {'videoId': 'M1I5HlzQges',
#     'videoPublishedAt': '2023-09-22T11:46:35Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'GrEzUnPO5hn_VGGrdt4_poII6iM',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlRfLTBsME9SaTVJ',
#    'contentDetails': {'videoId': 'T_-0l0ORi5I',
#     'videoPublishedAt': '2023-09-05T10:50:39Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '1iT5MxaO-aNNMZ2PZq0ySOhmcf8',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLncxM3pKQl9qeUJJ',
#    'contentDetails': {'videoId': 'w13zJB_jyBI',
#     'videoPublishedAt': '2023-08-24T11:30:19Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'CsCMN2KacZ1d5gd7V9SQP0OPWh4',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLm9aOXJNcnF5VGJJ',
#    'contentDetails': {'videoId': 'oZ9rMrqyTbI',
#     'videoPublishedAt': '2023-08-14T11:30:19Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'vvHNtJnrA7rO-qfdt11p3PqWvMc',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjZCcllLZHFxNHVB',
#    'contentDetails': {'videoId': '6BrYKdqq4uA',
#     'videoPublishedAt': '2023-08-07T17:57:05Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'XAQjqVcW_L1EETupB1Hi67uoUzA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjFkQXZiSU1yTG9z',
#    'contentDetails': {'videoId': '1dAvbIMrLos',
#     'videoPublishedAt': '2023-07-24T12:00:01Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'KJarbB5RfPB-1kDW8xFKWi2w3EI',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLmxxWXhtWU1rZks4',
#    'contentDetails': {'videoId': 'lqYxmYMkfK8',
#     'videoPublishedAt': '2023-07-22T09:42:29Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Tbrmb_fMvMtA5Xm33U-KUBlT1yg',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLi1KVFU3MzRvTWZr',
#    'contentDetails': {'videoId': '-JTU734oMfk',
#     'videoPublishedAt': '2023-06-23T17:28:36Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'DfsthqjoImNJX9fZxGMQhXJ-ylw',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkhWcGJtdTdyRllF',
#    'contentDetails': {'videoId': 'HVpbmu7rFYE',
#     'videoPublishedAt': '2023-05-26T12:00:21Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'MqSC-d2PW0ClEI5EFAXVHGAWwdY',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk5RUTNEUmRYQVhF',
#    'contentDetails': {'videoId': 'NQQ3DRdXAXE',
#     'videoPublishedAt': '2023-05-16T12:00:25Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'U2EUYUCBCPVGoqaIaR1nRZ6-VwM',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnhwaS1NMmozTm1F',
#    'contentDetails': {'videoId': 'xpi-M2j3NmE',
#     'videoPublishedAt': '2023-05-04T12:04:56Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'oeB3tZh_GYLh6_zcX2h6tcG9OZ0',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlgwN3c3UUZvTHBj',
#    'contentDetails': {'videoId': 'X07w7QFoLpc',
#     'videoPublishedAt': '2023-04-06T13:00:32Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'pxeYRG1p9Mj8fQ8U_QDP5bxzZu0',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlJSblRoQXRLdXEw',
#    'contentDetails': {'videoId': 'RRnThAtKuq0',
#     'videoPublishedAt': '2023-04-03T13:00:27Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'wcRuQ8RTWR7xzEJ3d6uYJGZhgM4',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnIzek9wakVPa2dF',
#    'contentDetails': {'videoId': 'r3zOpjEOkgE',
#     'videoPublishedAt': '2023-03-30T13:00:37Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Fql-Ly9OOYIRFDC2kovp1vDqlbk',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnMtWFlGRXp5OVdj',
#    'contentDetails': {'videoId': 's-XYFEzy9Wc',
#     'videoPublishedAt': '2023-03-27T13:00:41Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Z0_vlmOt-G1mdDD7acfGqwY8BmY',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLmlCaDF3bDRvNlY0',
#    'contentDetails': {'videoId': 'iBh1wl4o6V4',
#     'videoPublishedAt': '2023-03-23T13:00:35Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '8IYcCztqoLPZIxeMQ3YJgEHCmHc',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkw2bFhLZFA0UWJn',
#    'contentDetails': {'videoId': 'L6lXKdP4Qbg',
#     'videoPublishedAt': '2023-03-21T13:00:15Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'qCw4NEjAacOU7tPiNI5lGDU9n6Y',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnhHRGw2cmxCeWdV',
#    'contentDetails': {'videoId': 'xGDl6rlBygU',
#     'videoPublishedAt': '2023-03-18T13:00:42Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'bPZf58RWotVrLwNGQciEpMqAK-w',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlNZNnk2WThDNTk0',
#    'contentDetails': {'videoId': 'SY6y6Y8C594',
#     'videoPublishedAt': '2023-03-16T01:19:35Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'CBodyhzE2y9ExDEFPHYKx0NaBiU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjFSVWoyYUxReDhJ',
#    'contentDetails': {'videoId': '1RUj2aLQx8I',
#     'videoPublishedAt': '2023-03-09T13:00:01Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'H01yAfyEPUj8JmfKKXmSIexpjiA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk1relpYU3cxR2xr',
#    'contentDetails': {'videoId': 'MkzZXSw1Glk',
#     'videoPublishedAt': '2023-03-07T13:00:11Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HIGJhSWUXZuQ2mNgermErES7Eu0',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjluZURGWFR4S3hB',
#    'contentDetails': {'videoId': '9neDFXTxKxA',
#     'videoPublishedAt': '2023-03-03T13:00:07Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'jMX5JA5iJ2YBGOwCv8g3FwN9FmA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlVhTk5WdWtNMjdn',
#    'contentDetails': {'videoId': 'UaNNVukM27g',
#     'videoPublishedAt': '2023-03-01T13:00:17Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'shBB8PbbkVSV-N66Z0pkCBAQK5Q',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjNsTjAtUzNzeW1N',
#    'contentDetails': {'videoId': '3lN0-S3symM',
#     'videoPublishedAt': '2023-02-27T13:00:32Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'KHveEasTYn2tyFHsY-D5yIQexyU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk0tQU44ZVdMeG1z',
#    'contentDetails': {'videoId': 'M-AN8eWLxms',
#     'videoPublishedAt': '2023-02-24T17:00:13Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '65-qqr2IwwiiAp21oDyAO6hTc8E',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk1YRlpoYnZRcU04',
#    'contentDetails': {'videoId': 'MXFZhbvQqM8',
#     'videoPublishedAt': '2023-02-21T17:13:47Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Zz0WXj-ZyTsxVeTMmzPGb0yFxSs',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjU0bjYxWGpLaWZJ',
#    'contentDetails': {'videoId': '54n61XjKifI',
#     'videoPublishedAt': '2023-02-17T13:00:03Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'YAwFph-W7MMsbNG9aYRHcIlWvdk',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnB5V1lJUlI4cnJF',
#    'contentDetails': {'videoId': 'pyWYIRR8rrE',
#     'videoPublishedAt': '2023-02-15T10:00:37Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'tWF2Oz1ZZEcmGcX4ETuy6hV8UYQ',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLm9ud1JmYnQtLWN3',
#    'contentDetails': {'videoId': 'onwRfbt--cw',
#     'videoPublishedAt': '2023-02-13T13:00:36Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '31fkijtZRk5dZKt-QPSNmhJntzU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnU2UDIzb3VTWWhB',
#    'contentDetails': {'videoId': 'u6P23ouSYhA',
#     'videoPublishedAt': '2023-02-08T13:00:39Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '097w6feEWfAKi-c0GJdV3gxNLDU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLlJNTVZ1dlM3U19n',
#    'contentDetails': {'videoId': 'RMMVuvS7S_g',
#     'videoPublishedAt': '2023-02-06T19:35:25Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'jEJw6bW-V5_T1Wr8ClS1BvtIS9E',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjVBd2JQQVY4RlMw',
#    'contentDetails': {'videoId': '5AwbPAV8FS0',
#     'videoPublishedAt': '2023-02-03T12:00:03Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'xi4yNHei-X2fi0xAnoY_fHgMPN0',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkEyT1FnVTBJUk5v',
#    'contentDetails': {'videoId': 'A2OQgU0IRNo',
#     'videoPublishedAt': '2023-02-01T12:00:12Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'xdfK9lNoNwG3nKi0GgDbwetjVFs',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLng1UV9ucklxRmlr',
#    'contentDetails': {'videoId': 'x5Q_nrIqFik',
#     'videoPublishedAt': '2023-01-27T11:00:44Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'KaLSmnvo7zge1TuX2xyHZ5_z5GY',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjdqYTJFTEJWTWxV',
#    'contentDetails': {'videoId': '7ja2ELBVMlU',
#     'videoPublishedAt': '2023-01-25T11:00:05Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'MoNf-FCJP45otiZtGu6FAwzb8zc',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLloyTXlMUWFfdlZ3',
#    'contentDetails': {'videoId': 'Z2MyLQa_vVw',
#     'videoPublishedAt': '2023-01-23T15:31:48Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'OVdqsZa3jDmxE3BJHvIg3u29w5Y',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkpUbEI5ZndZUmsw',
#    'contentDetails': {'videoId': 'JTlB9fwYRk0',
#     'videoPublishedAt': '2023-01-19T07:00:06Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'QkL2yWkYdTzkyc8dKHO1toYDjPA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk9KRGZfZlRFTko0',
#    'contentDetails': {'videoId': 'OJDf_fTENJ4',
#     'videoPublishedAt': '2023-01-17T07:00:12Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'imc23_m0K_JxVjC-JhpV8FB1tds',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLm5xQ2tkcWhWLUpZ',
#    'contentDetails': {'videoId': 'nqCkdqhV-JY',
#     'videoPublishedAt': '2023-01-12T11:45:02Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'jgVOkbtGpWQ9evuS1tmNxbgJGhQ',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLmI4dDhsREwxM3Nn',
#    'contentDetails': {'videoId': 'b8t8lDL13sg',
#     'videoPublishedAt': '2023-01-09T00:35:13Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'eAyw_eC_Ltmu-PdIyt3KXDm7EKo',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLnQ2Q0QxRXdVNWtj',
#    'contentDetails': {'videoId': 't6CD1EwU5kc',
#     'videoPublishedAt': '2023-01-03T13:00:34Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '3OHlk4vG3vngGb2Va61Bax338cw',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLmVJeEhlNDVoemhR',
#    'contentDetails': {'videoId': 'eIxHe45hzhQ',
#     'videoPublishedAt': '2022-12-14T13:00:23Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'Hk_GHAMcKYNIpyXZkR6y_8NZbkA',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjNOSk9XV3ZOSzNJ',
#    'contentDetails': {'videoId': '3NJOWWvNK3I',
#     'videoPublishedAt': '2022-11-14T13:00:02Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'vNUTKRaVyvZRBlUepXUVmSxcyAU',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjRfVnRNV0pTbzFv',
#    'contentDetails': {'videoId': '4_VtMWJSo1o',
#     'videoPublishedAt': '2022-10-07T13:00:04Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'vUs4YtRdf0RryrGrxbOl5hUQ7ck',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLk95YlhXbDNJV3ZJ',
#    'contentDetails': {'videoId': 'OybXWl3IWvI',
#     'videoPublishedAt': '2022-09-29T20:40:31Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'OgFBaJHBI-P-stt6LkbNuFzfwBo',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLm5SSFBRNVplQjVZ',
#    'contentDetails': {'videoId': 'nRHPQ5ZeB5Y',
#     'videoPublishedAt': '2022-09-27T17:21:13Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'G8fBd1aGSkajTC6XDs_iEYOCso4',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLjBKV0M0TTBRaHFj',
#    'contentDetails': {'videoId': '0JWC4M0Qhqc',
#     'videoPublishedAt': '2022-08-29T13:00:01Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'APXw7Eg8APX2_X8uTDQyhXX8mHQ',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLm9Odnl2WUd3NW40',
#    'contentDetails': {'videoId': 'oNvyvYGw5n4',
#     'videoPublishedAt': '2022-08-05T20:20:04Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'gXqZaEehTdQCvGMolRuiLhEIPBY',
#    'id': 'VVVpVDlSSVRROVBXNkJoWEsweTJqYWVnLkdhWlJ1Y2hSQ3l3',
#    'contentDetails': {'videoId': 'GaZRuchRCyw',
#     'videoPublishedAt': '2022-08-04T18:34:49Z'}}],
#  'pageInfo': {'totalResults': 285, 'resultsPerPage': 50}}

# %% [markdown]
# # Creating Table With Creators and VideoIDs

# %%
playlist_ids_dict = dict(zip(channel_stats_df['channel_name'], channel_stats_df['playlist_id']))

playlist_ids_dict
# Out:
# {'Ken Jee': 'UUiT9RITQ9PW6BhXK0y2jaeg',
#  '365 Data Science': 'UUEBpSZhI1X8WaP-kY_2LLcg',
#  'StatQuest with Josh Starmer': 'UUtYLUTtgS3k1Fg4y5tAhLbw',
#  'Alex The Analyst': 'UU7cs8q-gJRlGwj4A8OmCmXg',
#  'Data Science Dojo': 'UUzL_0nIe8B4-7ShhVPfJkgw',
#  'Data Professor': 'UUV8e2g4IWQqK71bbzGDEI4Q',
#  'DataCamp': 'UU79Gv3mYp6zKiSwYemEik9A'}

# %%
def get_video_ids(youtube, playlist_ids_dict):
    
    # Empty list to fill with the video IDs
    # A way of storing Channel name with all of the video IDs

# %% [markdown]
# # What do we want from each video?

# %%
# Title (for NLP)
# Views
# Likes
# Tags
# Description

# %%
request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId = playlist_id)
    
response = request.execute()

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="L5Cis5bOwgw")
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'h4x4JsNyenieNu07dWDgywzmODA',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'CRzmisgylXlOUTkhsx-WA8raCWM',
#    'id': 'L5Cis5bOwgw',
#    'snippet': {'publishedAt': '2023-11-17T12:00:28Z',
#     'channelId': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#     'title': 'A Data Dream Come True',
#     'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Ken Jee',
#     'tags': ['Data Science',
#      'Ken Jee',
#      'Machine Learning',
#      'Sports Analytics',
#      'data scientist',
#      'data science journey',
#      'data science 2023'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'A Data Dream Come True',
#      'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT12M38S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1303',
#     'likeCount': '71',
#     'favoriteCount': '0',
#     'commentCount': '22'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

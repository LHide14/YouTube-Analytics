# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %% [markdown]
# # API Key

# %%
# api key AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8

# %% [markdown]
# # Configuring YouTube Connection

# %%
api_key = 'AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # List of Wanted Channel's IDs

# %%
channel_ids = ['UCEBpSZhI1X8WaP-kY_2LLcg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCzL_0nIe8B4-7ShhVPfJkgw',
               'UC79Gv3mYp6zKiSwYemEik9A',
               'UCV8e2g4IWQqK71bbzGDEI4Q',
               'UCtYLUTtgS3k1Fg4y5tAhLbw',
               'UC7cs8q-gJRlGwj4A8OmCmXg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCnz-ZXXER4jOvuED5trXfEA',
               'UCteRPiisgIoHtMgqHegpWAQ',
               'UCSMqVwPTmerMiCaL_zKRjBw',
               'UCJublDh2UsiIKsAE1553miw',
               'UCvZnwzmc3m1Eush-Or8Z6DA',
               'UCNU_lfiiWBdtULKOw6X0Dig',
               'UCRqCK8izkO5xeVVtMKSHeRQ',
               'UC9LfrPNcIyHspci0t2W4T_w',
               'UCJQJAI7IjbLcpsjWdSzYz0Q',
               'UCaGe6wVIAymH17HKO8kjQsw',
               'UCWzIuRTyadYzg1-6OCejRMg',
               'UCHXa4OpASJEwrHrLeIzw7Yg',
               'UCb5aI-GwJm3ZxlwtCsLu78Q',
               'UCHGw1uT1XmqaRm-6W15-KlQ',
               'UCmMGlb7mGXYVthrXYSwlQhw',
               'UCQALLeQPoZdZC4JNUboVEUg',
               'UCSATlCAUi7R0Ik-wsZb2gOA',
               'UC1emV4A8liRs9p80CY8ElUQ',
               'UCDybamfye5An6p-j1t2YMsg',
               'UCVhQ2NnY5Rskt6UjCUkJ_DA',
               'UCq6XkhO5SZ66N04IcPbqNcw',
               'UCn1O_4_ApzbYwrsUdRoMmOg',
               'UCUIBKDoSSwehuDK4jk1CjFQ',
               'UCw_LFe2pS8x3NyipGNJgeEA',
               'UCPvDKIsrjA_h3g5yZJwCIHA',
               'UCObs0kLIrDjX2LLSybqNaEA',
               'UCChmJrVa8kDg05JfCmxpLRw',
               'UCup-fnSNRaByeuXOWqfnykw',
               'UCI8JpGrDmtggrryhml8kFGw']

# %% [markdown]
# # Function to Gather Channel Information

# %%
def get_channel_stats(youtube, channel_id):
    
    all_data = []
    
    request = youtube.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %% [markdown]
# # Channel Stats Dataframe

# %%
channel_stats_df = pd.DataFrame(channel_stats)
channel_stats_df
# Out:
#                             channel_name                channel_id  \
# 0                  Thu Vu data analytics  UCJQJAI7IjbLcpsjWdSzYz0Q
# 1                         Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q
# 2                 Rocketing Data Science  UCUIBKDoSSwehuDK4jk1CjFQ
# 3                               DataCamp  UC79Gv3mYp6zKiSwYemEik9A
# 4                          luke barousse  UCaGe6wVIAymH17HKO8kjQsw
# 5                     Shashank Kalanithi  UCvZnwzmc3m1Eush-Or8Z6DA
# 6                             Krish Naik  UCNU_lfiiWBdtULKOw6X0Dig
# 7                              Jon Krohn  UCup-fnSNRaByeuXOWqfnykw
# 8                         Great Learning  UCObs0kLIrDjX2LLSybqNaEA
# 9                             ArjanCodes  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 10                               Jabrils  UCQALLeQPoZdZC4JNUboVEUg
# 11                      365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg
# 12           StatQuest with Josh Starmer  UCtYLUTtgS3k1Fg4y5tAhLbw
# 13                      Nicholas Renotte  UCHXa4OpASJEwrHrLeIzw7Yg
# 14                          Data With Mo  UCDybamfye5An6p-j1t2YMsg
# 15                               Dataiku  UCSMqVwPTmerMiCaL_zKRjBw
# 16                        Darshil Parmar  UCChmJrVa8kDg05JfCmxpLRw
# 17                           Keith Galli  UCq6XkhO5SZ66N04IcPbqNcw
# 18                               techTFQ  UCnz-ZXXER4jOvuED5trXfEA
# 19       Tom Henry - data science with R  UCb5aI-GwJm3ZxlwtCsLu78Q
# 20                      Alex The Analyst  UC7cs8q-gJRlGwj4A8OmCmXg
# 21                       Study with Tina  UCI8JpGrDmtggrryhml8kFGw
# 22                         Andy McDonald  UCn1O_4_ApzbYwrsUdRoMmOg
# 23                     Data Science Dojo  UCzL_0nIe8B4-7ShhVPfJkgw
# 24                             Data Nash  UCRqCK8izkO5xeVVtMKSHeRQ
# 25                      Learn with Lukas  UCw_LFe2pS8x3NyipGNJgeEA
# 26                          Tech Classes  UCPvDKIsrjA_h3g5yZJwCIHA
# 27                  freeCodeCamp Español  UC1emV4A8liRs9p80CY8ElUQ
# 28                               Ken Jee  UCiT9RITQ9PW6BhXK0y2jaeg
# 29                     Time Out With Tim  UCSATlCAUi7R0Ik-wsZb2gOA
# 30                             Greg Hogg  UCJublDh2UsiIKsAE1553miw
# 31                           Joma in NYC  UCmMGlb7mGXYVthrXYSwlQhw
# 32                         Sundas Khalid  UCteRPiisgIoHtMgqHegpWAQ
# 33          Data Science for High School  UCWzIuRTyadYzg1-6OCejRMg
# 34  Data36 - Online Data Science Courses  UC9LfrPNcIyHspci0t2W4T_w
# 35                   Data Science Basics  UCHGw1uT1XmqaRm-6W15-KlQ
#
#    subscribers total_views total_videos               playlist_id
# 0       174000     5789346           78  UUJQJAI7IjbLcpsjWdSzYz0Q
# 1       168000     5373120          323  UUV8e2g4IWQqK71bbzGDEI4Q
# 2         1750      153848           88  UUUIBKDoSSwehuDK4jk1CjFQ
# 3       154000    22705138         1512  UU79Gv3mYp6zKiSwYemEik9A
# 4          331        3264            8  UUaGe6wVIAymH17HKO8kjQsw
# 5       138000     6478635          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 6       839000    84839423         1743  UUNU_lfiiWBdtULKOw6X0Dig
# 7        18200      692260          143  UUup-fnSNRaByeuXOWqfnykw
# 8       806000    62767792         1851  UUObs0kLIrDjX2LLSybqNaEA
# 9       204000    13918532          304  UUVhQ2NnY5Rskt6UjCUkJ_DA
# 10      496000    26815549          164  UUQALLeQPoZdZC4JNUboVEUg
# 11      301000    13314176          223  UUEBpSZhI1X8WaP-kY_2LLcg
# 12     1040000    56232443          265  UUtYLUTtgS3k1Fg4y5tAhLbw
# 13      214000    13679412          303  UUHXa4OpASJEwrHrLeIzw7Yg
# 14       71500     2130348           64  UUDybamfye5An6p-j1t2YMsg
# 15       15100     9118566          675  UUSMqVwPTmerMiCaL_zKRjBw
# 16      101000     4119688          136  UUChmJrVa8kDg05JfCmxpLRw
# 17      207000    14183360           78  UUq6XkhO5SZ66N04IcPbqNcw
# 18      250000    13090245          100  UUnz-ZXXER4jOvuED5trXfEA
# 19        3760      191081           16  UUb5aI-GwJm3ZxlwtCsLu78Q
# 20      629000    26574606          262  UU7cs8q-gJRlGwj4A8OmCmXg
# 21       20900      290359          249  UUI8JpGrDmtggrryhml8kFGw
# 22        6440      288453           47  UUn1O_4_ApzbYwrsUdRoMmOg
# 23      101000     5695646          454  UUzL_0nIe8B4-7ShhVPfJkgw
# 24       18300      880630           49  UURqCK8izkO5xeVVtMKSHeRQ
# 25       27000     1423295           53  UUw_LFe2pS8x3NyipGNJgeEA
# 26       29200     1883561          155  UUPvDKIsrjA_h3g5yZJwCIHA
# 27      225000     7652655           78  UU1emV4A8liRs9p80CY8ElUQ
# 28      254000     8698465          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 29        6410       28427            9  UUSATlCAUi7R0Ik-wsZb2gOA
# 30       55300     3372500          539  UUJublDh2UsiIKsAE1553miw
# 31      260000    14887179           20  UUmMGlb7mGXYVthrXYSwlQhw
# 32      180000     9038366          114  UUteRPiisgIoHtMgqHegpWAQ
# 33          32        1278           34  UUWzIuRTyadYzg1-6OCejRMg
# 34        4800      203916           69  UU9LfrPNcIyHspci0t2W4T_w
# 35        5620      281639          144  UUHGw1uT1XmqaRm-6W15-KlQ

# %% [markdown]
# # Get Video IDs

# %% [markdown]
# #### Procuring Playlist IDs for each Channel

# %%
playlist_id_list = list(channel_stats_df['playlist_id'])

# %% [markdown]
# ## Function for Video IDs

# %%
def mass_video_ids(youtube, wanted_playlist_ids):

    all_data = []

    for id in wanted_playlist_ids:
        
        nextpage = True
        page = None

        while nextpage:
        # request for first page of playlist
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = id,
                maxResults=50,
                pageToken=page)
            # dictionary of the first page   
            response = request.execute()

        # Accessing videos ids on that first page
            for i in range(len(response['items'])):
                data = dict(playlist_id = id,
                    video_id = response['items'][i]['contentDetails']['videoId'])
                all_data.append(data)

            # Checking to see if there is a next page
            if 'nextPageToken' in response:
                page = response['nextPageToken']              

            else:
                nextpage = False
    # 
    all_data_df = pd.DataFrame(all_data)

    return all_data_df

# %% [markdown]
# ## Video IDs Dataframe

# %%
channel_video_df = mass_video_ids(youtube, playlist_id_list)
channel_video_df.head()
# Out:
#                 playlist_id     video_id
# 0  UUJQJAI7IjbLcpsjWdSzYz0Q  HKYULsQr_U0
# 1  UUJQJAI7IjbLcpsjWdSzYz0Q  fhFz0JfGvfc
# 2  UUJQJAI7IjbLcpsjWdSzYz0Q  lp6SfYCRGLM
# 3  UUJQJAI7IjbLcpsjWdSzYz0Q  uGynMyXCcg8
# 4  UUJQJAI7IjbLcpsjWdSzYz0Q  EzVIkHQWnhc

# %% [markdown]
# #### Checking Shape

# %%
channel_video_df.shape
# Out:
# (10752, 2)

# %% [markdown]
# #### Saving Dataframe

# %%
channel_stats_df.to_csv('channel_stats', index=False)

# %% [markdown]
# # What do we want from each video?

# %%
# Title (for NLP)
# Views
# Likes
# Tags
# Description
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']

# %% [markdown]
# # Function for Video Stats

# %% [markdown]
# #### Test Request

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="L5Cis5bOwgw")
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '5wzZKVtTxolxjU8wusoAjTWYfQo',
#  'items': [{'kind': 'youtube#video',
#    'etag': '5lvhPTuFLaFaGVV3L3fUQnG-iQ4',
#    'id': 'L5Cis5bOwgw',
#    'snippet': {'publishedAt': '2023-11-17T12:00:28Z',
#     'channelId': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#     'title': 'A Data Dream Come True',
#     'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Ken Jee',
#     'tags': ['Data Science',
#      'Ken Jee',
#      'Machine Learning',
#      'Sports Analytics',
#      'data scientist',
#      'data science journey',
#      'data science 2023'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'A Data Dream Come True',
#      'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT12M38S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1385',
#     'likeCount': '73',
#     'favoriteCount': '0',
#     'commentCount': '22'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# #### Finalised desired data pieces

# %%
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']

# %% [markdown]
# #### Testing Data Set of Video IDs

# %%
test_video_id_list = list(channel_video_df['video_id'])[:500]
print(len(test_video_id_list))
print(type(test_video_id_list))
# Out:
# 500
# <class 'list'>

# %% [markdown]
# #### Testing Results of Larger Requests

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=','.join(test_video_id_list))
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'oifKXVP5dnkjcJWaP05_CIG4Roc',
#  'items': [{'kind': 'youtube#video',
#    'etag': '_jXflgg-oFdveWtx_EhT8m--NlU',
#    'id': 'HKYULsQr_U0',
#    'snippet': {'publishedAt': '2023-11-12T17:06:48Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'Should You Still Learn to Code in 2024? #coding #datascience  #ai',
#     'description': '@Thuvu5',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HKYULsQr_U0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HKYULsQr_U0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HKYULsQr_U0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/HKYULsQr_U0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/HKYULsQr_U0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'Should You Still Learn to Code in 2024? #coding #datascience  #ai',
#      'description': '@Thuvu5'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT40S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '5157',
#     'likeCount': '240',
#     'favoriteCount': '0',
#     'commentCount': '8'}},
#   {'kind': 'youtube#video',
#    'etag': 'MKtaxMyG-55-9hIVuqeP5_Ef8t0',
#    'id': 'fhFz0JfGvfc',
#    'snippet': {'publishedAt': '2023-11-11T16:03:56Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'I Created a Custom GPT for Data Science Nerds 👩🏻\u200d💻',
#     'description': "Try out Data Dynamo 👉 https://chat.openai.com/g/g-tvkmLhaoL-data-dynamo\n(Note: Please don't share sensitive or personal data with this GPT!)\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:00 - Creat with GPT builder\n3:46 - Configuring GPT\n4:13 - Upload files as knowledge base\n5:27 - Add actions save to Google doc (Zapier AI Actions)\n10:25 - Sharing GPT\n10:36 - Outro & Final thoughts\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\n#gpt #ai #datascience #ThuVu #dataanalytics",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fhFz0JfGvfc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fhFz0JfGvfc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fhFz0JfGvfc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fhFz0JfGvfc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fhFz0JfGvfc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'I Created a Custom GPT for Data Science Nerds 👩🏻\u200d💻',
#      'description': "Try out Data Dynamo 👉 https://chat.openai.com/g/g-tvkmLhaoL-data-dynamo\n(Note: Please don't share sensitive or personal data with this GPT!)\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:00 - Creat with GPT builder\n3:46 - Configuring GPT\n4:13 - Upload files as knowledge base\n5:27 - Add actions save to Google doc (Zapier AI Actions)\n10:25 - Sharing GPT\n10:36 - Outro & Final thoughts\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\n#gpt #ai #datascience #ThuVu #dataanalytics"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT11M36S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '76780',
#     'likeCount': '1179',
#     'favoriteCount': '0',
#     'commentCount': '71'}},
#   {'kind': 'youtube#video',
#    'etag': 'UzEvrMITSRasRH47UFldR0yKVLo',
#    'id': 'lp6SfYCRGLM',
#    'snippet': {'publishedAt': '2023-10-16T22:03:49Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': "🤯 AI Is Taking Over Data Jobs: Here's What To Do About It",
#     'description': "📊 Curious about studying data analytics?\xa0🧭\xa0Try CareerFoundry's free\xa0short course: https://bit.ly/3QcWP7t \n👨\u200d💻 Ready for a career in data?\xa0Use my discount code and take 10% off CareerFoundry's Full Data Analytics program: https://bit.ly/46Mweod \n📞 Want to learn more about their programs?\xa0Book a free call with a program advisor: https://bit.ly/3LZwpo6 \n\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n0:39 - The skill gap - Learn to use AI\n3:25 - Learn data analytics with CareerFoundry (get 10% off)\n4:42 - The skill gap - Shine as humans!\n6:13 - Embrace continuous learning\n8:33 - Don’t put all your eggs in one basket\n10:10 - Your network is your net worth\n10:52 - Final thoughts\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#ai #datascience #ThuVu #dataanalytics",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lp6SfYCRGLM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lp6SfYCRGLM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lp6SfYCRGLM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lp6SfYCRGLM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/lp6SfYCRGLM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'r data analysis',
#      'vscode',
#      'artificial intelligence'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': "🤯 AI Is Taking Over Data Jobs: Here's What To Do About It",
#      'description': "📊 Curious about studying data analytics?\xa0🧭\xa0Try CareerFoundry's free\xa0short course: https://bit.ly/3QcWP7t \n👨\u200d💻 Ready for a career in data?\xa0Use my discount code and take 10% off CareerFoundry's Full Data Analytics program: https://bit.ly/46Mweod \n📞 Want to learn more about their programs?\xa0Book a free call with a program advisor: https://bit.ly/3LZwpo6 \n\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n0:39 - The skill gap - Learn to use AI\n3:25 - Learn data analytics with CareerFoundry (get 10% off)\n4:42 - The skill gap - Shine as humans!\n6:13 - Embrace continuous learning\n8:33 - Don’t put all your eggs in one basket\n10:10 - Your network is your net worth\n10:52 - Final thoughts\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#ai #datascience #ThuVu #dataanalytics"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT11M33S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '5699',
#     'likeCount': '355',
#     'favoriteCount': '0',
#     'commentCount': '30'}},
#   {'kind': 'youtube#video',
#    'etag': 'QgSEd8kYf0BpaP2Vdd4NFiargVU',
#    'id': 'uGynMyXCcg8',
#    'snippet': {'publishedAt': '2023-10-09T22:02:40Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': '📚 BEST AI Books to Read in 2023',
#     'description': 'Artificial Intelligence 👉 https://amzn.to/3tnhy0l\nThe Coming Wave 👉 https://amzn.to/45rDWTH\nLife 3.0 👉https://amzn.to/3FapEMs\nSuperintelligence 👉https://amzn.to/45iL7NW\nHuman Compatible 👉https://amzn.to/3tnhEFf\nThe Alignment Problem 👉https://amzn.to/3rIGajQ\nI, Human 👉https://amzn.to/48KBNoS\n\n#artificialintelligence #datascience #books',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uGynMyXCcg8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uGynMyXCcg8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uGynMyXCcg8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uGynMyXCcg8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uGynMyXCcg8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': '📚 BEST AI Books to Read in 2023',
#      'description': 'Artificial Intelligence 👉 https://amzn.to/3tnhy0l\nThe Coming Wave 👉 https://amzn.to/45rDWTH\nLife 3.0 👉https://amzn.to/3FapEMs\nSuperintelligence 👉https://amzn.to/45iL7NW\nHuman Compatible 👉https://amzn.to/3tnhEFf\nThe Alignment Problem 👉https://amzn.to/3rIGajQ\nI, Human 👉https://amzn.to/48KBNoS\n\n#artificialintelligence #datascience #books'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT59S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '7119',
#     'likeCount': '714',
#     'favoriteCount': '0',
#     'commentCount': '9'}},
#   {'kind': 'youtube#video',
#    'etag': 'SpCtpQDFD_OXM1LgQcKuFUtya2Y',
#    'id': 'EzVIkHQWnhc',
#    'snippet': {'publishedAt': '2023-08-22T00:29:27Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'Doing Data Analysis on Sensitive Data (ft. Oblivious)',
#     'description': '🏆 Check out Antigranular competition & win cash prizes up to €5,500  👉 https://www.antigranular.com/competitions\n📔 Sample notebook working with sensitive private data 👉 https://shorturl.at/yKX89\n\nHi everyone, in today\'s video we\'ll be talking about working with private and sensitive data. A lot of times data scientists do not work on the most valuable and "cool" datasets, simply because these datasets contain too sensitive individual information. I have encountered this many times at my work, and it\'s frustrating! In this video, I will give you a brief introduction to different techniques for handling senstive data, and how to implement them using Antigranular platform. \n\nThank you for watching! 😇\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:00 - Antigranular/ Oblivious (sponsor)\n1:22 - Overview of privacy-enhancing technologies\n4:28 - Antigranular & competition 🏆\n5:58 - What is Differential Privacy?\n6:51 - Sample notebook walkthrough\n7:49 - What is Secure Enclave?\n8:34 - Sample notebook walkthrough (cont.)\n11:07 - Training a regression model on private data\n11:46 - Outro\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET\'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#dataprivacy #datascience #ThuVu #dataanalytics',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EzVIkHQWnhc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EzVIkHQWnhc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EzVIkHQWnhc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/EzVIkHQWnhc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/EzVIkHQWnhc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'Doing Data Analysis on Sensitive Data (ft. Oblivious)',
#      'description': '🏆 Check out Antigranular competition & win cash prizes up to €5,500  👉 https://www.antigranular.com/competitions\n📔 Sample notebook working with sensitive private data 👉 https://shorturl.at/yKX89\n\nHi everyone, in today\'s video we\'ll be talking about working with private and sensitive data. A lot of times data scientists do not work on the most valuable and "cool" datasets, simply because these datasets contain too sensitive individual information. I have encountered this many times at my work, and it\'s frustrating! In this video, I will give you a brief introduction to different techniques for handling senstive data, and how to implement them using Antigranular platform. \n\nThank you for watching! 😇\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:00 - Antigranular/ Oblivious (sponsor)\n1:22 - Overview of privacy-enhancing technologies\n4:28 - Antigranular & competition 🏆\n5:58 - What is Differential Privacy?\n6:51 - Sample notebook walkthrough\n7:49 - What is Secure Enclave?\n8:34 - Sample notebook walkthrough (cont.)\n11:07 - Training a regression model on private data\n11:46 - Outro\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET\'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#dataprivacy #datascience #ThuVu #dataanalytics'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT12M19S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '5338',
#     'likeCount': '263',
#     'favoriteCount': '0',
#     'commentCount': '30'}},
#   {'kind': 'youtube#video',
#    'etag': 'DwlQLVSj8u1h4sYHCO9V6UAr5lk',
#    'id': '8sLq4P-QDL0',
#    'snippet': {'publishedAt': '2023-07-15T19:02:17Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': "I Tried ChatGPT Code Interpreter for Data Tasks - it's a game changer!",
#     'description': 'I tell ChatGPT Code Interpreter to do my job 😅\n\n\nDATA SCIENCE COURSES:\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n\n#shorts',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8sLq4P-QDL0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8sLq4P-QDL0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8sLq4P-QDL0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/8sLq4P-QDL0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/8sLq4P-QDL0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': "I Tried ChatGPT Code Interpreter for Data Tasks - it's a game changer!",
#      'description': 'I tell ChatGPT Code Interpreter to do my job 😅\n\n\nDATA SCIENCE COURSES:\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n\n#shorts'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '37052',
#     'likeCount': '1747',
#     'favoriteCount': '0',
#     'commentCount': '56'}},
#   {'kind': 'youtube#video',
#    'etag': '9UDwILVKWf1fb8QkCq3reaxDvZ0',
#    'id': '3736Pd_hwFQ',
#    'snippet': {'publishedAt': '2023-07-08T09:45:30Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'Become a PRO with These 40 Data science Productivity Tips',
#     'description': "📩 Interested in hearing about my coming courses? 👉 https://forms.gle/u4h9fLmbxjQHHScb9\n📚 Glimpse into R data.table 👉 https://bookdown.org/brianjmpark/everydayR/interlude-i-a-brief-glimpse-into-data.html\n\nHi everyone 👋! In this video I demonstrated 40 tips to help you become more proficient in day-to-day data science tools such as Jupyter notebooks, VS Code, Python, R and RStudio, and Excel! It's definitely the longest video I have ever made and took me tons of time, but hopefully it will give you some useful tips, no matter if you are a novice or a seasoned data analyst/ data scientist.\n\nThank you for watching and have a great day! 🤗\n\n🔑 TIMESTAMPS\n================================\n\nTips for Jupyter notebooks:\n00:00 Intro\n00:48 Jupyter Notebooks\n00:50 - #1 Use JupyterLab/ VS Code (instead of Notebook)\n2:44 - #2 Useful shortcuts in notebooks\n7:44 - #3 Add an image to notebooks\n8:36 - #4 Move around quickly\n10:04 - #5 Multi-cursors\n11:16 - #6 Code completion\n11:41 - #7 Debugging in JupyterLab\n19:45 - #8 Magics\n23:07 - #9 Timeit magic\n24:40 - #10 Writing formulas in notebook cells\n\nTips for Python:\n25:46 - Python\n25:58 - #11 Chaining comparisons\n26:31 - #12 Using f-strings\n27:32 - #13 List comprehensions\n29:12 - #14 Creating Python virtual environments\n30:47 - #15 Creating and using requirements.txt file\n32:39 - #16 Python libraries for profiling reports\n33:38 - #17 Highlighting pandas tables\n35:17 - #18 Type hinting\n\nTips for Visual Studio Code:\n37:14 - VS Code\n37:30 - #19 Opening project folders VS Code\n39:07 - #20 Using code completion VS Code\n39:43 - #21 Useful shortcuts in VS Code\n42:32 - #22 Running Python scripts interactively in VS Code\n43:55 - #23 Debugging in VS Code\n\nTips for RStudio (sorry I accidentally had double #27 here 😅)\n46:07 - RStudio\n46:23 - #24 Shortcuts in RStudio\n47:11 - #25 Find function definition in RStudio\n48:48 - #26 Creating R projects\n50:08 - #27 Debugging in RStudio\n51:20 - #27 The most useful package in R 😉\n52:31 - #28 Data profiling in R\n54:16 - #29 Parallelizing code in R (doParallel package)\n\nTips for Excel:\n59:16 - Excel\n59:41 - #30 Customising status bar in Excel\n1:00:24 - #31 Using Analyze Data tool in Excel\n1:02:48 - #32 Using Excel table\n1:05:24 - #33 Creating slicers for Excel reports\n1:06:28 - #34 Keyboard shortcuts in Excel\n1:07:48 - #35 Typing headers quickly in Excel \n1:08:27 - #36 Doing statistical analyses in Excel\n1:09:52 - #37 Filling blank values in Excel\n1:10:43 - #38 Conditional formatting in Excel\n1:12:00 - #39 Recording custom Excel macros\n1:15:15 Conclusion\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#python #datascience #productivity",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3736Pd_hwFQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3736Pd_hwFQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3736Pd_hwFQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/3736Pd_hwFQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/3736Pd_hwFQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'Become a PRO with These 40 Data science Productivity Tips',
#      'description': "📩 Interested in hearing about my coming courses? 👉 https://forms.gle/u4h9fLmbxjQHHScb9\n📚 Glimpse into R data.table 👉 https://bookdown.org/brianjmpark/everydayR/interlude-i-a-brief-glimpse-into-data.html\n\nHi everyone 👋! In this video I demonstrated 40 tips to help you become more proficient in day-to-day data science tools such as Jupyter notebooks, VS Code, Python, R and RStudio, and Excel! It's definitely the longest video I have ever made and took me tons of time, but hopefully it will give you some useful tips, no matter if you are a novice or a seasoned data analyst/ data scientist.\n\nThank you for watching and have a great day! 🤗\n\n🔑 TIMESTAMPS\n================================\n\nTips for Jupyter notebooks:\n00:00 Intro\n00:48 Jupyter Notebooks\n00:50 - #1 Use JupyterLab/ VS Code (instead of Notebook)\n2:44 - #2 Useful shortcuts in notebooks\n7:44 - #3 Add an image to notebooks\n8:36 - #4 Move around quickly\n10:04 - #5 Multi-cursors\n11:16 - #6 Code completion\n11:41 - #7 Debugging in JupyterLab\n19:45 - #8 Magics\n23:07 - #9 Timeit magic\n24:40 - #10 Writing formulas in notebook cells\n\nTips for Python:\n25:46 - Python\n25:58 - #11 Chaining comparisons\n26:31 - #12 Using f-strings\n27:32 - #13 List comprehensions\n29:12 - #14 Creating Python virtual environments\n30:47 - #15 Creating and using requirements.txt file\n32:39 - #16 Python libraries for profiling reports\n33:38 - #17 Highlighting pandas tables\n35:17 - #18 Type hinting\n\nTips for Visual Studio Code:\n37:14 - VS Code\n37:30 - #19 Opening project folders VS Code\n39:07 - #20 Using code completion VS Code\n39:43 - #21 Useful shortcuts in VS Code\n42:32 - #22 Running Python scripts interactively in VS Code\n43:55 - #23 Debugging in VS Code\n\nTips for RStudio (sorry I accidentally had double #27 here 😅)\n46:07 - RStudio\n46:23 - #24 Shortcuts in RStudio\n47:11 - #25 Find function definition in RStudio\n48:48 - #26 Creating R projects\n50:08 - #27 Debugging in RStudio\n51:20 - #27 The most useful package in R 😉\n52:31 - #28 Data profiling in R\n54:16 - #29 Parallelizing code in R (doParallel package)\n\nTips for Excel:\n59:16 - Excel\n59:41 - #30 Customising status bar in Excel\n1:00:24 - #31 Using Analyze Data tool in Excel\n1:02:48 - #32 Using Excel table\n1:05:24 - #33 Creating slicers for Excel reports\n1:06:28 - #34 Keyboard shortcuts in Excel\n1:07:48 - #35 Typing headers quickly in Excel \n1:08:27 - #36 Doing statistical analyses in Excel\n1:09:52 - #37 Filling blank values in Excel\n1:10:43 - #38 Conditional formatting in Excel\n1:12:00 - #39 Recording custom Excel macros\n1:15:15 Conclusion\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#python #datascience #productivity"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT1H16M9S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '13123',
#     'likeCount': '674',
#     'favoriteCount': '0',
#     'commentCount': '63'}},
#   {'kind': 'youtube#video',
#    'etag': 'AXZ1lWtrTZws4BThcuvUoyGXXos',
#    'id': 'PvnSSrnjLX8',
#    'snippet': {'publishedAt': '2023-06-16T22:57:31Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': "Self-taught vs. Guided Program: CareerFoundry's Data Analytics Program Review",
#     'description': "📊 Enroll with this link to get 10% off the Data Analytics Program (CareerFoundry) until the end of the year! https://bit.ly/46itfni\n📞 Not sure whether a career in Data Analytics is the right choice for you? Book a call with a\nProgram Advisor to get their personalized advice: https://bit.ly/3G5w0Of\n🖥 Want to know what it's like to be a Data Analyst? Check out CareerFoundry's free short course! https://bit.ly/3lZL6Oj\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:17 - What is CareerFoundry\n1:42 - Overview of program structure\n3:02 - Job guarantees\n4:23 - Mentorship\n5:59 - Detailed curriculum\n8:05 - Learning portal and course walkthrough\n10:47 - What I like and don't like\n12:45 - Price\n15:18 - Who I'd recommend this course to\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#datanalytics #datascience #ThuVu",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PvnSSrnjLX8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PvnSSrnjLX8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PvnSSrnjLX8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PvnSSrnjLX8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PvnSSrnjLX8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': "Self-taught vs. Guided Program: CareerFoundry's Data Analytics Program Review",
#      'description': "📊 Enroll with this link to get 10% off the Data Analytics Program (CareerFoundry) until the end of the year! https://bit.ly/46itfni\n📞 Not sure whether a career in Data Analytics is the right choice for you? Book a call with a\nProgram Advisor to get their personalized advice: https://bit.ly/3G5w0Of\n🖥 Want to know what it's like to be a Data Analyst? Check out CareerFoundry's free short course! https://bit.ly/3lZL6Oj\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n1:17 - What is CareerFoundry\n1:42 - Overview of program structure\n3:02 - Job guarantees\n4:23 - Mentorship\n5:59 - Detailed curriculum\n8:05 - Learning portal and course walkthrough\n10:47 - What I like and don't like\n12:45 - Price\n15:18 - Who I'd recommend this course to\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#datanalytics #datascience #ThuVu"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT16M32S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '7736',
#     'likeCount': '235',
#     'favoriteCount': '0',
#     'commentCount': '33'}},
#   {'kind': 'youtube#video',
#    'etag': 'UvD2tSBHdk1pfp-Wv5SGgIM9mIo',
#    'id': 'S5U76LPu_bQ',
#    'snippet': {'publishedAt': '2023-06-08T16:10:11Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'Is a Computer Science Degree WORTHLESS 🤯? (in the age of AI)',
#     'description': "I've been thinking lately if it's still worth it to pursue my Computer Science degree, given that AI is changing our jobs and lives at a neckbreaking speed. Hope this video is helpful for some of you who are asking yourselves the same question! Thank you for watching 😇.\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#computerscience #ai #ThuVu #dataanalytics",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/S5U76LPu_bQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/S5U76LPu_bQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/S5U76LPu_bQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/S5U76LPu_bQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/S5U76LPu_bQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'Is a Computer Science Degree WORTHLESS 🤯? (in the age of AI)',
#      'description': "I've been thinking lately if it's still worth it to pursue my Computer Science degree, given that AI is changing our jobs and lives at a neckbreaking speed. Hope this video is helpful for some of you who are asking yourselves the same question! Thank you for watching 😇.\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Google Advanced Data Analytics Certificate 👉 https://imp.i384100.net/anK9zZ\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\nEdited with Gling: https://gling.ai\n#computerscience #ai #ThuVu #dataanalytics"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT11M8S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '20072',
#     'likeCount': '684',
#     'favoriteCount': '0',
#     'commentCount': '58'}},
#   {'kind': 'youtube#video',
#    'etag': 'GS6hDmay8HwUO5fDkKMhINYszoo',
#    'id': 'l2YU8QuXiTM',
#    'snippet': {'publishedAt': '2023-05-28T14:33:38Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'ChatGPT + Jupyter Notebook = Mindblowing! 🤩',
# ...
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qdzuq_o8-dI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/qdzuq_o8-dI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/qdzuq_o8-dI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': '👩🏻\u200d💻 Why Macbook M1 Pro 2021 is the BEST laptop for Data Science',
#      'description': "👩🏻\u200d💻 My Macbook (Amazon): https://t.ly/x20C\n\nMacbook M1 Pro 14'' is here!! I have used this laptop for 3 months now and it has been really great! In this video, I'll break down (in a nerdy way) some core factors that affect computers' performance and why I think this Macbook is great for data science. This is definitely not a comprehensive discussion about computer specs. It was a lot of rambling but hope you enjoyed it and found it helpful! Thank you for watching! 👋 \n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n0:51 - My experience with performance\n3:28 - What matters for performance & Why M1 Pro is good ;)\n8:48 - Aesthetics\n9:23 - Convenience \n10:25 - Limitations\n\n#MacbookM1Pro #DataScience #Datanerd #DataAnalysis #CoffeeData #ThuVu #dataanalytics"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT11M45S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '64893',
#     'likeCount': '1659',
#     'favoriteCount': '0',
#     'commentCount': '172'}},
#   {'kind': 'youtube#video',
#    'etag': 'fKCxaUY-yMj4tNW5goMq_V4mKAg',
#    'id': 'eiZbEcMX3b4',
#    'snippet': {'publishedAt': '2022-03-18T21:32:41Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'How I come up with Data Project IDEAS 💡',
#     'description': 'Hello, data junkies! In today\'s video, I will talk about how I come up with personal data projects to develop different data skills. I feel like this topic is not talked about often enough. For those of you who are new to data science and still exploring and learning new things, I think personal projects are a fantastic way to learn new skills at your own pace and develop an interesting data portfolio to prepare you for a data science role. I\'m curious which projects you will come up with for yourself! Let me know in the comment below. Thank you for watching! 👋 \n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET\'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n0:18 - 2 ways of getting projects\n0:57 - Projects from hobbies\n3:50 - Solving daily problems\n5:35 - Inspired by your interests/ expertise\n6:20 - "Stealing like an artist"\n8:25 - How I capture ideas & keep track of progress\n9:05 - How to start and keep going\n\n================================\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on some of the links above.  It costs you nothing but helps me with content creation.\n\n#DataScience #Datanerd #DataAnalysis #CoffeeData #ThuVu #dataanalytics',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eiZbEcMX3b4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eiZbEcMX3b4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eiZbEcMX3b4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/eiZbEcMX3b4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/eiZbEcMX3b4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode',
#      'How to data portfolio',
#      'Portfolio projects',
#      'Data portfolio'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'How I come up with Data Project IDEAS 💡',
#      'description': 'Hello, data junkies! In today\'s video, I will talk about how I come up with personal data projects to develop different data skills. I feel like this topic is not talked about often enough. For those of you who are new to data science and still exploring and learning new things, I think personal projects are a fantastic way to learn new skills at your own pace and develop an interesting data portfolio to prepare you for a data science role. I\'m curious which projects you will come up with for yourself! Let me know in the comment below. Thank you for watching! 👋 \n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET\'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro\n0:18 - 2 ways of getting projects\n0:57 - Projects from hobbies\n3:50 - Solving daily problems\n5:35 - Inspired by your interests/ expertise\n6:20 - "Stealing like an artist"\n8:25 - How I capture ideas & keep track of progress\n9:05 - How to start and keep going\n\n================================\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on some of the links above.  It costs you nothing but helps me with content creation.\n\n#DataScience #Datanerd #DataAnalysis #CoffeeData #ThuVu #dataanalytics'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT9M58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '37953',
#     'likeCount': '2233',
#     'favoriteCount': '0',
#     'commentCount': '165'}},
#   {'kind': 'youtube#video',
#    'etag': 'Q3WbFuVUCK4SUZnLuu0K22unuAY',
#    'id': 'uhxiXOTKzfs',
#    'snippet': {'publishedAt': '2022-03-10T01:32:41Z',
#     'channelId': 'UCJQJAI7IjbLcpsjWdSzYz0Q',
#     'title': 'How to Create a Beautiful Python Visualization Dashboard With Panel/Hvplot',
#     'description': "Hello lovely nerds! In today's video, I will show you how to create a beautiful (I think 🙈) data visualization dashboard in Python from your Jupyter Notebooks. I had a lot of fun doing this project and I hope you will have fun watching it as well. I'm so sorry for my stuffy-nose voice today (my hay fever season just started 🤦🏻\u200d♀️), but I hope you can still hear me clearly. Let me know in the comment if you found this project useful! Thank you for watching! 👋 \n\n🔑 Github repo for this project: \nhttps://github.com/thu-vu92/python-dashboard-panel\n\n🔍 More on panel and hvplot packages:\nhttps://panel.holoviz.org/\nhttps://hvplot.holoviz.org/user_guide/Introduction.html\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro to project\n0:33 - Dataset & choosing tools\n1:50 - Intro to Panel package\n2:24 - Project set-up\n4:35 - Visualization ideation\n5:46 - Coding the dashboard \n10:06 - Serving dashboard\n\n#dataviz DataScience #Datanerd #DataAnalysis #CoffeeData #ThuVu #dataanalytics",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uhxiXOTKzfs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uhxiXOTKzfs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uhxiXOTKzfs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/uhxiXOTKzfs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/uhxiXOTKzfs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Thu Vu data analytics',
#     'tags': ['data analytics',
#      'data science',
#      'python',
#      'data',
#      'tableau',
#      'bi',
#      'programming',
#      'technology',
#      'coding',
#      'data visualization',
#      'python tutorial',
#      'data analyst',
#      'data scientist',
#      'data analysis',
#      'power bi',
#      'python data anlysis',
#      'data nerd',
#      'big data',
#      'learn to code',
#      'business intelligence',
#      'how to use r',
#      'r data analysis',
#      'vscode',
#      'Data portfolio',
#      'How to data portfolio'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'How to Create a Beautiful Python Visualization Dashboard With Panel/Hvplot',
#      'description': "Hello lovely nerds! In today's video, I will show you how to create a beautiful (I think 🙈) data visualization dashboard in Python from your Jupyter Notebooks. I had a lot of fun doing this project and I hope you will have fun watching it as well. I'm so sorry for my stuffy-nose voice today (my hay fever season just started 🤦🏻\u200d♀️), but I hope you can still hear me clearly. Let me know in the comment if you found this project useful! Thank you for watching! 👋 \n\n🔑 Github repo for this project: \nhttps://github.com/thu-vu92/python-dashboard-panel\n\n🔍 More on panel and hvplot packages:\nhttps://panel.holoviz.org/\nhttps://hvplot.holoviz.org/user_guide/Introduction.html\n\n👩🏻\u200d💻 COURSES & RESOURCES\n================================\n📖 Learn SQL Basics for Data Science Specialization 👉 https://imp.i384100.net/AovPnJ\n📖 Excel Skills for Business 👉 https://coursera.pxf.io/doPaoy\n📖 Machine Learning Specialization 👉 https://imp.i384100.net/RyjykN\n📖 Data Visualization with Tableau Specialization 👉https://imp.i384100.net/n15XWR\n📖 Deep Learning Specialization 👉 https://imp.i384100.net/zavBA0\n📖 Mathematics for Machine Learning and Data Science Specialization 👉 https://imp.i384100.net/LXK0gj\n📖 Google Data Analytics Certificate 👉 https://imp.i384100.net/15v9y6\n📖 Applied Data Science with Python 👉 https://imp.i384100.net/gbxOqv\n\n🙋🏻\u200d♀️ LET'S CONNECT!\n================================\n🤓 Join my Discord server: https://discord.gg/SK7ZC5XhcS\n📩  Newsletter: https://substack.com/profile/87689887-thu-vu\n✍ Medium: https://medium.com/@vuthihienthu.ueb\n🔗 All links: https://linktr.ee/thuvuanalytics\n\nAs a member of the Amazon and Coursera Affiliate Programs, I earn a commission from qualifying purchases on the links above. By using the links you help support this channel at no cost for you.\n\n\n🔑 TIMESTAMPS\n================================\n0:00 - Intro to project\n0:33 - Dataset & choosing tools\n1:50 - Intro to Panel package\n2:24 - Project set-up\n4:35 - Visualization ideation\n5:46 - Coding the dashboard \n10:06 - Serving dashboard\n\n#dataviz DataScience #Datanerd #DataAnalysis #CoffeeData #ThuVu #dataanalytics"},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT10M57S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '472900',
#     'likeCount': '19552',
#     'favoriteCount': '0',
#     'commentCount': '555'}}],
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50}}

# %% [markdown]
# ## Final Video Stats Function

# %%
def get_video_stats(youtube, list_of_video_ids):

    all_data = []

    # Will only return 50 results at a time, this for loop will do 50 Video IDs at a time
    for i in range(0, len(list_of_video_ids), 50):     

        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(list_of_video_ids[i:i+50]))

        response = request.execute()

        for video in response['items']:
  
            data = dict(channel_id = video['snippet']['channelId'],
                        video_id = video['id'],
                        published_at = video['snippet']['publishedAt'],
                        title = video['snippet']['title'],
                        description = video['snippet']['description'],
                        tags = video['snippet'].get('tags', []), # was issue here as not all videos had tags, .get() might generally offer better protection
                        category_id = video['snippet']['categoryId'],
                        duration = video['contentDetails']['duration'],
                        caption = video['contentDetails']['caption'],
                        licensed_content = video['contentDetails']['licensedContent'],
                        content_rating = video['contentDetails']['contentRating'],
                        view_count = video['statistics']['viewCount'],
                        like_count = video['statistics']['likeCount'],
                        favourite_count = video['statistics']['favoriteCount'],
                        comment_count = video['statistics']['commentCount'])

            all_data.append(data)

    return all_data

# %%
video_stats = get_video_stats(youtube, test_video_id_list)

# %% [markdown]
# ## Test Video Stats Dataframe

# %%
video_stats_df = pd.DataFrame(video_stats)
video_stats_df
# Out:
#                    channel_id     video_id          published_at  \
# 0    UCJQJAI7IjbLcpsjWdSzYz0Q  HKYULsQr_U0  2023-11-12T17:06:48Z
# 1    UCJQJAI7IjbLcpsjWdSzYz0Q  fhFz0JfGvfc  2023-11-11T16:03:56Z
# 2    UCJQJAI7IjbLcpsjWdSzYz0Q  lp6SfYCRGLM  2023-10-16T22:03:49Z
# 3    UCJQJAI7IjbLcpsjWdSzYz0Q  uGynMyXCcg8  2023-10-09T22:02:40Z
# 4    UCJQJAI7IjbLcpsjWdSzYz0Q  EzVIkHQWnhc  2023-08-22T00:29:27Z
# ..                        ...          ...                   ...
# 495  UC79Gv3mYp6zKiSwYemEik9A  jMXZT5jgudQ  2023-11-20T12:15:03Z
# 496  UC79Gv3mYp6zKiSwYemEik9A  Zav-V3xwUkY  2023-11-20T10:14:35Z
# 497  UC79Gv3mYp6zKiSwYemEik9A  Pb_RGAl75VE  2023-11-18T05:30:59Z
# 498  UC79Gv3mYp6zKiSwYemEik9A  SmSoTa5eRZA  2023-11-17T05:14:06Z
# 499  UC79Gv3mYp6zKiSwYemEik9A  SxJqyatlmTs  2023-11-16T05:06:43Z
#
#                                                  title  \
# 0    Should You Still Learn to Code in 2024? #codin...
# 1    I Created a Custom GPT for Data Science Nerds ...
# 2    🤯 AI Is Taking Over Data Jobs: Here's What To ...
# 3                      📚 BEST AI Books to Read in 2023
# 4    Doing Data Analysis on Sensitive Data (ft. Obl...
# ..                                                 ...
# 495  The Data Democratization Stack (with Lilac Sch...
# 496  #164 Driving Data Democratization with Lilac S...
# 497                 Fine-Tuning Your Own Llama 2 Model
# 498           Revolutionizing Decision Making using AI
# 499      GPT-4 Turbo, Custom GPTs & the Assistants API
#
#                                            description  \
# 0                                              @Thuvu5
# 1    Try out Data Dynamo 👉 https://chat.openai.com/...
# 2    📊 Curious about studying data analytics? 🧭 Try...
# 3    Artificial Intelligence 👉 https://amzn.to/3tnh...
# 4    🏆 Check out Antigranular competition & win cas...
# ..                                                 ...
# 495  Lilac Schoenbeck shares what to focus on when ...
# 496  The consequences of data not being easily acce...
# 497  The advent of large language models has taken ...
# 498  An average adult makes 35,000 decisions in a d...
# 499  At OpenAI Dev Day, OpenAI announced a host of ...
#
#                                                   tags category_id  \
# 0    [data analytics, data science, python, data, t...          22
# 1    [data analytics, data science, python, data, t...          22
# 2    [data analytics, data science, python, data, p...          22
# 3    [data analytics, data science, python, data, t...          22
# 4    [data analytics, data science, python, data, t...          22
# ..                                                 ...         ...
# 495                                                 []          24
# 496                                                 []          24
# 497                                                 []          24
# 498                                                 []          24
# 499                                                 []          24
#
#        duration caption  licensed_content content_rating view_count  \
# 0         PT40S   false              True             {}       5157
# 1      PT11M36S   false              True             {}      76781
# 2      PT11M33S   false              True             {}       5699
# 3         PT59S   false              True             {}       7119
# 4      PT12M19S   false              True             {}       5338
# ..          ...     ...               ...            ...        ...
# 495     PT4M45S   false             False             {}         86
# 496    PT48M46S   false             False             {}         83
# 497  PT1H22M46S   false             False             {}        681
# 498   PT1H8M22S   false             False             {}        454
# 499   PT1H2M16S   false             False             {}       1117
#
#     like_count favourite_count comment_count
# 0          240               0             8
# 1         1179               0            71
# 2          355               0            30
# 3          714               0             9
# 4          263               0            30
# ..         ...             ...           ...
# 495          1               0             0
# 496          1               0             0
# 497         36               0             0
# 498         23               0             0
# 499         40               0             0
#
# [500 rows x 15 columns]

# %%
len(video_stats)
# Out:
# 500

# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %% [markdown]
# # API Key

# %%
# api key AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8

# %% [markdown]
# # Configuring YouTube Connection

# %%
api_key = 'AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # List of Wanted Channel's IDs

# %%
channel_ids = ['UCEBpSZhI1X8WaP-kY_2LLcg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCzL_0nIe8B4-7ShhVPfJkgw',
               'UC79Gv3mYp6zKiSwYemEik9A',
               'UCV8e2g4IWQqK71bbzGDEI4Q',
               'UCtYLUTtgS3k1Fg4y5tAhLbw',
               'UC7cs8q-gJRlGwj4A8OmCmXg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCnz-ZXXER4jOvuED5trXfEA',
               'UCteRPiisgIoHtMgqHegpWAQ',
               'UCSMqVwPTmerMiCaL_zKRjBw',
               'UCJublDh2UsiIKsAE1553miw',
               'UCvZnwzmc3m1Eush-Or8Z6DA',
               'UCNU_lfiiWBdtULKOw6X0Dig',
               'UCRqCK8izkO5xeVVtMKSHeRQ',
               'UC9LfrPNcIyHspci0t2W4T_w',
               'UCJQJAI7IjbLcpsjWdSzYz0Q',
               'UCaGe6wVIAymH17HKO8kjQsw',
               'UCWzIuRTyadYzg1-6OCejRMg',
               'UCHXa4OpASJEwrHrLeIzw7Yg',
               'UCb5aI-GwJm3ZxlwtCsLu78Q',
               'UCHGw1uT1XmqaRm-6W15-KlQ',
               'UCmMGlb7mGXYVthrXYSwlQhw',
               'UCQALLeQPoZdZC4JNUboVEUg',
               'UCSATlCAUi7R0Ik-wsZb2gOA',
               'UC1emV4A8liRs9p80CY8ElUQ',
               'UCDybamfye5An6p-j1t2YMsg',
               'UCVhQ2NnY5Rskt6UjCUkJ_DA',
               'UCq6XkhO5SZ66N04IcPbqNcw',
               'UCn1O_4_ApzbYwrsUdRoMmOg',
               'UCUIBKDoSSwehuDK4jk1CjFQ',
               'UCw_LFe2pS8x3NyipGNJgeEA',
               'UCPvDKIsrjA_h3g5yZJwCIHA',
               'UCObs0kLIrDjX2LLSybqNaEA',
               'UCChmJrVa8kDg05JfCmxpLRw',
               'UCup-fnSNRaByeuXOWqfnykw',
               'UCI8JpGrDmtggrryhml8kFGw']

# %% [markdown]
# # Function to Gather Channel Information

# %%
def get_channel_stats(youtube, channel_id):
    
    all_data = []
    
    request = youtube.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %% [markdown]
# # Channel Stats Dataframe

# %%
channel_stats_df = pd.DataFrame(channel_stats)
channel_stats_df
# Out:
#                             channel_name                channel_id  \
# 0                   freeCodeCamp Español  UC1emV4A8liRs9p80CY8ElUQ
# 1                      Data Science Dojo  UCzL_0nIe8B4-7ShhVPfJkgw
# 2                     Shashank Kalanithi  UCvZnwzmc3m1Eush-Or8Z6DA
# 3                        Study with Tina  UCI8JpGrDmtggrryhml8kFGw
# 4           Data Science for High School  UCWzIuRTyadYzg1-6OCejRMg
# 5                      Time Out With Tim  UCSATlCAUi7R0Ik-wsZb2gOA
# 6            StatQuest with Josh Starmer  UCtYLUTtgS3k1Fg4y5tAhLbw
# 7                         Great Learning  UCObs0kLIrDjX2LLSybqNaEA
# 8                    Data Science Basics  UCHGw1uT1XmqaRm-6W15-KlQ
# 9                              Jon Krohn  UCup-fnSNRaByeuXOWqfnykw
# 10                               Ken Jee  UCiT9RITQ9PW6BhXK0y2jaeg
# 11                           Keith Galli  UCq6XkhO5SZ66N04IcPbqNcw
# 12                               Dataiku  UCSMqVwPTmerMiCaL_zKRjBw
# ...

# %% [markdown]
# # Get Video IDs

# %% [markdown]
# #### Procuring Playlist IDs for each Channel

# %%
playlist_id_list = list(channel_stats_df['playlist_id'])

# %% [markdown]
# ## Function for Video IDs

# %%
def mass_video_ids(youtube, wanted_playlist_ids):

    all_data = []

    for id in wanted_playlist_ids:
        
        nextpage = True
        page = None

        while nextpage:
        # request for first page of playlist
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = id,
                maxResults=50,
                pageToken=page)
            # dictionary of the first page   
            response = request.execute()

        # Accessing videos ids on that first page
            for i in range(len(response['items'])):
                data = dict(playlist_id = id,
                    video_id = response['items'][i]['contentDetails']['videoId'])
                all_data.append(data)

            # Checking to see if there is a next page
            if 'nextPageToken' in response:
                page = response['nextPageToken']              

            else:
                nextpage = False
    # 
    all_data_df = pd.DataFrame(all_data)

    return all_data_df

# %% [markdown]
# ## Video IDs Dataframe

# %%
channel_video_df = mass_video_ids(youtube, playlist_id_list)
channel_video_df.head()
# Out:
#                 playlist_id     video_id
# 0  UU1emV4A8liRs9p80CY8ElUQ  v8Evfd6AFpw
# 1  UU1emV4A8liRs9p80CY8ElUQ  drXkf_rytRs
# 2  UU1emV4A8liRs9p80CY8ElUQ  yKi9-BfbfzQ
# 3  UU1emV4A8liRs9p80CY8ElUQ  koiPxFFiqJ4
# 4  UU1emV4A8liRs9p80CY8ElUQ  mBYSUUnMt9M

# %% [markdown]
# #### Checking Shape

# %%
channel_video_df.shape
# Out:
# (10768, 2)

# %% [markdown]
# #### Saving Dataframe

# %%
channel_stats_df.to_csv('channel_stats', index=False)

# %% [markdown]
# # What do we want from each video?

# %%
# Title (for NLP)
# Views
# Likes
# Tags
# Description
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']
# Out:
# ['id',
#  'publishedAt',
#  'channelId',
#  'title',
#  'description',
#  'tags',
#  'categoryId',
#  'defaultLanguage',
#  'duration',
#  'caption',
#  'licensedContent',
#  'contentRating',
#  'viewCount',
#  'likeCount',
#  'favoriteCount',
#  'commentCount']

# %% [markdown]
# # Function for Video Stats

# %% [markdown]
# #### Test Request

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="L5Cis5bOwgw")
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'SROSHiNTeoIBCkLTCBcvR-RKu7A',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'i2ANaY46bVYVy77GRW7-Ytz7cO0',
#    'id': 'L5Cis5bOwgw',
#    'snippet': {'publishedAt': '2023-11-17T12:00:28Z',
#     'channelId': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#     'title': 'A Data Dream Come True',
# ...

# %% [markdown]
# #### Finalised desired data pieces

# %%
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']
# Out:
# ['id',
#  'publishedAt',
#  'channelId',
#  'title',
#  'description',
#  'tags',
#  'categoryId',
#  'defaultLanguage',
#  'duration',
#  'caption',
#  'licensedContent',
#  'contentRating',
#  'viewCount',
#  'likeCount',
#  'favoriteCount',
#  'commentCount']

# %% [markdown]
# #### Testing Data Set of Video IDs

# %%
test_video_id_list = list(channel_video_df['video_id'])[:500]
print(len(test_video_id_list))
print(type(test_video_id_list))
# Out:
# 500
# <class 'list'>

# %% [markdown]
# #### Testing Results of Larger Requests

# %%
# request = youtube.videos().list(
#         part="snippet,contentDetails,statistics",
#         id=','.join(test_video_id_list))
# response = request.execute()
# response
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# c:\Users\lawre\Documents\GitHub\YouTube-Analytics\Channel_Stats.ipynb Cell 35 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> request = youtube.videos().list(
#       <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a>         part="snippet,contentDetails,statistics",
#       <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a>         id=','.join(test_video_id_list))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X46sZmlsZQ%3D%3D?line=3'>4</a> response = request.execute()
# ...

# %% [markdown]
# ## Final Video Stats Function

# %%
def get_video_stats(youtube, list_of_video_ids):

    all_data = []

    # Will only return 50 results at a time, this for loop will do 50 Video IDs at a time
    for i in range(0, len(list_of_video_ids), 50):     

        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(list_of_video_ids[i:i+50]))

        response = request.execute()

        for video in response['items']:
  
            data = dict(channel_id = video['snippet']['channelId'],
                        video_id = video['id'],
                        published_at = video['snippet'].get('publishedAt'),
                        title = video['snippet'].get('title'),
                        description = video['snippet'].get('description'),
                        tags = video['snippet'].get('tags', []), # was issue here as not all videos had tags, .get() might generally offer better protection
                        category_id = video['snippet'].get('categoryId'),
                        duration = video['contentDetails'].get('duration'),
                        caption = video['contentDetails'].get('caption'),
                        licensed_content = video['contentDetails'].get('licensedContent'),
                        content_rating = video['contentDetails'].get('contentRating'),
                        view_count = video['statistics'].get('viewCount'),
                        like_count = video['statistics'].get('likeCount'), # issue 
                        favourite_count = video['statistics'].get('favoriteCount'),
                        comment_count = video['statistics'].get('commentCount'))

            all_data.append(data)

    return all_data

# %%
video_stats = get_video_stats(youtube, test_video_id_list)

# %% [markdown]
# ## Test Video Stats Dataframe

# %%
video_stats_df = pd.DataFrame(video_stats)
video_stats_df
# Out:
#                    channel_id     video_id          published_at  \
# 0    UCJQJAI7IjbLcpsjWdSzYz0Q  HKYULsQr_U0  2023-11-12T17:06:48Z
# 1    UCJQJAI7IjbLcpsjWdSzYz0Q  fhFz0JfGvfc  2023-11-11T16:03:56Z
# 2    UCJQJAI7IjbLcpsjWdSzYz0Q  lp6SfYCRGLM  2023-10-16T22:03:49Z
# 3    UCJQJAI7IjbLcpsjWdSzYz0Q  uGynMyXCcg8  2023-10-09T22:02:40Z
# 4    UCJQJAI7IjbLcpsjWdSzYz0Q  EzVIkHQWnhc  2023-08-22T00:29:27Z
# ..                        ...          ...                   ...
# 495  UC79Gv3mYp6zKiSwYemEik9A  jMXZT5jgudQ  2023-11-20T12:15:03Z
# 496  UC79Gv3mYp6zKiSwYemEik9A  Zav-V3xwUkY  2023-11-20T10:14:35Z
# 497  UC79Gv3mYp6zKiSwYemEik9A  Pb_RGAl75VE  2023-11-18T05:30:59Z
# 498  UC79Gv3mYp6zKiSwYemEik9A  SmSoTa5eRZA  2023-11-17T05:14:06Z
# 499  UC79Gv3mYp6zKiSwYemEik9A  SxJqyatlmTs  2023-11-16T05:06:43Z
#
#                                                  title  \
# 0    Should You Still Learn to Code in 2024? #codin...
# 1    I Created a Custom GPT for Data Science Nerds ...
# ...

# %%
len(video_stats)
# Out:
# 500

# %% [markdown]
# # Full Video Database

# %% [markdown]
# #### Tasks
#
# - Get full Database
# - Combine with channel stats
# - Duration mapping
# - Category mapping
# - Published date format
# - Like Ratio new column?
# - Tags format OHE?
# - Has Tags/Doesn't have tags column
# - Description word count
# - Title word count

# %%
video_id_list = list(channel_video_df['video_id'])
print(len(video_id_list))
print(type(video_id_list))
# Out:
# 10768
# <class 'list'>

# %%
full_video_stats = get_video_stats(youtube, video_id_list)
full_video_stats_df = pd.DataFrame(full_video_stats)
full_video_stats_df
# Out:
#                      channel_id     video_id          published_at  \
# 0      UC1emV4A8liRs9p80CY8ElUQ  v8Evfd6AFpw  2023-11-08T12:25:45Z
# 1      UC1emV4A8liRs9p80CY8ElUQ  drXkf_rytRs  2023-09-06T11:41:13Z
# 2      UC1emV4A8liRs9p80CY8ElUQ  yKi9-BfbfzQ  2023-08-15T12:13:02Z
# 3      UC1emV4A8liRs9p80CY8ElUQ  koiPxFFiqJ4  2023-06-19T11:30:19Z
# 4      UC1emV4A8liRs9p80CY8ElUQ  mBYSUUnMt9M  2023-02-09T13:52:39Z
# ...                         ...          ...                   ...
# 10763  UC9LfrPNcIyHspci0t2W4T_w  lys6-be36f8  2017-07-18T20:54:43Z
# 10764  UC9LfrPNcIyHspci0t2W4T_w  DGtJAJUIxXw  2017-06-04T12:45:04Z
# 10765  UC9LfrPNcIyHspci0t2W4T_w  WcZqmu9CdXk  2017-03-23T00:29:16Z
# 10766  UC9LfrPNcIyHspci0t2W4T_w  1vBbTD4xJ1Y  2017-03-16T16:02:30Z
# 10767  UC9LfrPNcIyHspci0t2W4T_w  _GedQybWp2k  2017-02-08T13:14:04Z
#
#                                                    title  \
# 0      Curso de JavaScript desde Cero - Aprende JavaS...
# ...

# %% [markdown]
# # Full Complete Database

# %%
full_df = full_video_stats_df.join(channel_stats_df, on='channel_id')
full_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lawre\Documents\GitHub\YouTube-Analytics\Channel_Stats.ipynb Cell 47 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> full_df = full_video_stats_df.join(channel_stats_df, on='channel_id')
#       <a href='vscode-notebook-cell:/c%3A/Users/lawre/Documents/GitHub/YouTube-Analytics/Channel_Stats.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> full_df
#
# File c:\Users\lawre\anaconda3\lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
# ...

# %%
full_df = pd.merge(full_video_stats_df, channel_stats_df, on='channel_id', how='left')
full_df.tail()
# Out:
#                      channel_id     video_id          published_at  \
# 10763  UC9LfrPNcIyHspci0t2W4T_w  lys6-be36f8  2017-07-18T20:54:43Z
# 10764  UC9LfrPNcIyHspci0t2W4T_w  DGtJAJUIxXw  2017-06-04T12:45:04Z
# 10765  UC9LfrPNcIyHspci0t2W4T_w  WcZqmu9CdXk  2017-03-23T00:29:16Z
# 10766  UC9LfrPNcIyHspci0t2W4T_w  1vBbTD4xJ1Y  2017-03-16T16:02:30Z
# 10767  UC9LfrPNcIyHspci0t2W4T_w  _GedQybWp2k  2017-02-08T13:14:04Z
#
#                                                    title  \
# 10763  0101 WELCOME TO THE COURSE | Data Science and ...
# 10764  How to import a 7M+ rows data set into Postgre...
# 10765  Data + Coding in Bash - episode 4 - Best Pract...
# 10766  Conversion Rate Optimization Framework ||| Tom...
# 10767                 Print a data file in Bash with Cat
#
#                                              description  \
# 10763  This video is part of my video course at O'Rei...
# 10764  Continue with my SQL tutorial vids: https://ww...
# ...

# %%
full_df.to_csv('full_df', index=False)

# %% [markdown]
# # Youtube Categories

# %%
request = youtube.videoCategories().list(
        part="snippet",
        id="22")
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': 'fjjURLufs-ZQ351B8xY7itlOqtA',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': 'cHDaaqPDZsJT1FPr1-MwtyIhR28',
#    'id': '22',
#    'snippet': {'title': 'People & Blogs',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}]}

# %%
category_ids = full_df['category_id'].unique()
print(len(category_ids))
# Out:
# 12

# %%
def get_categories(youtube, wanted_categories):

    all_data = []
    
    request = youtube.videoCategories().list(part='snippet', id=','.join(category_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(category_id = response['items'][i]['id'],
                category= response['items'][i]['snippet']['title'])
        all_data.append(data)

    return all_data

# %%
category_dict = get_categories(youtube, category_ids)
print(category_dict)
# Out:
# [{'category_id': '1', 'category': 'Film & Animation'}, {'category_id': '2', 'category': 'Autos & Vehicles'}, {'category_id': '10', 'category': 'Music'}, {'category_id': '17', 'category': 'Sports'}, {'category_id': '19', 'category': 'Travel & Events'}, {'category_id': '20', 'category': 'Gaming'}, {'category_id': '22', 'category': 'People & Blogs'}, {'category_id': '23', 'category': 'Comedy'}, {'category_id': '24', 'category': 'Entertainment'}, {'category_id': '26', 'category': 'Howto & Style'}, {'category_id': '27', 'category': 'Education'}, {'category_id': '28', 'category': 'Science & Technology'}]

# %%
category_df = pd.DataFrame(category_dict)
category_df
# Out:
#    category_id              category
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           17                Sports
# 4           19       Travel & Events
# 5           20                Gaming
# 6           22        People & Blogs
# 7           23                Comedy
# 8           24         Entertainment
# 9           26         Howto & Style
# 10          27             Education
# 11          28  Science & Technology

# %%
full_df_v2 = pd.merge(full_df, category_df, on='category_id', how='left')
full_df_v2
# Out:
#                      channel_id     video_id          published_at  \
# 0      UC1emV4A8liRs9p80CY8ElUQ  v8Evfd6AFpw  2023-11-08T12:25:45Z
# 1      UC1emV4A8liRs9p80CY8ElUQ  drXkf_rytRs  2023-09-06T11:41:13Z
# 2      UC1emV4A8liRs9p80CY8ElUQ  yKi9-BfbfzQ  2023-08-15T12:13:02Z
# 3      UC1emV4A8liRs9p80CY8ElUQ  koiPxFFiqJ4  2023-06-19T11:30:19Z
# 4      UC1emV4A8liRs9p80CY8ElUQ  mBYSUUnMt9M  2023-02-09T13:52:39Z
# ...                         ...          ...                   ...
# 10763  UC9LfrPNcIyHspci0t2W4T_w  lys6-be36f8  2017-07-18T20:54:43Z
# 10764  UC9LfrPNcIyHspci0t2W4T_w  DGtJAJUIxXw  2017-06-04T12:45:04Z
# 10765  UC9LfrPNcIyHspci0t2W4T_w  WcZqmu9CdXk  2017-03-23T00:29:16Z
# 10766  UC9LfrPNcIyHspci0t2W4T_w  1vBbTD4xJ1Y  2017-03-16T16:02:30Z
# 10767  UC9LfrPNcIyHspci0t2W4T_w  _GedQybWp2k  2017-02-08T13:14:04Z
#
#                                                    title  \
# 0      Curso de JavaScript desde Cero - Aprende JavaS...
# ...

# %%
full_df_v2['caption'].unique()
full_df_v2['caption'].value_counts()
# Out:
# false    9589
# true     1179
# Name: caption, dtype: int64

# %%
full_df_v2['licensed_content'].unique()
full_df_v2['licensed_content'].value_counts()
# Out:
# True     5523
# False    5245
# Name: licensed_content, dtype: int64

# %%
full_df_v2.to_csv('full_df.csv', index=False)

# %%
full_df_v2.describe()
# Out:
#                       channel_id     video_id          published_at  \
# count                      10768        10768                 10768
# unique                        36        10768                 10675
# top     UCObs0kLIrDjX2LLSybqNaEA  v8Evfd6AFpw  2019-03-08T22:34:17Z
# freq                        1854            1                    15
#
#                                                     title description   tags  \
# count                                               10768       10768  10768
# unique                                              10402        9537   7518
# top     study with me LIVE (2 hours) #accountability 🐈...                 []
# freq                                                   83         156   1624
#
#        category_id duration caption licensed_content  ... view_count  \
# count        10768    10768   10768            10768  ...      10768
# unique          12     3746       2                2  ...       8093
# ...

# %%
full_df_v2.columns
# Out:
# Index(['channel_id', 'video_id', 'published_at', 'title', 'description',
#        'tags', 'category_id', 'duration', 'caption', 'licensed_content',
#        'content_rating', 'view_count', 'like_count', 'favourite_count',
#        'comment_count', 'channel_name', 'subscribers', 'total_views',
#        'total_videos', 'playlist_id', 'category'],
#       dtype='object')

# %%
full_df_v2['content_rating'].value_counts()
# Out:
# {}    10768
# Name: content_rating, dtype: int64

# %%
print(full_df_v2['content_rating'].explode().unique())
# Out:
# [nan]

# %% [markdown]
# # Duration Cleaning

# %% [markdown]
# #### Removing 'PT' from duration column

# %%
full_df_v2['duration'] = full_df_v2['duration'].str.replace('PT', '')

# %% [markdown]
# #### Conversion Function

# %%
from datetime import timedelta

# create function to format duration column
def format_duration(time_string):

    # store hours, minutes, seconds as integers
    H = 0
    M = 0
    S = 0

    # check if vid time contains hours, minutes and/or seconds
    if 'H' in time_string:
        H += int(time_string.split('H')[0])
    if 'M' in time_string:
        M += int(time_string.split('M')[0].split('H')[-1])
    if 'S' in time_string:
        S += int(time_string.split('S')[0].split('M')[-1].split('H')[-1])
    
    formatted_time = timedelta(hours=H, minutes=M, seconds=S)

    return formatted_time

# %%
full_df_v2['duration_formatted'] = full_df_v2['duration'].apply(format_duration)
full_df_v2
# Out:
#                      channel_id     video_id          published_at  \
# 0      UC1emV4A8liRs9p80CY8ElUQ  v8Evfd6AFpw  2023-11-08T12:25:45Z
# 1      UC1emV4A8liRs9p80CY8ElUQ  drXkf_rytRs  2023-09-06T11:41:13Z
# 2      UC1emV4A8liRs9p80CY8ElUQ  yKi9-BfbfzQ  2023-08-15T12:13:02Z
# 3      UC1emV4A8liRs9p80CY8ElUQ  koiPxFFiqJ4  2023-06-19T11:30:19Z
# 4      UC1emV4A8liRs9p80CY8ElUQ  mBYSUUnMt9M  2023-02-09T13:52:39Z
# ...                         ...          ...                   ...
# 10763  UC9LfrPNcIyHspci0t2W4T_w  lys6-be36f8  2017-07-18T20:54:43Z
# 10764  UC9LfrPNcIyHspci0t2W4T_w  DGtJAJUIxXw  2017-06-04T12:45:04Z
# 10765  UC9LfrPNcIyHspci0t2W4T_w  WcZqmu9CdXk  2017-03-23T00:29:16Z
# 10766  UC9LfrPNcIyHspci0t2W4T_w  1vBbTD4xJ1Y  2017-03-16T16:02:30Z
# 10767  UC9LfrPNcIyHspci0t2W4T_w  _GedQybWp2k  2017-02-08T13:14:04Z
#
#                                                    title  \
# 0      Curso de JavaScript desde Cero - Aprende JavaS...
# ...

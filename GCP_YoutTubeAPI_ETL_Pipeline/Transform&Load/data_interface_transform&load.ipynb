# %% [markdown]
# # Importing Libraries

# %%
# Importing Packages
import pandas as pd
from google.cloud import storage
import os
from dotenv import load_dotenv
import io
from googleapiclient.discovery import build
from datetime import timedelta, datetime
import datetime
import io

# %%
load_dotenv()

api_key = os.getenv('API_KEY')

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# Variables
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
bucket_name = os.getenv('BUCKET_NAME')
folder_path = os.getenv('FOLDER_PATH')
project_name = os.getenv('PROJECT_NAME')
running_data_folder = os.getenv('RUNNING_DATA_FOLDER')
client = storage.Client()
blobs = client.list_blobs(bucket_name, prefix=folder_path)

# %%
def get_channel_stats(youtube_key, channel_ids):

    all_data = []

    request = youtube_key.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))

    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    channel_stats_df = pd.DataFrame(all_data)

    return channel_stats_df

# %%
def database_creator(data, days):

    # Filter by requested days

    filter_list = list(data[data['Day'] == int(days)]['video_id'])
    filtered_df = data[data['video_id'].isin(filter_list)]
    filtered_df = filtered_df[filtered_df['Day'] <= int(days)]

    # Flip
    filtered_df['Day'] = 'Day' + filtered_df['Day'].astype(str)
    df_pivoted = filtered_df.pivot_table(index='video_id', columns='Day', values=['view_count', 'like_count', 'comment_count'],
                                         aggfunc='first', fill_value=0).reset_index()

    columns_to_keep = ['video_id', 'channel_id', 'title', 'description', 'tags', 'caption',
        'licensed_content','category', 'duration_formatted',
        'no_of_tags', 'title_length', 'description_length',
        'published_at_formatted', 'extraction_date_formatted']
    df_unique_ids = filtered_df[columns_to_keep].copy()

    df_unique_ids.drop_duplicates(subset='video_id', keep='first', inplace=True)

    df_unique_ids.reset_index(drop=True, inplace=True)

    # Merge with the original DataFrame to include other information
    result_df = df_pivoted.merge(df_unique_ids, on='video_id', how='left')
    result_df.drop(columns=[('video_id', '')], inplace=True)


    # get list of channel ids of the videos
    channel_ids_list = list(set(result_df['channel_id']))
    
    # get channel stats dataframe
    channel_df = get_channel_stats(youtube, channel_ids_list)

    # merge final dataframe
    final_df = pd.merge(result_df, channel_df, on='channel_id', how='left')

    return final_df

# %%
def get_running_df():

    bucket = client.get_bucket(bucket_name)
    blob = bucket.blob('YouTube_Running_Data/running_youtube_video_data.csv')
    running_csv = blob.download_as_string()
    running_df = pd.read_csv(io.BytesIO(running_csv), encoding='utf-8')

    return running_df

# %%
def interface_function():
    
    days = input('How many days data would you like? ')

    df = get_running_df()

    new_df = database_creator(df, days)

    return new_df

# %%
# adjust display options to show all columns
pd.set_option('display.max_columns', None)

# %%
database = interface_function() # tested function to return videos that have data across 3 days
database
# Out:
# C:\Users\mms\AppData\Local\Temp\ipykernel_9516\1895171874.py:25: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (2 levels on the left, 1 on the right)
#   result_df = df_pivoted.merge(df_unique_ids, on='video_id', how='left')
#         video_id  (comment_count, Day1)  (comment_count, Day2)  \
# 0    -4xVbmIzGfE                     31                     40
# 1    -PAq8nh5txE                     37                     43
# 2    -Tv1T40Kypw                      8                     16
# 3    -f1o7i0ExhM                     10                     19
# 4    -ny5_RSMV6k                     37                     47
# ..           ...                    ...                    ...
# 303  z4u_fts6yfE                      0                      0
# 304  zNPrifp7djc                      0                      0
# 305  zT-cc1IblsQ                     12                     14
# 306  zee_QlhO1kQ                      0                      0
# 307  zs1i2rh8Skk                     20                     30
#
#      (comment_count, Day3)  (like_count, Day1)  (like_count, Day2)  \
# 0                       47                1026                1463
# 1                       46                 680                 762
# 2                       16                  24                  50
# 3                       22                 626                1065
# 4                       52                 458                 551
# ..                     ...                 ...                 ...
# 303                      0                   2                   3
# 304                      0                   0                   0
# 305                     14                 192                 279
# 306                      0                   1                   2
# 307                     47                 758                1401
#
#      (like_count, Day3)  (view_count, Day1)  (view_count, Day2)  \
# 0                  1767               14035               22114
# 1                   820               17862               21191
# 2                    59                 306                 927
# 3                  1303                6644               13297
# 4                   591                6256                8328
# ..                  ...                 ...                 ...
# 303                   3                  58                  74
# 304                   0                   0                   0
# 305                 296                3546               11346
# 306                   4                   0                   0
# 307                1789                8122               17755
#
#      (view_count, Day3)                channel_id  \
# 0                 29240  UCJublDh2UsiIKsAE1553miw
# 1                 23918  UCNU_lfiiWBdtULKOw6X0Dig
# 2                  1145  UCw_LFe2pS8x3NyipGNJgeEA
# 3                 16866  UCJublDh2UsiIKsAE1553miw
# 4                  9082  UCNU_lfiiWBdtULKOw6X0Dig
# ..                  ...                       ...
# 303                  72  UC79Gv3mYp6zKiSwYemEik9A
# 304                   0  UC79Gv3mYp6zKiSwYemEik9A
# 305               14669  UCNU_lfiiWBdtULKOw6X0Dig
# 306                   0  UC79Gv3mYp6zKiSwYemEik9A
# 307               26810  UCJublDh2UsiIKsAE1553miw
#
#                                                  title  \
# 0    Very Common FAANG Interview Question! | Index ...
# 1    In this Mass Layoff Becoming Recession proof-I...
# 2             DataCamp Review - Is It Worth It? (2024)
# 3    VERY COMMON FAANG INTERVIEW QUESTION | Leetcod...
# 4    End To End Multi Language Invoice Extractor Pr...
# ..                                                 ...
# 303  #178 Making SMARTER Decisions with Lori Silver...
# 304  Get Started Analyzing Survey Data with SQL & P...
# 305  Complete MLOPS Platform To Build LLMs Applicat...
# 306                Data & AI Trends & Predictions 2024
# 307  I HATE This Coding Question, but FAANG Loves i...
#
#                                            description  \
# 0    dynamic programming, leetcode, coding intervie...
# 1                             Becoming Recession proof
# 2    👉Try DataCamp for free:\nhttps://bit.ly/3HWXK8...
# 3    dynamic programming, leetcode, coding intervie...
# 4    Join me in this exciting video as we develop a...
# ..                                                 ...
# 303  We don’t think about every decision we make. S...
# 304                                                NaN
# 305  PostgresML is a complete MLOps platform in a P...
# 306                                                NaN
# 307  dynamic programming, leetcode, coding intervie...
#
#                                                   tags  caption  \
# 0    ['leetcode', 'coding interview question', 'dat...    False
# 1                                                   []    False
# 2    ['data science', 'data analytics', 'data analy...    False
# 3    ['leetcode', 'coding interview question', 'dat...    False
# 4    ['yt:cc=on', 'machine learnign tutorials', 'in...    False
# ..                                                 ...      ...
# 303  ['podcast', 'data', 'ai', 'dataframed', 'lori ...    False
# 304                                                 []    False
# 305  ['yt::cc=on', 'postgresml', 'postgresml tutori...    False
# 306                                                 []    False
# 307  ['leetcode', 'coding interview question', 'dat...    False
#
#      licensed_content              category duration_formatted  no_of_tags  \
# 0                True             Education    0 days 00:00:55          26
# 1                True             Education    0 days 00:03:54           2
# 2                True  Science & Technology    0 days 00:07:49          31
# 3                True             Education    0 days 00:00:58          26
# 4                True             Education    0 days 00:25:59          28
# ..                ...                   ...                ...         ...
# 303             False         Entertainment    0 days 01:07:45          24
# 304             False         Entertainment    0 days 00:00:00           2
# 305              True             Education    0 days 00:17:37          25
# 306             False         Entertainment    0 days 00:00:00           2
# 307              True             Education    0 days 00:00:58          26
#
#      title_length  description_length published_at_formatted  \
# 0              95                 112    2024-02-03 02:30:00
# 1              61                  24    2024-02-03 02:47:19
# 2              40                 383    2024-02-09 18:17:35
# 3              67                 112    2024-01-23 12:25:48
# 4              90                2414    2023-12-27 04:41:32
# ..            ...                 ...                    ...
# 303            94                3271    2024-02-01 09:58:37
# 304            51                   0    2024-01-16 12:38:53
# 305            94                2086    2023-12-18 14:51:44
# 306            35                   0    2024-01-08 12:00:11
# 307            82                 112    2024-01-26 11:31:02
#
#     extraction_date_formatted      channel_name subscribers total_views  \
# 0         2024-02-03 23:00:46         Greg Hogg       85600     9407006
# 1         2024-02-03 23:00:46        Krish Naik      888000    90296973
# 2         2024-02-09 23:00:46  Learn with Lukas       33600     1886454
# 3         2024-01-23 23:00:42         Greg Hogg       85600     9407006
# 4         2023-12-27 23:00:42        Krish Naik      888000    90296973
# ..                        ...               ...         ...         ...
# 303       2024-02-01 23:00:45          DataCamp      158000    24138315
# 304       2024-01-16 23:00:41          DataCamp      158000    24138315
# 305       2023-12-18 23:00:52        Krish Naik      888000    90296973
# 306       2024-01-08 23:00:54          DataCamp      158000    24138315
# 307       2024-01-26 23:00:44         Greg Hogg       85600     9407006
#
#     total_videos               playlist_id
# 0            640  UUJublDh2UsiIKsAE1553miw
# 1           1813  UUNU_lfiiWBdtULKOw6X0Dig
# 2             74  UUw_LFe2pS8x3NyipGNJgeEA
# 3            640  UUJublDh2UsiIKsAE1553miw
# 4           1813  UUNU_lfiiWBdtULKOw6X0Dig
# ..           ...                       ...
# 303         1582  UU79Gv3mYp6zKiSwYemEik9A
# 304         1582  UU79Gv3mYp6zKiSwYemEik9A
# 305         1813  UUNU_lfiiWBdtULKOw6X0Dig
# 306         1582  UU79Gv3mYp6zKiSwYemEik9A
# 307          640  UUJublDh2UsiIKsAE1553miw
#
# [308 rows x 28 columns]

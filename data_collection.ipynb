# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %% [markdown]
# # API Key

# %%
# api key AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8

# %% [markdown]
# # Configuring YouTube Connection

# %%
api_key = 'AIzaSyBAobEQD70yA3gEWGjeZxGfyvvlwvMDsr8'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # List of Wanted Channel's IDs

# %%
channel_ids = ['UCEBpSZhI1X8WaP-kY_2LLcg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCzL_0nIe8B4-7ShhVPfJkgw',
               'UC79Gv3mYp6zKiSwYemEik9A',
               'UCV8e2g4IWQqK71bbzGDEI4Q',
               'UCtYLUTtgS3k1Fg4y5tAhLbw',
               'UC7cs8q-gJRlGwj4A8OmCmXg',
               'UCiT9RITQ9PW6BhXK0y2jaeg',
               'UCnz-ZXXER4jOvuED5trXfEA',
               'UCteRPiisgIoHtMgqHegpWAQ',
               'UCSMqVwPTmerMiCaL_zKRjBw',
               'UCJublDh2UsiIKsAE1553miw',
               'UCvZnwzmc3m1Eush-Or8Z6DA',
               'UCNU_lfiiWBdtULKOw6X0Dig',
               'UCRqCK8izkO5xeVVtMKSHeRQ',
               'UC9LfrPNcIyHspci0t2W4T_w',
               'UCJQJAI7IjbLcpsjWdSzYz0Q',
               'UCaGe6wVIAymH17HKO8kjQsw',
               'UCWzIuRTyadYzg1-6OCejRMg',
               'UCHXa4OpASJEwrHrLeIzw7Yg',
               'UCb5aI-GwJm3ZxlwtCsLu78Q',
               'UCHGw1uT1XmqaRm-6W15-KlQ',
               'UCmMGlb7mGXYVthrXYSwlQhw',
               'UCQALLeQPoZdZC4JNUboVEUg',
               'UCSATlCAUi7R0Ik-wsZb2gOA',
               'UC1emV4A8liRs9p80CY8ElUQ',
               'UCDybamfye5An6p-j1t2YMsg',
               'UCVhQ2NnY5Rskt6UjCUkJ_DA',
               'UCq6XkhO5SZ66N04IcPbqNcw',
               'UCn1O_4_ApzbYwrsUdRoMmOg',
               'UCUIBKDoSSwehuDK4jk1CjFQ',
               'UCw_LFe2pS8x3NyipGNJgeEA',
               'UCPvDKIsrjA_h3g5yZJwCIHA',
               'UCObs0kLIrDjX2LLSybqNaEA',
               'UCChmJrVa8kDg05JfCmxpLRw',
               'UCup-fnSNRaByeuXOWqfnykw',
               'UCI8JpGrDmtggrryhml8kFGw']

# %% [markdown]
# # Function to Gather Channel Information

# %%
def get_channel_stats(youtube, channel_id):
    
    all_data = []
    
    request = youtube.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %% [markdown]
# # Channel Stats Dataframe

# %%
channel_stats_df = pd.DataFrame(channel_stats)
channel_stats_df
# Out:
#                             channel_name                channel_id  \
# 0                                Ken Jee  UCiT9RITQ9PW6BhXK0y2jaeg
# 1                         Great Learning  UCObs0kLIrDjX2LLSybqNaEA
# 2                         Darshil Parmar  UCChmJrVa8kDg05JfCmxpLRw
# 3                          luke barousse  UCaGe6wVIAymH17HKO8kjQsw
# 4                             ArjanCodes  UCVhQ2NnY5Rskt6UjCUkJ_DA
# 5                       Alex The Analyst  UC7cs8q-gJRlGwj4A8OmCmXg
# 6                           Tech Classes  UCPvDKIsrjA_h3g5yZJwCIHA
# 7                             Krish Naik  UCNU_lfiiWBdtULKOw6X0Dig
# 8                     Shashank Kalanithi  UCvZnwzmc3m1Eush-Or8Z6DA
# 9                                Dataiku  UCSMqVwPTmerMiCaL_zKRjBw
# 10                         Sundas Khalid  UCteRPiisgIoHtMgqHegpWAQ
# 11                   Data Science Basics  UCHGw1uT1XmqaRm-6W15-KlQ
# 12                             Jon Krohn  UCup-fnSNRaByeuXOWqfnykw
# 13                        Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q
# 14                               Jabrils  UCQALLeQPoZdZC4JNUboVEUg
# 15                              DataCamp  UC79Gv3mYp6zKiSwYemEik9A
# 16                               techTFQ  UCnz-ZXXER4jOvuED5trXfEA
# 17          Data Science for High School  UCWzIuRTyadYzg1-6OCejRMg
# 18                      Nicholas Renotte  UCHXa4OpASJEwrHrLeIzw7Yg
# 19                      Learn with Lukas  UCw_LFe2pS8x3NyipGNJgeEA
# 20                 Thu Vu data analytics  UCJQJAI7IjbLcpsjWdSzYz0Q
# 21                     Data Science Dojo  UCzL_0nIe8B4-7ShhVPfJkgw
# 22                  freeCodeCamp Español  UC1emV4A8liRs9p80CY8ElUQ
# 23                             Data Nash  UCRqCK8izkO5xeVVtMKSHeRQ
# 24                     Time Out With Tim  UCSATlCAUi7R0Ik-wsZb2gOA
# 25                           Keith Galli  UCq6XkhO5SZ66N04IcPbqNcw
# 26                           Joma in NYC  UCmMGlb7mGXYVthrXYSwlQhw
# 27                         Andy McDonald  UCn1O_4_ApzbYwrsUdRoMmOg
# 28                      365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg
# 29                       Study with Tina  UCI8JpGrDmtggrryhml8kFGw
# 30                          Data With Mo  UCDybamfye5An6p-j1t2YMsg
# 31                Rocketing Data Science  UCUIBKDoSSwehuDK4jk1CjFQ
# 32  Data36 - Online Data Science Courses  UC9LfrPNcIyHspci0t2W4T_w
# 33           StatQuest with Josh Starmer  UCtYLUTtgS3k1Fg4y5tAhLbw
# 34                             Greg Hogg  UCJublDh2UsiIKsAE1553miw
# 35       Tom Henry - data science with R  UCb5aI-GwJm3ZxlwtCsLu78Q
#
#    subscribers total_views total_videos               playlist_id
# 0       254000     8708402          285  UUiT9RITQ9PW6BhXK0y2jaeg
# 1       807000    62826895         1853  UUObs0kLIrDjX2LLSybqNaEA
# 2       102000     4194962          137  UUChmJrVa8kDg05JfCmxpLRw
# 3          356        3992            9  UUaGe6wVIAymH17HKO8kjQsw
# 4       206000    14071553          305  UUVhQ2NnY5Rskt6UjCUkJ_DA
# 5       633000    26791198          264  UU7cs8q-gJRlGwj4A8OmCmXg
# 6        29400     1899669          155  UUPvDKIsrjA_h3g5yZJwCIHA
# 7       842000    85147365         1744  UUNU_lfiiWBdtULKOw6X0Dig
# 8       139000     6500329          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 9        15100     9124710          675  UUSMqVwPTmerMiCaL_zKRjBw
# 10      181000     9105765          114  UUteRPiisgIoHtMgqHegpWAQ
# 11        5710      287371          147  UUHGw1uT1XmqaRm-6W15-KlQ
# 12       18500      702066          143  UUup-fnSNRaByeuXOWqfnykw
# 13      169000     5401232          323  UUV8e2g4IWQqK71bbzGDEI4Q
# 14      496000    26822743          164  UUQALLeQPoZdZC4JNUboVEUg
# 15      154000    22746900         1516  UU79Gv3mYp6zKiSwYemEik9A
# 16      252000    13190849          100  UUnz-ZXXER4jOvuED5trXfEA
# 17          32        1318           34  UUWzIuRTyadYzg1-6OCejRMg
# 18      216000    13801218          303  UUHXa4OpASJEwrHrLeIzw7Yg
# 19       27500     1462060           54  UUw_LFe2pS8x3NyipGNJgeEA
# 20      174000     5818634           79  UUJQJAI7IjbLcpsjWdSzYz0Q
# 21      101000     5706352          453  UUzL_0nIe8B4-7ShhVPfJkgw
# 22      225000     7710050           79  UU1emV4A8liRs9p80CY8ElUQ
# 23       18600      890542           50  UURqCK8izkO5xeVVtMKSHeRQ
# 24        6410       28438            9  UUSATlCAUi7R0Ik-wsZb2gOA
# 25      208000    14217381           79  UUq6XkhO5SZ66N04IcPbqNcw
# 26      260000    14897599           20  UUmMGlb7mGXYVthrXYSwlQhw
# 27        6490      292704           47  UUn1O_4_ApzbYwrsUdRoMmOg
# 28      302000    13342371          223  UUEBpSZhI1X8WaP-kY_2LLcg
# 29       20900      290589          249  UUI8JpGrDmtggrryhml8kFGw
# 30       72700     2175337           65  UUDybamfye5An6p-j1t2YMsg
# 31        1770      157494           88  UUUIBKDoSSwehuDK4jk1CjFQ
# 32        4810      204504           69  UU9LfrPNcIyHspci0t2W4T_w
# 33     1040000    56515535          265  UUtYLUTtgS3k1Fg4y5tAhLbw
# 34       55900     3444777          546  UUJublDh2UsiIKsAE1553miw
# 35        3760      191499           16  UUb5aI-GwJm3ZxlwtCsLu78Q

# %% [markdown]
# # Get Video IDs

# %% [markdown]
# #### Procuring Playlist IDs for each Channel

# %%
playlist_id_list = list(channel_stats_df['playlist_id'])

# %% [markdown]
# ## Function for Video IDs

# %%
def mass_video_ids(youtube, wanted_playlist_ids):

    all_data = []

    for id in wanted_playlist_ids:
        
        nextpage = True
        page = None

        while nextpage:
        # request for first page of playlist
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = id,
                maxResults=50,
                pageToken=page)
            # dictionary of the first page   
            response = request.execute()

        # Accessing videos ids on that first page
            for i in range(len(response['items'])):
                data = dict(playlist_id = id,
                    video_id = response['items'][i]['contentDetails']['videoId'])
                all_data.append(data)

            # Checking to see if there is a next page
            if 'nextPageToken' in response:
                page = response['nextPageToken']              

            else:
                nextpage = False
    # 
    all_data_df = pd.DataFrame(all_data)

    return all_data_df

# %% [markdown]
# ## Video IDs Dataframe

# %%
channel_video_df = mass_video_ids(youtube, playlist_id_list)
channel_video_df.head()
# Out:
#                 playlist_id     video_id
# 0  UUiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw
# 1  UUiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges
# 2  UUiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I
# 3  UUiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI
# 4  UUiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI

# %% [markdown]
# #### Checking Shape

# %%
channel_video_df.shape
# Out:
# (10776, 2)

# %% [markdown]
# #### Saving Dataframe

# %%
channel_stats_df.to_csv('channel_stats.csv', index=False)

# %% [markdown]
# # What do we want from each video?

# %%
# Title (for NLP)
# Views
# Likes
# Tags
# Description
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']
# Out:
# ['id',
#  'publishedAt',
#  'channelId',
#  'title',
#  'description',
#  'tags',
#  'categoryId',
#  'defaultLanguage',
#  'duration',
#  'caption',
#  'licensedContent',
#  'contentRating',
#  'viewCount',
#  'likeCount',
#  'favoriteCount',
#  'commentCount']

# %% [markdown]
# # Function for Video Stats

# %% [markdown]
# #### Test Request

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="L5Cis5bOwgw")
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'YPz88QBN6sGO1fSSc1atQFO0_oo',
#  'items': [{'kind': 'youtube#video',
#    'etag': '-woAXkzR7cExykUyDGUGLQH59PM',
#    'id': 'L5Cis5bOwgw',
#    'snippet': {'publishedAt': '2023-11-17T12:00:28Z',
#     'channelId': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#     'title': 'A Data Dream Come True',
#     'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/L5Cis5bOwgw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Ken Jee',
#     'tags': ['Data Science',
#      'Ken Jee',
#      'Machine Learning',
#      'Sports Analytics',
#      'data scientist',
#      'data science journey',
#      'data science 2023'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'A Data Dream Come True',
#      'description': '#datascience  #KenJee \nI gave up on my dream of playing professional golf 10 years ago. Recently, I had the opportunity to relive this through my data science and content work. Through this video, I also had the ability to reflect on how Data and AI are transforming golf while keeping the spirit of the game alive.  Special thanks to SAS for making this possible! \n\nSponsors, Affiliates, and Partners:\n- Pathrise - http://pathrise.com/KenJee | Career mentorship for job applicants (Free till you land a job)\n- Taro - http://jointaro.com/r/kenj308 (20% discount) | Career mentorship if you already have a job \n- 365 Data Science (57% discount) - https://365datascience.pxf.io/P0jbBY | Learn data science today\n- Interview Query (10% discount) - https://www.interviewquery.com/?ref=kenjee |  Interview prep questions\n\nMORE DATA SCIENCE CONTENT HERE:\n🐤My Twitter - https://twitter.com/KenJee_DS\n👔 LinkedIn -  https://www.linkedin.com/in/kenjee/\n📈 Kaggle - https://www.kaggle.com/kenjee\n📑 Medium Articles - https://medium.com/@kenneth.b.jee\n💻 Github - https://github.com/PlayingNumbers\n🏀 My Sports Blog -https://www.playingnumbers.com\n\nCheck These Videos Out Next! \nMy Leaderboard Project: https://www.youtube.com/watch?v=myhoWUrSP7o&ab_channel=KenJee\n66 Days of Data: https://www.youtube.com/watch?v=qV_AlRwhI3I&ab_channel=KenJee\nHow I Would Learn Data Science in 2021: https://www.youtube.com/watch?v=41Clrh6nv1s&ab_channel=KenJee\n\nMy Playlists \nData Science Beginners: https://www.youtube.com/playlist?list=PL2zq7klxX5ATMsmyRazei7ZXkP1GHt-vs\nProject From Scratch: https://www.youtube.com/watch?v=MpF9HENQjDo&list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t&ab_channel=KenJee\nKaggle Projects: https://www.youtube.com/playlist?list=PL2zq7klxX5AQXzNSLtc_LEKFPh2mAvHIO'},
#     'defaultAudioLanguage': 'en-US'},
#    'contentDetails': {'duration': 'PT12M38S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1521',
#     'likeCount': '75',
#     'favoriteCount': '0',
#     'commentCount': '22'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# #### Finalised desired data pieces

# %%
['id', 'publishedAt', 'channelId', 'title', 'description', 'tags', 'categoryId',
'defaultLanguage', 'duration', 'caption', 'licensedContent', 'contentRating',
'viewCount', 'likeCount', 'favoriteCount', 'commentCount']
# Out:
# ['id',
#  'publishedAt',
#  'channelId',
#  'title',
#  'description',
#  'tags',
#  'categoryId',
#  'defaultLanguage',
#  'duration',
#  'caption',
#  'licensedContent',
#  'contentRating',
#  'viewCount',
#  'likeCount',
#  'favoriteCount',
#  'commentCount']

# %% [markdown]
# #### Testing Data Set of Video IDs

# %%
test_video_id_list = list(channel_video_df['video_id'])[:500]
print(len(test_video_id_list))
print(type(test_video_id_list))
# Out:
# 500
# <class 'list'>

# %% [markdown]
# #### Testing Results of Larger Requests

# %%
# request = youtube.videos().list(
#         part="snippet,contentDetails,statistics",
#         id=','.join(test_video_id_list))
# response = request.execute()
# response

# %% [markdown]
# ## Final Video Stats Function

# %%
def get_video_stats(youtube, list_of_video_ids):

    all_data = []

    # Will only return 50 results at a time, this for loop will do 50 Video IDs at a time
    for i in range(0, len(list_of_video_ids), 50):     

        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(list_of_video_ids[i:i+50]))

        response = request.execute()

        for video in response['items']:
  
            data = dict(channel_id = video['snippet']['channelId'],
                        video_id = video['id'],
                        published_at = video['snippet'].get('publishedAt'),
                        title = video['snippet'].get('title'),
                        description = video['snippet'].get('description'),
                        tags = video['snippet'].get('tags', []), # was issue here as not all videos had tags, .get() might generally offer better protection
                        category_id = video['snippet'].get('categoryId'),
                        duration = video['contentDetails'].get('duration'),
                        caption = video['contentDetails'].get('caption'),
                        licensed_content = video['contentDetails'].get('licensedContent'),
                        default_language = video['snippet'].get('defaultLanguage'),
                        content_rating = video['contentDetails'].get('contentRating'),
                        view_count = video['statistics'].get('viewCount'),
                        like_count = video['statistics'].get('likeCount'), # issue 
                        favourite_count = video['statistics'].get('favoriteCount'),
                        comment_count = video['statistics'].get('commentCount'))

            all_data.append(data)

    return all_data

# %%
video_stats = get_video_stats(youtube, test_video_id_list)

# %% [markdown]
# ## Test Video Stats Dataframe

# %%
video_stats_df = pd.DataFrame(video_stats)
video_stats_df
# Out:
#                    channel_id     video_id          published_at  \
# 0    UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1    UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2    UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3    UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4    UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
# ..                        ...          ...                   ...
# 495  UCObs0kLIrDjX2LLSybqNaEA  -Z_cwgzDfPc  2022-03-18T13:30:00Z
# 496  UCObs0kLIrDjX2LLSybqNaEA  dPg14kNalrQ  2022-03-17T13:30:06Z
# 497  UCObs0kLIrDjX2LLSybqNaEA  9YS0o3hy08k  2022-03-17T11:53:28Z
# 498  UCObs0kLIrDjX2LLSybqNaEA  djasGchNkKs  2022-03-16T13:30:13Z
# 499  UCObs0kLIrDjX2LLSybqNaEA  Wl7F8SKpers  2022-03-16T11:54:30Z
#
#                                                  title  \
# 0                               A Data Dream Come True
# 1    The Death of the Full-Time Job (Rise of the Co...
# 2                How to Survive a Down Data Job Market
# 3             The Harsh Reality of the Data Job Market
# 4            7 Industries AI will Aggressively Disrupt
# ..                                                 ...
# 495  Customer segmentation using clustering | Clust...
# 496  Lambda Expression In Java | Use of Lambda Expr...
# 497  Today’s Job opportunities and free course on R...
# 498  Brand Strategy | Brand Positioning | Core Valu...
# 499  Today’s Job opportunities and free courses on ...
#
#                                            description  \
# 0    #datascience  #KenJee \nI gave up on my dream ...
# 1    #KenJee #jobs \nBuild your new website in seco...
# 2    #datascience  #KenJee \n\nIn this video, I giv...
# 3    #DataScience #KenJee \nFrom everything I'm hea...
# 4    #DataScience #KenJee \n\nThe future is here, a...
# ..                                                 ...
# 495  Clustering is the task of dividing the populat...
# 496  Among various new feature additions to Java, t...
# 497  Free course on R Programming - https://glacad....
# 498  Logical Reasoning is a part of almost all majo...
# 499  Link to free Data Structures course - https://...
#
#                                                   tags category_id   duration  \
# 0    [Data Science, Ken Jee, Machine Learning, Spor...          28   PT12M38S
# 1    [Data Science, Ken Jee, Machine Learning, jobs...          28     PT7M9S
# 2    [Data Science, Ken Jee, data scientist, data s...          28    PT9M56S
# 3    [Data Science, Ken Jee, data scientist, data s...          28    PT6M43S
# 4    [Data Science, Ken Jee, Machine Learning, ai, ...          28   PT10M44S
# ..                                                 ...         ...        ...
# 495  [customer segmentation using clustering, custo...          27    PT58M2S
# 496  [lamda expression in java, java, java 8, lambd...          27  PT1H1M30S
# 497  [Great Learning, Great Lakes, Data Analytics, ...          27   PT19M31S
# 498  [brand management, brand management strategies...          27  PT1H5M51S
# 499  [Great Learning, Great Lakes, Data Analytics, ...          27      PT21M
#
#     caption  licensed_content default_language content_rating view_count  \
# 0     false              True               en             {}       1521
# 1     false              True               en             {}       5386
# 2     false              True               en             {}      16112
# 3     false              True               en             {}     104975
# 4     false              True               en             {}       5753
# ..      ...               ...              ...            ...        ...
# 495   false             False             None             {}       6822
# 496   false             False             None             {}       1702
# 497   false             False             None             {}       1253
# 498   false             False             None             {}       1442
# 499   false             False             None             {}       1104
#
#     like_count favourite_count comment_count
# 0           75               0            22
# 1          365               0            73
# 2          529               0            64
# 3         2554               0           292
# 4          235               0            41
# ..         ...             ...           ...
# 495        100               0            14
# 496         43               0             3
# 497         30               0             2
# 498         49               0             2
# 499         27               0             0
#
# [500 rows x 16 columns]

# %%
len(video_stats)
# Out:
# 500

# %% [markdown]
# # Full Video Database

# %% [markdown]
# #### Tasks
#
# - Get full Database
# - Combine with channel stats
# - Duration mapping
# - Category mapping
# - Published date format
# - Like Ratio new column?
# - Tags format OHE?
# - Has Tags/Doesn't have tags column
# - Description word count
# - Title word count

# %%
video_id_list = list(channel_video_df['video_id'])
print(len(video_id_list))
print(type(video_id_list))
# Out:
# 10776
# <class 'list'>

# %%
full_video_stats = get_video_stats(youtube, video_id_list)
full_video_stats_df = pd.DataFrame(full_video_stats)
full_video_stats_df
# Out:
#                      channel_id     video_id          published_at  \
# 0      UCiT9RITQ9PW6BhXK0y2jaeg  L5Cis5bOwgw  2023-11-17T12:00:28Z
# 1      UCiT9RITQ9PW6BhXK0y2jaeg  M1I5HlzQges  2023-09-22T11:46:35Z
# 2      UCiT9RITQ9PW6BhXK0y2jaeg  T_-0l0ORi5I  2023-09-05T10:50:39Z
# 3      UCiT9RITQ9PW6BhXK0y2jaeg  w13zJB_jyBI  2023-08-24T11:30:19Z
# 4      UCiT9RITQ9PW6BhXK0y2jaeg  oZ9rMrqyTbI  2023-08-14T11:30:19Z
# ...                         ...          ...                   ...
# 10771  UCb5aI-GwJm3ZxlwtCsLu78Q  khKT1RMe_Fk  2020-07-02T00:56:33Z
# 10772  UCb5aI-GwJm3ZxlwtCsLu78Q  ae_XVhjHd_o  2020-06-30T08:21:17Z
# 10773  UCb5aI-GwJm3ZxlwtCsLu78Q  V-EssPrGPHg  2020-06-24T05:08:39Z
# 10774  UCb5aI-GwJm3ZxlwtCsLu78Q  KiqPS6du3B4  2020-06-20T01:29:43Z
# 10775  UCb5aI-GwJm3ZxlwtCsLu78Q  QMovh2PPhbg  2020-05-29T00:42:17Z
#
#                                                    title  \
# 0                                 A Data Dream Come True
# 1      The Death of the Full-Time Job (Rise of the Co...
# 2                  How to Survive a Down Data Job Market
# 3               The Harsh Reality of the Data Job Market
# 4              7 Industries AI will Aggressively Disrupt
# ...                                                  ...
# 10771  11 YouTube Channels Every Data Scientist Shoul...
# 10772  Text analysis / mining in R - how to plot word...
# 10773  Discover 7 Hidden Gems in the R Package Ecosystem
# 10774         Clean column names in R with clean_names()
# 10775  How to plot a time series in R with ggplot2 in...
#
#                                              description  \
# 0      #datascience  #KenJee \nI gave up on my dream ...
# 1      #KenJee #jobs \nBuild your new website in seco...
# 2      #datascience  #KenJee \n\nIn this video, I giv...
# 3      #DataScience #KenJee \nFrom everything I'm hea...
# 4      #DataScience #KenJee \n\nThe future is here, a...
# ...                                                  ...
# 10771  🔔 *Subscribe for weekly R videos:* https://www...
# 10772  🔔 *Subscribe for weekly R videos:* https://www...
# 10773  🔔 *Subscribe for weekly R videos:* https://www...
# 10774  🔔 *Subscribe for weekly R videos:* https://www...
# 10775  🧰 Data science projects & consulting - https:/...
#
#                                                     tags category_id  \
# 0      [Data Science, Ken Jee, Machine Learning, Spor...          28
# 1      [Data Science, Ken Jee, Machine Learning, jobs...          28
# 2      [Data Science, Ken Jee, data scientist, data s...          28
# 3      [Data Science, Ken Jee, data scientist, data s...          28
# 4      [Data Science, Ken Jee, Machine Learning, ai, ...          28
# ...                                                  ...         ...
# 10771                                                 []          28
# 10772  [datascience, tidytext, tidyverse, ggraph, igr...          28
# 10773                                                 []          28
# 10774                              [datascience, rstats]          28
# 10775  [ggplot2, timeseries, datascience, datascience...          22
#
#        duration caption  licensed_content default_language content_rating  \
# 0      PT12M38S   false              True               en             {}
# 1        PT7M9S   false              True               en             {}
# 2       PT9M56S   false              True               en             {}
# 3       PT6M43S   false              True               en             {}
# 4      PT10M44S   false              True               en             {}
# ...         ...     ...               ...              ...            ...
# 10771   PT5M44S   false             False             None             {}
# 10772  PT25M38S   false             False             None             {}
# 10773  PT20M18S   false             False             None             {}
# 10774   PT3M16S   false             False             None             {}
# 10775  PT11M44S   false             False             None             {}
#
#       view_count like_count favourite_count comment_count
# 0           1521         75               0            22
# 1           5386        365               0            73
# 2          16112        529               0            64
# 3         104975       2554               0           292
# 4           5753        235               0            41
# ...          ...        ...             ...           ...
# 10771      11907        438               0            36
# 10772      27396        627               0            61
# 10773      11757        484               0            49
# 10774       4562        116               0            11
# 10775       5689         57               0             9
#
# [10776 rows x 16 columns]

# %% [markdown]
# # Full Complete Database

# %%
full_df = pd.merge(full_video_stats_df, channel_stats_df, on='channel_id', how='left')
full_df.tail()
# Out:
#                      channel_id     video_id          published_at  \
# 10771  UCb5aI-GwJm3ZxlwtCsLu78Q  khKT1RMe_Fk  2020-07-02T00:56:33Z
# 10772  UCb5aI-GwJm3ZxlwtCsLu78Q  ae_XVhjHd_o  2020-06-30T08:21:17Z
# 10773  UCb5aI-GwJm3ZxlwtCsLu78Q  V-EssPrGPHg  2020-06-24T05:08:39Z
# 10774  UCb5aI-GwJm3ZxlwtCsLu78Q  KiqPS6du3B4  2020-06-20T01:29:43Z
# 10775  UCb5aI-GwJm3ZxlwtCsLu78Q  QMovh2PPhbg  2020-05-29T00:42:17Z
#
#                                                    title  \
# 10771  11 YouTube Channels Every Data Scientist Shoul...
# 10772  Text analysis / mining in R - how to plot word...
# 10773  Discover 7 Hidden Gems in the R Package Ecosystem
# 10774         Clean column names in R with clean_names()
# 10775  How to plot a time series in R with ggplot2 in...
#
#                                              description  \
# 10771  🔔 *Subscribe for weekly R videos:* https://www...
# 10772  🔔 *Subscribe for weekly R videos:* https://www...
# 10773  🔔 *Subscribe for weekly R videos:* https://www...
# 10774  🔔 *Subscribe for weekly R videos:* https://www...
# 10775  🧰 Data science projects & consulting - https:/...
#
#                                                     tags category_id  \
# 10771                                                 []          28
# 10772  [datascience, tidytext, tidyverse, ggraph, igr...          28
# 10773                                                 []          28
# 10774                              [datascience, rstats]          28
# 10775  [ggplot2, timeseries, datascience, datascience...          22
#
#        duration caption  licensed_content  ... content_rating view_count  \
# 10771   PT5M44S   false             False  ...             {}      11907
# 10772  PT25M38S   false             False  ...             {}      27396
# 10773  PT20M18S   false             False  ...             {}      11757
# 10774   PT3M16S   false             False  ...             {}       4562
# 10775  PT11M44S   false             False  ...             {}       5689
#
#       like_count favourite_count comment_count  \
# 10771        438               0            36
# 10772        627               0            61
# 10773        484               0            49
# 10774        116               0            11
# 10775         57               0             9
#
#                           channel_name subscribers total_views total_videos  \
# 10771  Tom Henry - data science with R        3760      191499           16
# 10772  Tom Henry - data science with R        3760      191499           16
# 10773  Tom Henry - data science with R        3760      191499           16
# 10774  Tom Henry - data science with R        3760      191499           16
# 10775  Tom Henry - data science with R        3760      191499           16
#
#                     playlist_id
# 10771  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10772  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10773  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10774  UUb5aI-GwJm3ZxlwtCsLu78Q
# 10775  UUb5aI-GwJm3ZxlwtCsLu78Q
#
# [5 rows x 21 columns]

# %%
full_df.to_csv('raw_df.csv', index=False)

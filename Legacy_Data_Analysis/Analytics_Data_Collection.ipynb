# %% [markdown]
# # Importing Libraries

# %%
from googleapiclient.discovery import build
import pandas as pd
import pickle
import os
from dotenv import load_dotenv

# %% [markdown]
# # Establishing API Connection

# %%
load_dotenv()

api_key = os.getenv('API_KEY')

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# # Importing Chosen Playlist IDs

# %%
def chosen_playlist_ids():

    with open('chosen_playlist_ids.pkl', 'rb') as file:
        playlist_ids = pickle.load(file)
    
    return playlist_ids

# %%
playlist_ids = chosen_playlist_ids()

# %% [markdown]
# # Grabbing Video IDs

# %%
def mass_video_ids(youtube, wanted_playlist_ids):

    all_data = []

    for id in wanted_playlist_ids:
        
        nextpage = True
        page = None

        while nextpage:
        # request for first page of playlist
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = id,
                maxResults=50,
                pageToken=page)
            # dictionary of the first page   
            response = request.execute()

        # Accessing videos ids on that first page
            for i in range(len(response['items'])):
                data = dict(playlist_id = id,
                    video_id = response['items'][i]['contentDetails']['videoId'])
                all_data.append(data)

            # Checking to see if there is a next page
            if 'nextPageToken' in response:
                page = response['nextPageToken']              

            else:
                nextpage = False
    # Create df
    all_data_df = pd.DataFrame(all_data)

    return all_data_df

# %%
video_ids = mass_video_ids(youtube, playlist_ids)

# %%
len(video_ids)
# Out:
# 9322

# %%
video_ids.head()
# Out:
#                 playlist_id     video_id
# 0  UUvZnwzmc3m1Eush-Or8Z6DA  3fqTNzXY5tg
# 1  UUvZnwzmc3m1Eush-Or8Z6DA  bgVu5WVR9SE
# 2  UUvZnwzmc3m1Eush-Or8Z6DA  4we3smhjAB8
# 3  UUvZnwzmc3m1Eush-Or8Z6DA  lpF5SSgczeE
# 4  UUvZnwzmc3m1Eush-Or8Z6DA  cRVM-LTe3fI

# %% [markdown]
# # Getting Video Stats

# %%
video_ids_list = list(video_ids['video_id'])

# %%
def get_video_stats(youtube, list_of_video_ids):

    all_data = []

    # Will only return 50 results at a time, this for loop will do 50 Video IDs at a time
    for i in range(0, len(list_of_video_ids), 50):     

        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(list_of_video_ids[i:i+50]))

        response = request.execute()

        for video in response['items']:
  
            data = dict(video_id = video['id'],
                        channel_id = video['snippet']['channelId'],
                        published_at = video['snippet'].get('publishedAt'),
                        title = video['snippet'].get('title'),
                        description = video['snippet'].get('description'),
                        tags = video['snippet'].get('tags', []), # was issue here as not all videos had tags, .get() might generally offer better protection
                        category_id = video['snippet'].get('categoryId'),
                        duration = video['contentDetails'].get('duration'),
                        caption = video['contentDetails'].get('caption'),
                        licensed_content = video['contentDetails'].get('licensedContent'),
                        default_language = video['snippet'].get('defaultLanguage'),
                        content_rating = video['contentDetails'].get('contentRating'),
                        view_count = video['statistics'].get('viewCount'),
                        like_count = video['statistics'].get('likeCount'), # issue 
                        favourite_count = video['statistics'].get('favoriteCount'),
                        comment_count = video['statistics'].get('commentCount'))

            all_data.append(data)

    all_data_df = pd.DataFrame(all_data)

    return all_data_df

# %%
video_stats_df = get_video_stats(youtube, video_ids_list)

# %%
video_stats_df.head()
# Out:
#       video_id                channel_id          published_at  \
# 0  3fqTNzXY5tg  UCvZnwzmc3m1Eush-Or8Z6DA  2023-02-19T14:00:02Z
# 1  bgVu5WVR9SE  UCvZnwzmc3m1Eush-Or8Z6DA  2022-11-04T03:32:38Z
# 2  4we3smhjAB8  UCvZnwzmc3m1Eush-Or8Z6DA  2022-11-01T16:30:09Z
# 3  lpF5SSgczeE  UCvZnwzmc3m1Eush-Or8Z6DA  2022-10-25T14:00:07Z
# 4  cRVM-LTe3fI  UCvZnwzmc3m1Eush-Or8Z6DA  2022-10-07T03:36:26Z
#
#                                                title  \
# 0               Using Code and GPT-3 to Learn Faster
# 1  Data Analyst MENTORSHIP -  Q&A (while I drink ...
# 2                    How Data Science ACTUALLY Works
# 3  Does Instagram think you live in an influentia...
# 4  Data Analyst MENTORSHIP -  Q&A (while I drink ...
#
#                                          description tags category_id  \
# 0  Thanks to ProjectPro.io for their support: htt...   []          27
# 1  ⬇️⬇️⬇️Check here prior to asking your question...   []          27
# 2  Check out Deepnote for the easiest way to prac...   []          27
# 3  Request this and many other datasets @: https:...   []          27
# 4  ⬇️⬇️⬇️Check here prior to asking your question...   []          27
#
#     duration caption  licensed_content default_language content_rating  \
# 0    PT18M6S   false              True             None             {}
# 1   PT29M22S   false              True             None             {}
# 2   PT26M50S   false              True             None             {}
# 3  PT1H24M8S   false              True             None             {}
# 4   PT26M55S   false              True             None             {}
#
#   view_count like_count favourite_count comment_count
# 0       6871        184               0            23
# 1       3723        184               0             9
# 2      85152       2647               0           136
# 3       4470        158               0            12
# 4       3078        104               0             4

# %% [markdown]
# # Creating Channel Stats Dataframe

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(part='snippet,contentDetails,statistics', id=','.join(channel_ids))
    
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name = response['items'][i]['snippet']['title'],
                channel_id = response['items'][i]['id'],
                subscribers = response['items'][i]['statistics']['subscriberCount'],
                total_views = response['items'][i]['statistics']['viewCount'],
                total_videos = response['items'][i]['statistics']['videoCount'],
                playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_ids_list = list(video_stats_df['channel_id'].unique())

# %%
len(channel_ids_list)
# Out:
# 22

# %%
channel_stats_df = pd.DataFrame(get_channel_stats(youtube, channel_ids_list))

# %%
channel_stats_df
# Out:
#                    channel_name                channel_id subscribers  \
# 0                   Keith Galli  UCq6XkhO5SZ66N04IcPbqNcw      209000
# 1                      DataCamp  UC79Gv3mYp6zKiSwYemEik9A      155000
# 2                Great Learning  UCObs0kLIrDjX2LLSybqNaEA      809000
# 3                Data Professor  UCV8e2g4IWQqK71bbzGDEI4Q      171000
# 4            Shashank Kalanithi  UCvZnwzmc3m1Eush-Or8Z6DA      140000
# 5                 Sundas Khalid  UCteRPiisgIoHtMgqHegpWAQ      185000
# 6                  Tech Classes  UCPvDKIsrjA_h3g5yZJwCIHA       30000
# 7         Thu Vu data analytics  UCJQJAI7IjbLcpsjWdSzYz0Q      179000
# 8                    Krish Naik  UCNU_lfiiWBdtULKOw6X0Dig      851000
# 9              Nicholas Renotte  UCHXa4OpASJEwrHrLeIzw7Yg      220000
# 10                      Ken Jee  UCiT9RITQ9PW6BhXK0y2jaeg      255000
# 11             Learn with Lukas  UCw_LFe2pS8x3NyipGNJgeEA       29300
# 12               Darshil Parmar  UCChmJrVa8kDg05JfCmxpLRw      106000
# 13            Data Science Dojo  UCzL_0nIe8B4-7ShhVPfJkgw      101000
# 14                   ArjanCodes  UCVhQ2NnY5Rskt6UjCUkJ_DA      211000
# 15                      Mo Chen  UCDybamfye5An6p-j1t2YMsg       75700
# 16              Study with Tina  UCI8JpGrDmtggrryhml8kFGw       20900
# 17             365 Data Science  UCEBpSZhI1X8WaP-kY_2LLcg      303000
# 18                    Greg Hogg  UCJublDh2UsiIKsAE1553miw       61900
# 19                      techTFQ  UCnz-ZXXER4jOvuED5trXfEA      256000
# 20  StatQuest with Josh Starmer  UCtYLUTtgS3k1Fg4y5tAhLbw     1060000
# 21             Alex The Analyst  UC7cs8q-gJRlGwj4A8OmCmXg      647000
#
#    total_views total_videos               playlist_id
# 0     14309460           80  UUq6XkhO5SZ66N04IcPbqNcw
# 1     22950468         1532  UU79Gv3mYp6zKiSwYemEik9A
# 2     63094287         1857  UUObs0kLIrDjX2LLSybqNaEA
# 3      5502842          325  UUV8e2g4IWQqK71bbzGDEI4Q
# 4      6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 5      9376789          116  UUteRPiisgIoHtMgqHegpWAQ
# 6      1954008          156  UUPvDKIsrjA_h3g5yZJwCIHA
# 7      5981075           79  UUJQJAI7IjbLcpsjWdSzYz0Q
# 8     86329667         1758  UUNU_lfiiWBdtULKOw6X0Dig
# 9     14187082          303  UUHXa4OpASJEwrHrLeIzw7Yg
# 10     8740951          286  UUiT9RITQ9PW6BhXK0y2jaeg
# 11     1588707           58  UUw_LFe2pS8x3NyipGNJgeEA
# 12     4429930          139  UUChmJrVa8kDg05JfCmxpLRw
# 13     5737808          455  UUzL_0nIe8B4-7ShhVPfJkgw
# 14    14481229          308  UUVhQ2NnY5Rskt6UjCUkJ_DA
# 15     2308352           74  UUDybamfye5An6p-j1t2YMsg
# 16      291211          249  UUI8JpGrDmtggrryhml8kFGw
# 17    13543820          223  UUEBpSZhI1X8WaP-kY_2LLcg
# 18     4258081          576  UUJublDh2UsiIKsAE1553miw
# 19    13467047          100  UUnz-ZXXER4jOvuED5trXfEA
# 20    57507946          266  UUtYLUTtgS3k1Fg4y5tAhLbw
# 21    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg

# %% [markdown]
# # Combining DataFrames

# %%
df = pd.merge(video_stats_df, channel_stats_df, on='channel_id', how='left')

# %%
df
# Out:
#          video_id                channel_id          published_at  \
# 0     3fqTNzXY5tg  UCvZnwzmc3m1Eush-Or8Z6DA  2023-02-19T14:00:02Z
# 1     bgVu5WVR9SE  UCvZnwzmc3m1Eush-Or8Z6DA  2022-11-04T03:32:38Z
# 2     4we3smhjAB8  UCvZnwzmc3m1Eush-Or8Z6DA  2022-11-01T16:30:09Z
# 3     lpF5SSgczeE  UCvZnwzmc3m1Eush-Or8Z6DA  2022-10-25T14:00:07Z
# 4     cRVM-LTe3fI  UCvZnwzmc3m1Eush-Or8Z6DA  2022-10-07T03:36:26Z
# ...           ...                       ...                   ...
# 9317  4rfr6A3lO-Y  UC7cs8q-gJRlGwj4A8OmCmXg  2020-01-30T14:07:55Z
# 9318  OTq2NRy_AGs  UC7cs8q-gJRlGwj4A8OmCmXg  2020-01-25T16:38:39Z
# 9319  ya28cb3zFGE  UC7cs8q-gJRlGwj4A8OmCmXg  2020-01-23T03:16:09Z
# 9320  Hsi2BG0SOiQ  UC7cs8q-gJRlGwj4A8OmCmXg  2020-01-21T03:52:15Z
# 9321  6lQzbk6_OTw  UC7cs8q-gJRlGwj4A8OmCmXg  2020-01-17T14:31:39Z
#
#                                                   title  \
# 0                  Using Code and GPT-3 to Learn Faster
# 1     Data Analyst MENTORSHIP -  Q&A (while I drink ...
# 2                       How Data Science ACTUALLY Works
# 3     Does Instagram think you live in an influentia...
# 4     Data Analyst MENTORSHIP -  Q&A (while I drink ...
# ...                                                 ...
# 9317  Data Analyst Resume | Reviewing My Resume! | F...
# 9318  Working at a Big Company Vs Small Company | To...
# 9319      Data Analyst Salary | 100k with No Experience
# 9320  Truth About Big Companies | Told by a Fortune ...
# 9321                  Top 3 Data Analyst Skills in 2020
#
#                                             description  \
# 0     Thanks to ProjectPro.io for their support: htt...
# 1     ⬇️⬇️⬇️Check here prior to asking your question...
# 2     Check out Deepnote for the easiest way to prac...
# 3     Request this and many other datasets @: https:...
# 4     ⬇️⬇️⬇️Check here prior to asking your question...
# ...                                                 ...
# 9317  Data Analyst Resume | Reviewing My Resume! | F...
# 9318  Working at a Big Company Vs Small Company | To...
# 9319  Data Analyst Salary | 100k with No Experience ...
# 9320  Truth About Big Companies // There are a ton o...
# 9321  Top 3 Data Analyst Skills in 2020 // There are...
#
#                                                    tags category_id  \
# 0                                                    []          27
# 1                                                    []          27
# 2                                                    []          27
# 3                                                    []          27
# 4                                                    []          27
# ...                                                 ...         ...
# 9317  [Data Analyst, How to become a data analyst, D...          27
# 9318  [Data Analyst, How to become a Data Analyst, B...          22
# 9319  [Data Analyst Salary, Data analyst with no exp...          22
# 9320  [Working at a big company, Big company data an...          22
# 9321  [Top skills for data analyst, Top 3 skills for...          22
#
#        duration caption  licensed_content  ... content_rating view_count  \
# 0       PT18M6S   false              True  ...             {}       6871
# 1      PT29M22S   false              True  ...             {}       3723
# 2      PT26M50S   false              True  ...             {}      85152
# 3     PT1H24M8S   false              True  ...             {}       4470
# 4      PT26M55S   false              True  ...             {}       3078
# ...         ...     ...               ...  ...            ...        ...
# 9317    PT7M33S   false              True  ...             {}      66316
# 9318    PT5M50S   false              True  ...             {}      14527
# 9319     PT5M3S   false              True  ...             {}      62166
# 9320    PT5M45S   false              True  ...             {}       8157
# 9321    PT2M40S   false              True  ...             {}      27814
#
#      like_count favourite_count comment_count        channel_name subscribers  \
# 0           184               0            23  Shashank Kalanithi      140000
# 1           184               0             9  Shashank Kalanithi      140000
# 2          2647               0           136  Shashank Kalanithi      140000
# 3           158               0            12  Shashank Kalanithi      140000
# 4           104               0             4  Shashank Kalanithi      140000
# ...         ...             ...           ...                 ...         ...
# 9317       1574               0            64    Alex The Analyst      647000
# 9318        397               0            20    Alex The Analyst      647000
# 9319       2153               0           227    Alex The Analyst      647000
# 9320        305               0            18    Alex The Analyst      647000
# 9321       1365               0           138    Alex The Analyst      647000
#
#      total_views total_videos               playlist_id
# 0        6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 1        6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 2        6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 3        6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# 4        6562136          152  UUvZnwzmc3m1Eush-Or8Z6DA
# ...          ...          ...                       ...
# 9317    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg
# 9318    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg
# 9319    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg
# 9320    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg
# 9321    27519398          270  UU7cs8q-gJRlGwj4A8OmCmXg
#
# [9322 rows x 21 columns]

# %% [markdown]
# # Saving DataFrame

# %%
with open('new_raw_data.pkl', 'wb') as file:
    pickle.dump(df, file)
